# %%
import openai
import os
import json

from qdrant_client import QdrantClient
from qdrant_client.models import Filter, FieldCondition, MatchValue

from langsmith import Client

# %%
qdrant_client = QdrantClient(url="http://localhost:6333")

# %% [markdown]
# ### Downloaad all data from Qdrant

# %%
all_points = qdrant_client.scroll(
    collection_name="Amazon-items-collection-00",
    limit=1000,
    offset=None,
    with_payload=True,
    with_vectors=False
)

# %%
all_points[0][0].payload
# Out:
# {'description': 'BOVKE Travel Carrying Case for Samaung T7 Shield / T7 / T7 Touch Portable SSD 500GB 1TB 2TB USB 3.2 External Solid State Drives, Extra Mesh Pocket for USB Cables and More Accessories, Black Case Only! ( samsung ssd & accessories not included )This external hard drive case perfectly fit for: Samsung T7 Shield Portable SSD, Samsung T7 Portable SSD, Samsung T7 Touch 500GB 1TB 2TB USB 3.2 Portable Solid State Drives, provide excellent protection, keeps the solid state external hard drives safe from damage and prolongs the service life of your T7 external ssd. This samsung t7 case bag is featured with 2 elastic bands inside, securely store the samsung t7 shield portable ssd, and the T7 Carrying Case can prevent the Samsung external ssd from falling, protects your external solid state drives from tossing around while on the go, gives your portable ssd great protection. This T7 shield hard drive carrying case comes with a mesh pocket to accommodate the USB cables of the Samsung T7 Touch Portable SSD drive and other small accessories. The double zippers of the t7 case are smooth enough for easy opening and closing, offer you excellent using experience. This samsung ssd case is made of hard EVA and PU material, with good waterproof and shockproof, protects your samsung portable ssd from extrusion, dust and splashing, Interior velevt lining is ultra soft, provides great protection for your Samsung T7 ssd external hard drive from scratches, bumping and droping. Dimension: 5.42 x 3.01 x 1.21 inches, compact and lightweight, this Samsung T7 shield ssd case holder comes with a sturdy lanyard and a carabiner to provide various ways to carry, the samsung t7 storage case can be put in your pocket or bag, or you can also hang this T7 ssd bag on your backpack, convenient to use.',
#  'images': 'https://m.media-amazon.com/images/I/41iu-ZNKIgL._AC_.jpg',
#  'rating_number': 446,
#  'price': 10.99,
#  'average_rating': 4.7,
#  'parent_asin': 'B01N1P97SL'}

# %%
all_context = [{"id": data.payload["parent_asin"], "text":data.payload["description"]} for data in all_points[0]]

# %%
all_context
# Out:
# [{'id': 'B01N1P97SL',
#   'text': 'BOVKE Travel Carrying Case for Samaung T7 Shield / T7 / T7 Touch Portable SSD 500GB 1TB 2TB USB 3.2 External Solid State Drives, Extra Mesh Pocket for USB Cables and More Accessories, Black Case Only! ( samsung ssd & accessories not included )This external hard drive case perfectly fit for: Samsung T7 Shield Portable SSD, Samsung T7 Portable SSD, Samsung T7 Touch 500GB 1TB 2TB USB 3.2 Portable Solid State Drives, provide excellent protection, keeps the solid state external hard drives safe from damage and prolongs the service life of your T7 external ssd. This samsung t7 case bag is featured with 2 elastic bands inside, securely store the samsung t7 shield portable ssd, and the T7 Carrying Case can prevent the Samsung external ssd from falling, protects your external solid state drives from tossing around while on the go, gives your portable ssd great protection. This T7 shield hard drive carrying case comes with a mesh pocket to accommodate the USB cables of the Samsung T7 Touch Portable SSD drive and other small accessories. The double zippers of the t7 case are smooth enough for easy opening and closing, offer you excellent using experience. This samsung ssd case is made of hard EVA and PU material, with good waterproof and shockproof, protects your samsung portable ssd from extrusion, dust and splashing, Interior velevt lining is ultra soft, provides great protection for your Samsung T7 ssd external hard drive from scratches, bumping and droping. Dimension: 5.42 x 3.01 x 1.21 inches, compact and lightweight, this Samsung T7 shield ssd case holder comes with a sturdy lanyard and a carabiner to provide various ways to carry, the samsung t7 storage case can be put in your pocket or bag, or you can also hang this T7 ssd bag on your backpack, convenient to use.'},
#  {'id': 'B0B778L1DZ',
#   'text': 'SunFounder Ultimate Starter Kit Compatible with Arduino UNO IDE Scratch, 3 in 1 IoT/Smart Car/Basic Kit with Online Tutorials, Video Courses, 192 Items, 87 Projects, Suitable for Age 8+ Beginners Expert-Designed Courses: Teaming up with Circuit Basics, SunFounder 3-in-1 Starter Kit offers comprehensive videos and online tutorials for well-rounded learning. Suitable for age 8+ beginners. Complete Component Kit: Our kit includes high quality sensors, actuators, power supplies, and an Arduino-compatible Uno for diverse projects and skill-building. Progressive Learning Journey: With Circuit Basics, the courses cater to your skill level, covering essentials and advancing to complex topics like IoT, robot cars, and sensor integration. Engaging Projects: Apply your knowledge through hands-on projects, ranging from simple LED blinking to advanced robot car, IoT applications, for skill development and confidence-building. Dedicated Support: Benefit from our ongoing assistance, including a community forum and timely technical help for a seamless learning experience.'},
#  {'id': 'B0B5GPCS2V',
#   'text': "Gyehuo for Airpod Case, Compatible with Apple AirPods 2nd & 1st Generation Case (Cow) 【Perfectly Fit】 Compatible with Apple AirPods 1st & AirPods 2nd generation case. The AirPods case cover fits tightly without worrying about the AirPod case coming loose or coming off 【360° Full Protection】This AirPods case protective cover made of premium flexible material,protects your AirPods against bumps, drops and scratches 【Fashion Design】The cute AirPods case is protected by a protective PET film. Bright and lovely patterns don't fade with time 【Convenient Charging & Portable Keychain】 Charge your airpods without removing the cover. Comes with a metal Keychain, making it convenient and secure to carry your AirPod 2 & 1 anywhere 【Our Service】The airpod case is returnable in 30 days, please don’t hesitate to contact us if you have any question about our product. We will always offer the best solutions"},
#  {'id': 'B0BRQRS9BM',
#   'text': "KNOWSQT Wired Computer Keyboard - Milk Tea Colorful Full-Size Round Keycaps Typewriter Keyboards for Windows, Laptop, PC, Desktop, Mac ▥【Milk tea colorful Wired Computer Keyboard】most popular color of 2022, to attract more people's eyes, give you a different vision, enjoy a different keyboard experience, create a colorful desk, and be a pleasant mood for you! ▥【USB Cable Connection & More Stable】Cable length 65inch, plug and play, no need to install other software, no delays or Drop the line, Make your desk surface more neat and tidy, Keyboard just insert a single USB port to use your USB Wired Keyboard! ▥【Detachable Keycaps & Floating Button Design】All buttons can be disassembled, put in water to clean, and also equipped with a brush to clean the garbage on the keyboard. The floating button design gives you a soft and quiet feeling, and takes you back to the most original type of Typewriter Style! ▥【Wide Compatibility】Wired Computer Keyboard are perfectly compatible with Windows 10 / 8 / 7 / XP/ Vista operating system (USB 2.0 port). The Wired keyboard work with PC, Mac, Desktop, Laptop, Notebook, Chrome-Book, Computers, Smart TVs, etc. It is the best choice for personal offices and corporate businesses! ▥【Any Refunds and Questions will Reply to you within 12 Hours】 Whether it's exceeding Amazon's return time or receiving a defective product, Or anything product problem, please contact us through Amazon email for the first time, and we will provide you with satisfactory solutions. ❤1 Year Warranty❤"},
#  {'id': 'B0BQXLF477',
#   'text': 'BLACKSYNCZE USB C to Lightning Cable 2Pack 6FT, [MFi Certified] iPhone Charger Cord USB C Nylon Braided Type C to Lightning Cable Fast Charging for iPhone 13 12 11 Pro Max XR XS X 8 7 6s, SE2020 [MFi Certified iPhone Cable] This USB C to Lightning Cable features an upgraded C94 connector and original MFi chip for seamless compatibility and no pop-up error messages; protects your devices from overcurrent and overvoltage while charging. [20W PD Fast Charging Cable] With 20W PD fast charging, this iPhone Charger Fast Charging Cable can charge an iPhone 13 or 12 up to 50% in just 30 minutes, which is 2.5 times faster than a standard lightning cable (5V/1A). [Durability & Flexibility] Includes built-in overvoltage and overcurrent protection and features a durable design with reinforced joints, silver-plated connectors, and a triple layer of braided nylon; withstands over 12,000 bends in laboratory tests. [Wide Compatibility] This Lightning Cable USB C is widely compatible with fast-charging support for iPhone 13 Pro Max, 13 Pro, 13, 13 Mini, 12 Pro Max, 12 Pro, 12, 12 Mini, 11 Pro Max, 11 Pro, 11 iPhone XR, XS, Max, XS, X, SE2020, iPhone 8 Plus, and 8; also supports standard charging for iPhone 7 Plus, 7, 6s Plus, 6s, 6 Plus, 6, 5s, 5c, 5 SE, etc. [What You Get] Includes 2 Pack 6FT BLACKSYNCZE Type C to Lightning Cable with full lifetime warranty and friendly 24/7 customer service.'},
#  {'id': 'B0B2JT5B86',
#   'text': "KEDIERS PC Case - ATX Tower Tempered Glass Gaming Computer Case with 9 ARGB Fans,C590 [9 Pre-Installed 120mm ARGB Fans]-- Suitable for enhanced cooling. With the pre-installed ARGB controller you can sync it with the motherboard, each addressable ARGB fan offers 16.8 million colors for exceptional customizable lighting. You don't need to pay extra for fans. Only when the 5V-3PIN cable on the control board is connected to the motherboard can the ARGB light synchronization be realized. [2 Tempered glass]-- C590 gaming case is equipped 2 * 4mm thick tempered glass, which can clearly see the RGB lighting and the components in the building, Creating a good gaming atmosphere. [I/O Panel]-- 2 x USB3.0 Port, 1 x Type C, 1 x HD Audio, Reset Button, Power Button. [Cable Management]-- Back Bays: 3x 3.5'' HDD's and 3 x 2.5'' SSD's. Removable storage cable box;Designed reasonable back routing hole. [Remarkable Expansion]-- C590 Mid Tower Gaming Computer Case supports ATX/Micro-ATX/Mini-ITX motherboards. [Package]-- 1* computer case /9* ARGB FANS /1* Multifunctional RGB remote control."},
#  {'id': 'B0CGV9LQB8',
#   'text': 'Blood Glucose Monitor Smart Watch for iPhone Android Bluetooth Calling 2023 Upgraded Non-invasive Blood Sugar Test Smartwatchs Men Women with Heart Rate Blood Oxygen Pressure HRV Fitness Tracker Watch 【New Upgraded Blood Sugar Monitor Watch】This smart watch offers non-invasive blood glucose testing, eliminating the need for needles or blood samples. The built-in blood sugar monitoring chip provides precise and safe readings.\u200b The core patented new algorithm evaluates the users health. stores data on the mobile phone, accurately calculates, comprehensively evaluates, and pushes personalized blood sugar interval values, so you can stay informed and take control of your health. 【24H Accurate Health Monitoring】Intelligent diabetic health watch, 1.92inch 280*350 HD touch screen, non-invasive blood sugar test, heart rate monitoring, blood pressure monitoring, blood oxygen monitoring and save the data results in the APP, which is convenient for viewing and analysis at anytime. And it will monitor your sleep status automatically and provides comprehensive sleep quality analysis. 【Activity & Fitness Tracker smartwatch with IP68 Waterproof】Track your health and fitness goals with the fitness & activity tracker. The tracker watch supports a variety of sports modes such as running, cycling, and hiking etc., and can monitor important data such as sports center rate distance, speed and calorie consumption in real time, helping you explore the larger world and constantly expand your boundaries and with an IP68 waterproof, the watch is perfect for swimming and any activity. 【Personalized Watch Dial with Practical Tools】The fitness watch for men women comes with theme dials and even upload your own photos, such as selfies or pictures of your pets, to create a truly personalized look. The smartwatch features practical tools such as remote take photo, stopwatch, timer, music control, breathing training, night mode, alarm clock and wrist up awake, weather forecast, giving more convenience and fun to your life. 【Multifunction Bluetooth Smart Watch】The smartwatch is compatible with smartphones that run on iOS 8.0 or Android OS 5.0 or higher. This fitness activity smart watch full screen for iPhone and Android phones includes a bunch of new features such as smart watch can call reminder, receive and notifications WhatsAPP, SMS, Facebook, Twitter, etc. messenger reminder by bluetooth and avoid missing important information.'},
#  {'id': 'B0BKJGRZGP',
#   'text': "140W USB C Charger Power Adapter for MacBook Pro 16 inch 2023 2021, MacBook Pro 14 15 13, MacBook Air, PD 3.1 28V Great for M1 / M2 Laptop, Original Quality, Reduce Battery Aging, Temperature Control Fast Charge Your MacBook: thanks to a 140W / 28V / 5A max output and USB Power Delivery 3.1, you can full charge your 2021 MacBook Pro 16ʺ in only 1h 26 mins and charge it up to 50% in only 26 mins as fast as to full charge a cellphone. Notice: doesn't include USB C to MagSafe 3 Cable. Original Quality Helps to Keep MacBook Battery Health: built-in original dynamic software and hardware systems to keep Maximum Battery Capacity to 98%, intelligently learning your daily charging routine to reduce battery aging and intelligently monitoring temperature to safeguard your devices. Strong Power to Support “M” Series Chip: PD 3.1 provide you a higher charging efficiency than PD 3.0 to meet the high-speed processing capacity of M1, M1 Pro, M1 Max, M2 chip, choose MARSDOCK PD 3.1 charger if your MacBook use the “M” series chip. Universal Compatibility: thanks to the newest PD 3.1 protocol, it can intelligently output 127W, 96W, 90W, 67W, 65W, 45W, 30W according to your device and keep the peak charging performance at the mean time, widely compatible with MacBook Pro 16”, 15”, 14”, 13”, MacBook Air, Surface(127W/102W), Lenovo(65W/45W), HP, iPad Pro / Air / Mini, iPhone, Samsung Galaxy, Google Pixel... Superior Safety and Dependable Warranty: built-in multi safeguards to protect against overcharging, short circuiting, overheating, spark; enjoy worry-free 12-month warranty by refund or replacement and friendly customer service."},
#  {'id': 'B08LYX8BZ3',
#   'text': '4-Pack Replace for Dymo Label Maker Refills Metallic Letratag Labeling Tape 91338, Black Print on Metallic Silver Tape, 12mm x 4m - 1/2" x 13\', Work with Dymo Label Maker LT-100H LT-110T QX50 LT-200B Package Includes: 4-Pack compatile with dymo letratag refills black on metallic silver label tape 91338. Width: 1/2 inch (12mm) each; Length: 13 feet (4m) each. Compatible with dymo label printer: LT-100H, LT-100T, LT-110T, LT-200B, LT-100H Plus, LT-100T Plus, QX50, XR, XM, 2000. Easy to Peel: Split back design makes the compatible with dymo letra tag labels 12mmx4m- 1/2 x 13 tape easy to peel and apply. Wonfoucs lt metallic plastic labels are water resistant, tear-resistant and wear resistant and create clear, highly visible text. These replacement for dymo letratag label maker refills 1/2 x 13 are suitable for long-lasting applications. Perfect for using in home, office, school and so on, labeling files, folders, shelves, books, cabinets, accessories, etc. Add texture to your labeling work with unique metallic silver look. Our compatible dymo metallic label maker refills stick well on flat and dry surfaces. So please clean the surface of the object to make it free of oil or dirty before you stick the tapes, then flattened the label tape.'},
#  {'id': 'B0B3HYZ427',
#   'text': 'Tronsmart Wireless Earbuds, Dual-Driver Earbuds Bluetooth 5.3 with 3 EQ Modes, in-Ear Bluetooth Headphones IPX5 Waterproof, Stereo Wireless Earphones 32Hrs Playtime for Music, Workout, etc. Black 🎶【Pure Sound Quality】-The wireless earbuds are equipped with a 10mm Dynamic Driver and a balanced Armature Driver, this dual driver technology could deliver high and low-frequency sound directly to your ear without interference. Its wide soundstage is detailed and spacious, the bass has a deep punch, mids are luscious, and treble sparkles. 🎼【3EQ Modes】-The 3EQ modes of these Bluetooth earbuds will upgrade your music experience. The Bass Booster enhances bass-heavy music, Pure makes voices stand out clearly, and the default EQ (Normal) delivers well-balanced sound. To switch to a different mode, quickly press the left bud 3 times. 🦻【One Step Pairing】-The moment you open the charging case, the Bluetooth Headphones will automatically connect to your devices (after being paired the first time). The specific touch control function makes it more convenient, just touch the earbuds for various functions. ⚡【Great Battery Life】 Playtime lasts for over 7 hours from a single charge and a total of 32 hours with a charging case, and the indicator will let you know the electricity anytime. Tronsmart Wireless Earphones can accompany you all day. ✈️【Comfort-fit & Lightweight】After thousands of tests, these wireless headphones are ergonomically designed to fit your ears better, reduce pressure and not slip off. True wireless earbuds come with 3 sizes of soft ear tips to fit all kinds of ear canals, always comfortable for you. Only 4.5g, small size can be taken to anywhere. 📱【Fully Compatible】Updated Bluetooth 5.3 chip provides a more stable connection(up to 15m)and faster pairing (within 2s). Earbuds Bluetooth are compatible with most Bluetooth devices (iOS, Android, Laptop, TV, phones, etc.), ideal for meeting, listening, podcast, calls, and more. 🥰【Professional, Focused, Attentive】Tronsmart as a professional audio equipment manufacturer, has been committed to updating the music experience with technological innovation for years. While we continue to accumulate experience, we also have a professional technology team to solve all your issues anytime. Your Smile is our greatest motivation.'},
#  {'id': 'B0CH4ZTTJJ',
#   'text': 'Military Smart Watch for Men with LED Flashlight 1.45” Rugged Waterproof Smart Watch with 100+ Sports Modes Fitness Tracker with Heart Rate Sleep Monitor Tactical Smartwatch for iPhone Samsung 【YOUR ADVENTURE COMPANION WITH FLASHLIGHT】- EIGIIS military smart watches for men has military-grade standard certification, including -40°C cold resistance, 240-hour moisture resistance, freezing rain resistance, 70°C heat resistance, 96-hour salt spray resistance, impact resistance, etc. In addition, the EIGIIS rugged smart watch is equipped with a small flashlight on the side, adding practical function for your outdoor adventure and helping you light the road in the wilderness. 【SUPPORTS 100+ SPORT MODES】- EIGIIS outdoor sports watch supports up to 100+ sports modes tailored for who love sports, including Running, Climbing, Cycling, Basketball, etc. Whether you’re sweating on the court or riding through the fields, this activity tracker watch can accompany you to enjoy the fun of sports and it will automatically records the steps, heart rate and calories burned. You can check your exercise data on the fitcloudpro app. (Note: The measurement data is FOR REFERENCE ONLY) 【BLUETOOTH CALLING & SMART NOTIFICATION】- With the built-in speaker and microphone, this smart watches for men can easily make and receive calls even when the phone is not nearby. In addition, EIGIIS smart watch with text and call can receive message from Skype, WhatsApp, Facebook, LINE, etc. Free up your hands from mobile phone and never miss important texts and calls, especially when driving, jogging, working out, etc. 【HEALTH MONITORING & SLEEP TRACKER】 - EIGIIS fitness tracker watch provides 24/7 heart rate and blood oxygen monitoring to help you better understand your body condition. Besides, EIGIIS men smart watch also has sleep tracker function to analyze your sleep quality. It will upload your data to FitCloudPro APP, keeps your health always in your eyes. FOR SPORTS OR AVIATION USE ONLY, NOT FOR MEDICAL USE. 【MORE PRACTICAL FUNCTIONS】- EIGIIS multifunctional smartwatch provides various functions to facilitate your life, including pedometer,alarm reminder, remote camera control, find your phone and voice assistant. In addition, EIGIIS Android smart watch is IP67 water resistant that allows you to wash your hands or dishes with the watch. (Note: Don’t use it while diving, sauna, shower,etc.) 【HIGH COMPATIBILITY AND AFTER-SALES SERVICE】- EIGIIS tactical smartwatch is compatible with iOS 10.0 and Andorid 8.0 or above devices. EIGIIS is committed to providing quality after-sales service. EIGIIS provides 12 months quality guarantee for the military smart watch. If you encounter any problems in the process of using the product, please contact us by email, we will definitely help you solve the problem.'},
#  {'id': 'B0C1Z4MNJT',
#   'text': 'Vansuny 5 Pack 64GB USB 3.0 Flash Drives - 70MB/s, High Speed USB Drives USB3.0 Thumb Drives Memory Sticks Zip Drives Jump Drives Pendrives 【USB 3.0 Data Transmission】 With USB 3.0 technology, VANSUNY USB 3.0 flash drive will provide read and write speeds of up to 70 MB/s and 25 MB/s. 【Plug and Play】VANSUNY flash drive, easy to operate, plug and play, no need to install any software. Thumb drive 64GB default format is exFAT, and you can reformat it if needed. 【Considerate design】 Rugged ABS casing for durability and a lanyard loop to prevent loss. LED acts as an indicator light when the USB stick is getting powered, which is helpful in making sure the drive is properly plugged in and working. 【Widely Compatibility】- The Portable USB 3.0 flash drive 64GB is compatible with USB 2.0, and can work on mainstream operating systems, such as Windows, Android, Linux, and Mac OS system etc. 【What You Get】 - 5* 64GB USB 3.0 Flash Drive, 24 Months Warranty, 60 Days Money Back Guarantee and Friendly Customer Service.'},
#  {'id': 'B0B931CQN2',
#   'text': 'EZDIY-FAB ATX 24-pin 90 Degree Power Connector Adapter 5V 3 Pin ARGB Rainbow Female to Male Power Adapter for Computer Motherboard ATX Power Supply- White-1 Pack The ATX 24 Pin 90° Adapter is compatible with all ATX motherboards and power supply units that support a standard 24 pin main power connection. Built with the advanced ARGB lighting system , it features ARGB Rainbow color that glows attractively without straining your eyes . 90 Degrees right angle design, connecting between PSU 24 Pin Cable and motherboard connector, does not cause pressure on the motherboard connector for long-term stable use. ATX 24-pin female to male connector 90 degrees suitable for motherboard .Plug and play installation. This design will solve the PSU installation for the limited height chassis You can install the 24PIN power cable from vertical to horizontal direction with this adapter.'},
#  {'id': 'B0B7N2DVRQ',
#   'text': "TRIDENITE 256 GB NVMe M.2 2280 PCIe Gen 3x4 Internal Solid State Drive (SSD) CrystalDiskMark(CDM) Sequential Speeds Up To: Read 1700MB/s, Write 1000MB/s NVMe (PCIe Gen 3.0 x 4)、M.2 (2280)、3D NAND. Compatible OS: Windows 11、10、7、XP. Linux. Mac OS: 10.X+ Shock Resistence：1,500G/0.5ms、Minimum TBW：200 TB、MTBF：1.5 million hours. Supports: SmartZip、HMB、Trim、DIPM、HIPM Operating Temperature: 0°C ~ 70°C (32°F ~ 158°F). Dimensions: 80 x 22 x 2.15mm (3.14 x 0.86 x 0.08inches), Weight: 6.3g (0.22ounces) Made in Taiwan, 3 year manufacturer's exchange support"},
#  {'id': 'B0BGRWNKZ1',
#   'text': '20pcs Magnetic Cable Ties Twist Ties, Cord Clips Holder, Cable Cord Organizer for Bundling and Organizing, Holding Stuff, Book Markers,Fridge Magnets, or Just for Fun, Assorted Color 4.65" 🔥【Premium Material】These magnetic cable ties are made from soft, flexible, and stretchy silicone, and are easy to pull to the exact size needed. 🔥【Wide Usage】Wrap and tie various items such as electrical cords, cables, etc. They are effortless to use and highly reusable. 🔥【Magnet Design】 Built with two built-in magnets on two ends. Magnetically attaches to many metal surfaces—great replacement for twist ties. 🔥【Interesting Gift】With eye-catching, helpful, and super cute shapes. Interesting gift for kids, friends, family, colleagues, students, teachers, using in home, school, office and so on. 🔥【Service Guarantee】We attach great importance to customer experience and strive to satisfy every customer. If you have any problem with the product, just contact us. We will provide a replacement or refund for you.'},
#  {'id': 'B0BHKMQ7PN',
#   'text': 'Ulirath Case for AirPod 3rd Skull Funny Unique Design Unique Scary Cute for AirPods Air Pods 3 Design Skeleton Cover Cases Skin for Boys Girls Kids 【PREMIUM MATERIAL】This AirPod 3rd protective housing with scary design is made of high quality TPU, and the surface ghost pattern is printed by IMD thermal transfer technology. Thus this case is not easy to break, and the surface pattern will stay bright and beautiful and is not easy to fall off. 【EXCELLENT PROTECTION ABILITY】Our case with dust-proof, shockproof, and anti-fingerprints function can provide a full protection to your AirPods 3. It can protect your AirPods 3rd Gen from outside damage and prevent your Air Pods Third Generation from scratching by any sharp and hard stuffs and leave scratches. 【STYLISH DESIGN】This AirPods 3 case design with a Ghost Calling pattern design which is a very cute and interesting element and has highlight personality. The chic element is suitable for most people, and it is good choice to give it to your family and friends as gift before . 【ULTRA-THIN DESIGN】This thin and light protective shell fits well to the AirPods 3 without creating extra bulk or compromising their wireless charging. The cutout on the bottom of the charging port is very accurate, so you can charge your AirPod 3 with usb cable without removing this protective case. 【THE ATTACHED MOUNTAINEERING】Besides the wonderful skeleton case, the package also include a metal climbing buckle carabiner, which can be very convenient to hang the AirPod on a backpack, belt or key when going out. It is very convenient for outdoor travel, fitness, walking and cycling.'},
#  {'id': 'B0B8TYRD53',
#   'text': 'Intel Core i9 (12th Gen) i9-12900KS Hexadeca-core (16 Core) 2.50 GHz Processor 14 MB L2 + 30 MB L3 cache memory provides excellent hit rate in short access time enabling improved system performance Built-in Intel UHD Graphics 770 controller for great graphics and visual quality'},
#  {'id': 'B0B4RYF7BD',
#   'text': '3 Pack Silicone Bands Compatible with Fitbit Inspire 2 Bands for Women Men, Adjustable Replacement Sport Wristbands Straps for Fitbit Inspire 2 / Ace 3 (Black/Navy Blue/Wine Red) Mugust Replacement Sport Bands Only for Fitbit Inspire 2 / Ace 3 Health & Fitness Tracker. NOTICE: Not for Fitbit Inspire HR & Fitbit Inspire & Fitbit Ace 2, the fitness tracker is not included! Replacement Bands for Fitbit Inspire 2 is made of flexible elastomer Silicone material. Sweat resistant, lightweight and easy to clean. Durable premium material can prevent skin from irritation. Very soft and comfortable to wear. Unique Colors Available & Free Size: Fitbit inspire 2 bands free size for 5.1" - 8.1" (130mm-205mm) wrist. Mugust Unique Colors Rose Gold, Champagne Gold, Silver, Glistening Rose Gold, Glistening Champagne Gold colors available for your Inspire 2 bands, which can personalize your fitness tracker to fit your mood and outfits in daily life. Multipack bands can also be mixed wearing, and create your own unique style. The buckle of Mugust Fitbit inspire 2 bands are made of Stainless Steel, simple to install and remove, perfectly fit as original band. Besides, there is a notch under the ring, which can double hold your band securely in place and secure the extra length of Fitbit Inspire 2 Bands. After-Sales Service: Any question about Mugust fitbit inspire 2 bands, please contact us via "contact seller" by email at any time. Free replacement or full refund for any quality-related issues. Fast response and immediate action within 12 hours.'},
#  {'id': 'B0B93BK6JQ',
#   'text': 'TumpCez 5 Pack Solo\xa0Loop Nylon Band Compatible With Xiaomi Mi Band 7 6 5 4 3/Amazfit Band 5, Adjustable Breathable Comfortable Elastic Sport Replacement Strap for Women Men Compatible models: TumpCez elastic band is compatible with Xiaomi Mi Band 7 6 5 4 3/Amazfit band 5, suitable for people of all ages , it is the best gift for family and friends. Breathable and Comfortable Nylon Material: Breathable band is made of high-quality nylon material, which is soft, durable and washable. Comfortable band is skin-friendly and ideal for hot summer sports, making it the best partner for summer sports. Easy to install : Sport band with adjustable size design, allowing you to install and adjust the size manually without any tools. The suitable wrist size is 6.69in-10.63in (170mm-270mm), you can choose according to your wrist size. Multiple Choices: The 5-pack fashion watch bands are available in a variety of colors to suit your various outfits and occasions, giving you the perfect wearing experience. Premium Service: Our product in case of defect or any quality problem, please feel free to contact us, we will refund or replace for free without any conditions. If you have any questions about our products, please feel free to contact us, we will solve all your problems within 24 hours.'},
#  {'id': 'B0B8QV4DTS',
#   'text': 'ARMIDO Wireless WiFi PTZ 1080p Light Socket Bulb Security Camera Floodlight Night Vision Motion Detection Two-Way Audio 2.4Ghz and 5Ghz Support '},
#  {'id': 'B09TZPTR9N',
#   'text': "CoStySee Headphone Stand for Airpods Max with Auto-Sleep Mode Aluminum Sleep Holder with Anti-Slip Base and U-Shaped Silicone Headrest for Airpods Max (Rose Gold) 【ALUMINUM ALLOY MATERIAL】CoStySee sleep stand is made of aluminum alloy to avoid rust and deformation of the stand, and the surface is frosted and oxidized to prevent fingerprint and stains. The headband is made of silicone material and U-shaped design to avoid direct contact between the headphone part and the bracket to cause scratches. Simple design brings a more advanced visual experience 【SUPPORT DISCONNECT BLUETOOTH CONNECTION MODE】The headphone stand supports Bluetooth disconnect mode, it adds a magnetic silicone pad on the support bar , when you put airpods max on the stand, it can automatically disconnect the bluetooth, activate the sleep function, and reduce battery consumption. Note: Bluetooth Disconnect Mode is Only Available for Airpods Max 【STURDY AND STABLE HEADPHONE STAND】The headphone stand base is hand-polished with 3mm thick weighted aluminum alloy, very flat, don't worry about the base warping, and the anti-slip sponge on the bottom can also prevent the stand from moving when you pick up the headset. The headphone stand aluminum solid center rod is hand-polished and polished to perfectly match the base and will never bend or tilt 【SUITABLE FOR MOST HEADPHONES/SCENES】This headphone stand is suitable for most headphones with a head width within 2.5 inches (6cm), the simple and stylish design matches your headphones perfectly, allowing you to store and collect them easily. Ideal for computer desks, offices, studios, home work areas, bedrooms, headphone stores, etc 【ALL-ALUMINUM MATERIAL & QUALITY ASSURANCE】CoStySee focus on high quality products and worry-free service! The headphone stand is made of aluminum all over, sturdy and durable, no part of it is cheap plastic! After ordering, you will get 60 days return and 12 months warranty. If you have any questions or suggestions, please contact us promptly,We will reply within 12 hours"},
#  {'id': 'B0B45TXPPJ',
#   'text': 'AZMKIMI Universal Remote Replacement for Roku Player 1 2 3 4 Premiere/+ Express/+ Ultra with 9 More Learning Keys Programmed to Control TV/Soundbar/Receiver (NOT for Any Ro-ku Stick or Ro-ku TV) ★COMPATIBILITY---AZMKIMI universal replacement remote control compatible with Roku player 1, 2, 3, 4, Express, Express+, Premier, Premier+, Ultra (for keys Power, Mute, Vol+/-, Source, CH+/-). ★EASY TO USE---This universal replacement remote control compatible with Roku remote control including shortcut app keys, simplify your life. ★ONE FOR ALL REMOTE----There are 9 programmable buttons easy to program (Power, vol+/-, mute, A&B self-determined buttons). You can use the learning feature to fully customise this remote, by learning functions directly from your original remote control your devices all in one. You can set up it easily with the instruction. ★KINDLY NOTICE---Not for Roku stick or built-in Roku smart TV. Without earphone jack, pairing button, voice search and game. NOT a RF remote or a Wi-Fi remote. ★No program or setup need for the Remote Control. Just install new 2AAA Alkaline batteries to get it work!'},
#  {'id': 'B09WDFDG7Z',
#   'text': 'Twozoh Right Angled Micro HDMI to HDMI Adapter Cable, Nylon Braided 90°Degree Micro HDMI Male to HDMI Female Cable (Type D to Type A) Support 4K/60Hz 1080p (0.6FT) [Cable Length ] Micro HDMI to HDMI Adapter 8 inch (20cm). [NOTE] This HDMI Cable is Micro HDMI to HDMI Female (Type D Male to Type A Female), please confirm it is Micro HDMI port on your device. Not for Android phone & iPhone!!!!!!!!!!! [High Speed]: High-speed Micro HDMI to HDMI cable, D to A type, Meets the latest HDMI standards (4K Video at 60 Hz, 2160p, 48 bit/px color depth) that supports bandwidth up to 18Gbps and backwards compatible with earlier versions. [Ultra-Durable] Gold-Plated Connectors ensure stable and reliable signal transmission; Fol & Nylon braided shielding can reduce Electromagnetic Interference. [Wide Compatibility]This Micro HDMI to HDMI adapter is compatible with GoPro Hero 7 Black, Hero 6 Hero5, Hero 4 Silver, Hero 3 White, Hero3+, Go Pro Hero 2018, Raspberry Pi 4, Sony A5000 handycam, Sony A6500 A6000 A6400 A73 A7S camera, Nikon b500, Canon EOS M50'},
#  {'id': 'B09Y5P41L8',
#   'text': "LopBast Screen 100INCH Manual Pull Down White Projector Screen 16:9 1.2 Gain Retractable Auto-Locking 4K 8K 3D Ultra HD for Home Theater Movie Office Game Projection Screen with Slow Retract Mechanism 【High Quality Material】 Metal housing design, can effectively prevent damage and deformation during transportation. The projector screen uses a composite fabric of multiple layers, make the surface smoother and flatter, fully black backed to eliminate light penetration, has excellent projection quality. 【Manual Self-Locking Device】 Use manual self-locking design, can pull down to lock the screen to the specified position exactly. The slow retract mechanism uses high-purity lubricating oil and sealed dust-proof structure, long-lasting durability. 【Visual Enjoyment】 The matte process of the screen makes the light reflected evenly and resists the interference of ambient light. A gain of 1.2 provides a brighter image. 100 inch, 160° panoramic viewing angle and 16:9 field of view, let you and your family enjoy a high-quality movie viewing experience. Screen supports 1080p, 4K and Full HD images. 【Use and Care】 You can easily install it on walls and ceilings or anywhere in your home. The material of the screen is not easy to get wet and moldy, edge is made by a special process, does not roll or warp over time. The projection screen is easy to clean with water. 【Use in multiple scenarios】 This portable projection screen is suitable for every scene. Home, school, office, church, classroom, backyard; on any venues: speeches, conferences, weddings, parties; suitable for any entertainment activity: sporting events, movies, games, etc., it's definitely your best choice."},
#  {'id': 'B0899NYH3J',
#   'text': "ACdream Case for All-New Fire HD 8 & 8 Plus Tablet (12th Generation/10th Gen, 2022/2020 Release), Folio Leather Cover, Folding Stand, Auto Wake Sleep, Hand Strap, Card Slots, Black EXACT FIT: Our Fire HD 8 tablet case was designed and manufactured to be the precise fit ONLY for Amazon All-New Fire HD 8 & 8 Plus (12th Generation/10th Generation, 2022/2020 Release). The Kindle Fire case will NOT fit older Kindle Fire generations. The precise fit of this Fire 8 tablet case ensures that all buttons and ports are accessible and the camera lens is not obstructed. NOTE: Before ordering this tablet case please make sure that your Kindle Fire model is correct. STRONG PROTECTION: Does your Amazon Fire tablet need a case that will protect it and make the device look better? We have just what you're looking for. The Fire tablet cases are made with high-quality PU leather that will keep your tablet safe from scratches and other damage. Our Fire tablet 8 case will keep your Kindle Fire device safe and sound for years. This lightweight Kindle Fire 8 case is the perfect way to protect your device without adding bulk. STUNNING DESIGN: This Fire Tablet case has a beautiful design that is both functional and fashionable. Our Amazon Fire tablet case is the perfect way to show off your device's sleek style! With its upscale look and unique design, this Fire HD 8 case is perfect for any occasion. The quality of the PU leather material gives Kindle Fire hd 8 plus cover a luxurious feel! With multiple colors of tablet cover available, you'll be able to show off your individuality! SMART FEATURES: With a magnetic strip built-in, our Amazon Fire 8 tablet case automatically wakes up or goes to sleep when the lid is opened or closed. Two card pockets on the inside of our Kindle Fire HD 8 case, are ideal for storing credit cards or cash. The Amazon tablet case comes with an extra hand strap, so you can hold onto it easier. Our Amazon Fire HD 8 tablet case has a handy pen holder, so you can securely store your stylus or pen in there, for faster access. SECURE STAND: The Amazon Fire tablet 8 case has a built-in adjustable flip stand. Our Fire HD 8 plus cover lets you angle your screen to make typing or watching videos more comfortable. This Amazon Fire HD 8 case can be flipped to type with two hands by simply using the built-in stand. The Fire 8 case is great for watching videos on your tablet. Kindle Fire cover will keep the screen upright and stable, on any exterior!"},
#  {'id': 'B0B4T696W5',
#   'text': 'Intel AX210 IEEE 802.11ax Bluetooth 5.2 Tri Band Wi-Fi/Bluetooth Combo Adapter for Notebook 【Wi-Fi 6E】With Intel Wi-Fi 6E technology network adapter provides strong performance and good compatibility, while reducing power consumption and improving service life. 【AX210 NGW Wireless LAN Card】Provides tri-band (6GHz, 5GHz and 2.4GHz) signal. Maximum speed up to 5374Mbps(2400Mbps @6GHz + 2400Mbps @5GHz + 574Mbps @2.4GHz). 【Bluetooth 5.3】Based on Bluetooth 5.2, Bluetooth 5.3 adds LE enhanced connection/Host set Controller key length function/LE channel hierarchy function. Make Bluetooth 5.3 lower latency, stronger anti-interference, improve battery life. 【Installation Requirements】For motherboards with Intel CPU and M2 network slot, NGFF M2 2230 A/E key. 【Compatible System】Support Windows 11/10 64-bit, WiFi and Bluetooth drivers need to be installed on the running PC (search "AX210NGW" from Intel website to download and install wifi and Bluetooth drivers). 【Warranty】We provide one year warranty and lifetime technical support for AX210 WIFI card.'},
#  {'id': 'B0C3ZQ7KHJ',
#   'text': 'Bluetooth Headphones Wireless Earbuds 90H Playtime with 2200mAh Charging Case Dual Power Display Ear Buds Waterproof Over Ear Earphones with Earhooks for Sport Workout Laptop TV Computer Phone Black 90Hrs Long Lasting Battery with 2200mAh Charging Case: Bluetooth headphones are equipped with a 75mAh battery to get 10 hours of music from a single charge of the workout earbuds. Add an extra 8 full recharges up to 90 hours of listening time combined with the included charging case. More than 2 hours playtime with a 15-minute quick charge on the go, so you can keep your music going with no interruptions at all. (10-12hrs in buds with 60%-80% volume) Dual LED Digital Display: Wireless earbuds with digital screen show the remaining power of the charging case by the left number and the charging status of the ear buds by the right LED light bar, which can intuitively reflect real time power to ensure timely charging and embody the sense of technology. The case presents its battery levels from 1 to 100. Once earphones are placed back into the charging case, which will begin to charge, and stop flashing until fully charged. Immersive Stereo Sound & Crystal Clear Calls: Wireless headphones features an 11mm speaker with dual-chamber acoustic drivers for bass and crisp stereo sound that will immerse you in your music and give you a private concert listening experience. The built-in dual beam forming microphone target your voice and filter partial noise, which allowing you to catch every word of the call and have a great conversation without take the earbuds wireless bluetooth off. One-step Pairing & Dual Button Control: Bluetooth earbuds are easy and fast to pair with your device by opening the charging case and taking earbuds out. Ear phones compatible with mobile phones and any devices with Bluetooth-enabled. Multi-functional physical and volume control button are sturdy and responsive, no worry of accidental touching. Bluetooth connectivity can be maintained within 30 feet which can free your hands to easily control audio play and calls without operating your phone. Designed for Sports & IPX7 Sweatproof: Headphones wireless bluetooth are ergonomically designed with flexible earhooks and three different sizes of silicone eartips so that wireless earphones can fit your ears comfortably. No need to worry about shifting or falling out, they will stay in place even when doing exercise. IPX7 sweatproof can effectively resist sweat and rain without worrying about damaging the ear buds perfect for your workout, gym or running. The charging case is not waterproof. Support Wireless & Type-C Charging: The charging case for wireless headphones bluetooth supports wireless and Type-C charging, which make charging more convenient. Wireless charging gets rid of the cable and simply keeps the LED display facing up on top of any Qi-certified charging mat (not included). Type-C charging just use the included USB-C cable and a charging adapter (not included) to charge. Fully charge the charging case takes 3 hours via Type-C cable or about 6 hours via charging mat.'},
#  {'id': 'B0BQGWMZ53',
#   'text': 'Heymell 150W 2.0ch Soundbar for TV, 3D Surround Sound Bars for TV, 6X Speakers Bluetooth Soundbar Built in Subwoofer, Clear Sound No Noise TV Speakers Sound Bar HDMI ARC Optical AUX Voyage201 Better Sound: 6x speakers. 2x digital amplifer sound bars for smart tv. Peak Power 150W, 2.0CH TV sound bar. DSP 3D surround sound, TV sound gain technology,strong bass, dialogue Enhance,improve the weak bass and unclear sound of the TV. Provide a better listening experience. Clear Sound: Background Noise Cancelling, ≤1% distorition, no background noise in low volume and quiet environment. Dialogue Enhance, get clear and loud dialogue for watch TV. Easy Use: Support HDMI-CEC & HDMI ARC, get uncompressed audio signal. Via bluetooth 5.0, or wired connection with Optical / Aux cable (included), HDMI (ARC) / Coaxial cable (not included) , works with smart TV, projector, computer / laptop, DVD player, game consoles, etc. 8 Sound Modes: 4 auto contains Music, Movie, News (dialogue program such as news / talk show) , game. 4 Manual for "Bass+ /-" and "Treble +/- to". Various sound mode suits for different occasions, get a different listening experience. Service: Size- L913.5 x W91.24 x H69.24mm / L35.9 x W3.59 x H2.72 inch.The audio output format of TV must be set to be "PCM". 2 AAA batteries required for remote control (sold separately). We offer timely technical support and feedback within 24 hours. Please download the user manual and troubleshooting in the prouduct link where is "Product guides and documents".'},
#  {'id': 'B09XTS6YYW',
#   'text': 'COO Case for iPad 9th Generation/8th Gen/7th Gen/iPad Air 3rd Generation/iPad Pro 10.5” with Pencil Holder, PU Leather Case for iPad 10.2”/ 10.5”, Trifold Stand Cover with Auto Sleep/Wake (Blue) 【Compatibility】This case is designed for iPad 10.2” 9th Generation 2021 (Model: A2602/ A2603/ A2604/ A2605), iPad 10.2” 8th Gen 2020 (Model: A2270/A2428/A2429), iPad 10.2” 7th Gen 2019 (Model: A2197/A2198/A2200), iPad Air 3rd Generation 2019 (Model: A2152/A2123/A2153), iPad Pro 10.5” 2017 (Model: A1701/A1709 ). 【Suitable Viewing Angles】 Tri-fold stand cover provides suitable angles for viewing and typing, free your hands when watching videos or movies. It is slim, lightweight, and will not add too much weight and space. 【Auto Sleep / Wake】 The magnetic strip in the cover provides auto sleep/wake features. It will auto sleep when you close the cover and auto wake when you open it, helping you save at least 5 percent electric quantity. 【Built-in Apple Pencil Holder】 This case is designed with an apple pencil holder, convenient to place and remove, preventing it from rolling and losing. The precise cutouts allow full access to all of the ports and features. 【Full Protection】 Made of premium PU leather and TPU, PU leather surface provide you a comfortable touch feeling and comprehensive protection for your iPad screen, the TPU back cover protects your iPad from drop and scratch.'},
#  {'id': 'B0B2W7QJXT',
#   'text': 'VOFUOE Bone Conduction Bluetooth Headphones, Wireless Open-Ear Headphones with Microphone, Sports Headset IPX5 Sweatproof Earphones for Outdoor, Running, Cycling, Driving, Hiking, Gym-Pink 【Bone Conduction Bluetooth Earphones】VOFUOE Bluetooth headphonesuse advanced bone conduction technology to transmit audio through the cheekbones to maximize sound fidelity, delivering balanced audio, optimal volume and rich bass. 【Open-Ear Comfort】The open ear Headphones helps you achieve the true painless and harmless as the earphone is no need to plug into the ear canal. Comfortable to wear all day, avoid prolonged high-pitched stimulation of the cochlea, and maintain healthy hearing. More comfortable and safer than traditional earbuds and headphones. 【Upgrade Bluetooth 5.0 & HD Microphone】 Bluetooth headset adopts an upgraded Bluetooth 5.0 device for fast and stable connection. Support a variety of Bluetooth compatible devices.The bone conduction Bluetooth headset has a built-in HD microphone, which intelligently cancels background noise and enables clear calls even in noisy environments. 【Perfect Sports Headphones】The open ear design allows you to pay attention to the surrounding environment while wearing the headset, making it safer to use. IPX5 sweat and moisture resistance, can also be worn in rainy days. Great for outdoor sports, running, cycling, gym and driving etc. 【Long battery life & perfect fit】The bluetooth headset battery has a protective plate, which can better protect the battery life. 180mAh capacity battery, can listen to music continuously for 4-6 hours. The memory titanium alloy skeleton can be twisted arbitrarily in 360 degrees, and it can be adapted according to different head shapes and fit perfectly. Multifunction button to easy control play, pause, skip and answer calls.'},
#  {'id': 'B09XKDCJSV',
#   'text': "Unipows Bluetooth Keyboard Compatible with Mac OS, Ultra Slim Wireless Keyboard for Mac OS/iOS/iPad OS Rechargeable Keyboard for MacBook, MacBook Air/Pro iMac, iPhone, iPad Pro (Silver White) Wireless Keyboard for Mac - Fully compatible with MacBook, MacBook Air, Macbook Pro, iMac, and iMac Pro, meeting Apple users' expectations. NOTE: This model is not compatible with Mac mini. Easy Bluetooth Connection - The wireless key board is easy to set and connect to Mac devices. Automatically connects to your last-connected device. Built-in Rechargeable Battery - Long battery life, powering your keyboard for a long time. Precise Light Touch Typing - Non-slip pad backside and low-profile silent keys improve typing experience. Scissor design beneath each key allows increasing stability. Slim Design - With compact look, this wireless keyboard is portable and lightweight. Ergonomic design helps reduce hand fatigue."},
#  {'id': 'B0C2BV9PB1',
#   'text': 'LP&No.1 Bluetooth Vinyl Record Player with External Speakers, 3-Speed Belt-Drive Turntable for Vinyl Albums with Auto Off and Bluetooth Input，Red Wood … 【3-Speed Belt Drive Turntable】 The diamond-tipped stylus plays all of 33 1/3, 45, and 86 RPMs records. Auto-stop setting makes it possible to stop automatically when it reaches the end of the record 【Stereo Turntable with Outstanding Sound】Equipped with a separable pair of speakers, let you enjoy the full,real and live vinyl audio in dual speakers easily.The volume is loud enough for many occasions 【Modern Record Player with Bluetooth】Great record player as well as ability to work as a Bluetooth speaker.Turn to BT on your phone and hook up to any Bluetooth device easily for premium sound 【Quality Vinyl Player and Speaker Set】Dual Bookshelf speakers allows for multiple placement options. You can make the speakers as a powerful sound base, or place it as a bookshelf or record shelf 【Vintage Audio Turntable Record Player】The audio turntable with solid wood appearance comes with a protective dust cover,and you can remove the lid or close it while the record is playing'},
#  {'id': 'B0BWFJGXM2',
# ...
#  {'id': 'B09TF3H8ZQ',
#   'text': 'Compatible for MorePro HM08 Screen Protector, [6 Pack] Lamshaw Premium High Definition Ultra HD Film Compatible for MorePro HM08 Fitness Tracker Smartwatch/FITVII HM08 / Mgaolo H91 Watch (6 Pack) *SOFT PROTECTOR for HM08 Fitness Tracker Screen Protector 1.69", you must make sure your watch model number is same before buying *The protector has 3 layers. Firstly, pls peel off the Red "Back 1" layer, then put the protector to screen, finally peel of Black "Front 2" layer, Leave the Middle layer on the screen. The middle layer is stickier to the side of "Back 1", some customers peel "Front 2" firstly in fact, and the side to "Front 2” is not sticky. If you meet this situation, please wrinkle the Red "Back 1", separate it to two layers, peel off the middle layer, let it go back to Black "Front 1", then install to screen *BUBBLE SELF-HEALING: Please use the card to push when installing, please refer to the installation diagram. Please use the card to push until the bubbles disappear. if buble is big, you need remove the protector and stick it again; *ANTI-SHATTER & ANTI SCRATCH, HIGH TRANSPARENCY & HIGH SENSITIVITY'},
#  {'id': 'B0BKZ2SX5H',
#   'text': 'ROCWARE RC08 Webcam with Microphone, Web Camera for Computer Camera, HD Webcam 1080p 2K Streaming Camera, Auto Focus Web cam with Built-in Mic, High-Performance Speaker, and Easy Plug-and-Play 【5x Faster ToF Auto-Focus web camera】 This webcam uses an upgraded version of ToF auto-focus technology, equipped with laser-assisted focusing and 4x digital zoom function. Compared to other web cam on the market, it only takes 0.2 seconds to focus. In the era of remote meetings, it enables precise distance measurement regardless of the features on the projection surface, allowing your audience to always focus on the main object or character of your content, eliminating unnecessary distractions and ensuring that the video image is always clear and smooth even in low-light conditions. It is ideal for PC video conferencing, Zoom meetings, online courses, webinars, and more. 【Amazing Sound Performance & Equipped with Privacy Protection Cover】 This webcam with microphone has undergone a complete speaker upgrade and is equipped with a high-performance speaker designed with a power of 2W, 82dB, and a coverage radius of up to 16.5 feet. The advanced sound chamber design inspired by air ducts and top audio technology makes the sound clearer and more natural, providing you with excellent sound effects. The audio performance of the RC08 is even better than the built-in speakers of a laptop computer. In addition, the hd webcam is equipped with a physical privacy shutter for the lens, providing individuals and large companies with added security and peace of mind. 【Built-in Stereo Microphone & Echo Cancellation Noise Reduction Technology】This webcam for streaming is equipped with a built-in microphone and special noise reduction and gain processing technology that solves the problem of noise in two-way communication environments. It can automatically capture your voice and filter out background noise, making it easier for your audience to hear and understand you. The Sound 3A Algorithm MIC (AEC/AGC/ANS) provides high-definition sound quality, and can easily be used for medium-sized conference tables. It is suitable for many fields such as online teaching, video calls, network calls, portrait collection, and live streaming. 【2K sensor and Full HD 1080P resolution real-time video】 The ROCWARE RC08 1080p webcam is a 3-in-1 smart streaming camera that is perfect for ZOOM camera conferences. It uses 2K 1080P Full HD resolution, 1/2.8-inch CMOS image sensor, 30fps image encoding speed, and 2.07 million effective pixels to capture your actions in real-time without delay. Its 90° wide-angle view can better capture people and surroundings, and the pc camera also supports one-button switch to portrait mode for a richer detail experience during vertical live streaming. It is ideal for professional fields such as ZOOM video conferences, social videos, game videos, live streaming, and more while working from home. 【Plug-and-Play and Widely Compatible USB Webcam】 This computer webcam supports fast USB 2.0 and 3.0 connections and is compatible with laptops, desktops, Macs, PCs, and LCD monitors without the need for additional drivers or software downloads. It can also be used with various operating systems, including Windows XP (SP2/SP3), Windows Vista/7/8/10, and Mac OS, among others. You can use it for Skype video conferences, video calls, YouTube recording, Xbox One, Hangouts, and more. The convenient mounting clip allows for easy installation on any display, laptop, TV, or tripod. ROCWARE provides 24 months of customer service to ensure satisfactory resolution of any issues with the web camera.'},
#  {'id': 'B09W9JMJ3L',
#   'text': 'Samsung Galaxy Tab A8 Case 10.5 Inch 2022 SM-X200/X205/X207 with Tempered Glass Screen Protector | Blosomeet Kids Case for Galaxy Tab A8 w/S Pen Holder Stand Hand Strap &Shoulder Strap | Black ☃▶Drop Proof Case for Samsung Galaxy Tab A8 2022◀ Just Compatible with 10.5 Inch Galaxy Tab A8 2022 Release with Model Number of SM-X200/X205/X207. It is NOT compatible with any other tablet. Please check the model number of your tablet model before purchase. ☃▶Tempered Glass Screen Protector◀ Comes with a 10.5 inch tempered glass screen protector, which made with high quality scratch-proof 0.33mm thick premium tempered glass ,high-response and high-transparency and can be used perfectly with S Pen.Your Samsung Tablet A8 10.5 Inch will get the full coverage. ☃▶360° Rotating Stand & Hand Strap◀ Rotatable kickstand allows multi-angle viewing, pretty easy for movie watching and kids learning on the go. Soft rotating handle strap prevents falling of Galaxy Tab A8, featuring convenient use for teachers, students, waiters, doctors, nurses and conference presenters. ☃▶Removable Shoulder Strap◀ Attach the strap to any two corner holes of this Samsung Galaxy Tab A8 Case and it will allow you to display your Tablet behind car head rest for easy personal viewing or between two seats for shared viewing. It is also a unique design for kids walking/travelling, architecture designers, real estate agents, construction workers as well as outdoor labor. ☃▶Pencil Holder◀ This advanced four-layer drop protection nonslip 2022 Samsung A8 10.5 Inch is combined of high-grade polycarbonate hard shell and soft silicone cover, which provides full body protection from accidental drop, bump and shock. Precise cut and design allow easy access to all ports sensors speakers cameras and all other functions.And the pencil holder can hold your pencil in place tightly to avoid falling out while walking. (The Pencil is NOT Included)'},
#  {'id': 'B09PV64F8J',
#   'text': 'HCMOUNTING Heavy Duty Long Dual Arm TV Wall Mount Holds up to 179 lbs, Swivel and Tilt TV Mount with 40.9" Extended Articulating Arms for Most 42-90 inch TVs, VESA 800x400mm, Fits 16\'\'-18\'\' Wood Studs 40.9 INCH EXTENSION TV WALL MOUNT: The extra long extension tv wall mount can retract 2.75" from the wall and extend 40.9" from the wall to cover more viewing positions. It is an ideal choice for corner placement / built-in cabinet let your home more tidy and wide. HEAVY DUTY TV WALL MOUNT: This strong full motion tv wall mount fits most 42"-90" flat/curved LCD LED OLED TVs, VESA patterns from 200x200mm up to 800x400mm, holding up to 179lbs. Six-arm construction is more sturdy and can make the large TVs safer to mount on the wall. FULL MOTION TV WALL MOUNT: This tv wall mount truly swivels and tilts effortlessly. With up to 10° of tilt forward, 10° backward, and swivel 180° left and right, level 3° up and down. EASY TO INSTALL: This long arm full motion tv wall mount comes with all necessary screws and detailed instruction that is simple to install (especially for a non-technical person), only 30 mins to install this tv wall mount on 16\'\' or 18" wood studs or concrete/brick wall. Please DO NOT install it on drywall alone. BEST AFTER-SALES SERVICE: As an enterprise focusing on TV wall mount brackets design innovation and production for 10 years, we have a professional after-sale team to offer you total solutions daily. If you have any questions, please feel free to contact us.'},
#  {'id': 'B09QPQRZCZ',
#   'text': '2 Pcs Pink Rose Gold Birthday Party Supplies Happy Birthday Backdrop Floral Banner Rose Gold Plastic Tablecloth Table Cover for Photoshoot for Girls Women Package Includes: you will get 1 piece of rose gold happy birthday backdrop, measured about 150 x 100 cm/ 59 x 39.4 inches, 1 white gold tablecloth, approx. 273 x 137 cm/ 107.5 x 54 inches, large size for you to decorate your party, they are nice supplements for your rose gold themed parties or floral themed parties, which will make your party more beautiful and attractive Reliable Material: the floral happy birthday backdrop is made of vinyl, and the disposable rectangular tablecloth is made of plastic material, both of them are sturdy and reliable to use, without unpleasant smell, besides, the backdrop banner can be washed and not easy to wrinkle or fade, lightweight and easier to store for the next party Delicate Design: the floral birthday backdrop for girls is printed with different vivid flowers, rose gold glitters confetti and happy birthday text, the plastic disposable tablecloth is decorated with many rose gold dots, the middle part is also printed with many dots, matched with white color, making your dining table and room full of sweet atmosphere, which will make your party charming and romantic Easy to Use: the plastic rose gold tablecloth and happy birthday backdrop for women are easy to use, the table cover will nicely fit your rectangular tables, it is disposable that when you use it, you do not need to take much time to clean your table, just throw it in the garbage can with the trash; The banner can be hung on windows, walls, yards and more, can be applied as photo background, wall decor, curtain, cake table decoration and so on Widely Applicable: the floral rose gold birthday photo backdrop and rose gold polka dot table cloth will be nicely integrated with your other themed party decoration supplies, can widely applied in weddings, bridal showers, garden tea parties, hen parties, baby showers, gender reveal parties, birthday parties and more, which will leave unforgettable memories in the hearts of guests'},
#  {'id': 'B09BCFY3F2',
#   'text': "BAGSMART Travel Laptop Backpack, Quilted Work Bookbag Fits 15.6 Inch Laptop, Laptop Backpack with Charging Port Hole, Lightweight Bookbag for College Work Business, Classic Black Quilted Fabrication: This functional collage backpack features a slouchy silhouette and quilted fabrication. It's lightweight yet durable and comes in a variety of colorful patterns. Versatile and made to carry-it-all, this bookbag can be toted to and from collage, taken on a hike, or thrown on before commuting. Smart Internal Organization: The laptop backpack has a spacious main compartment to hold all your daily essentials. Featuring plenty of organizational pockets, it will help you pack more efficiently while keeping the contents of your bag organized. Unparalleled Carrying Comfort: Its lightweight body (600g) is structured with contoured and padded shoulder straps for excellent fit and an air mesh back panel for ventilation, ensuring all-day comfort. Machine Washable Fabric: The back pack is made of sleek & lightweight quilted cotton. These solid colors bring style & function to your everyday life, allowing for a spin on a gentle cycle in the washing machine. Close at Hand, Far from Pickpockets: Keep pickpockets at bay by storing your valuables in the anti-theft pocket at the back. It's thoughtfully designed for stowing your wallet, passport, and other necessities. THIS ITEM IS NOT INTENDED FOR USE BY CHILDREN 12 AND UNDER"},
#  {'id': 'B09V24G4F8',
#   'text': 'Flat Plug Extension Cord 15 Ft, TESSAN Surge Protector Power Strip with 6 Outlets and 3 USB Ports, 1700 Joules, Desktop Black Long Power Cord for Indoor Home Office School Dorm Room Essential 15ft Flat Extension Cord: The long power strip 15 ft cord flexibly provides sufficient cord length to cover your outlets to reach the remote places such as living room, office; 45° degree convenient space-saving low profile flat head fits in tight spaces like behind furniture, bookshelves, desks or anything Multiple Safety Protection: This power strip surge protector built-in 1700 joules protection reliably protects your electrical appliances from lightning, power surges, and spikes; An integrated circuit breaker enables you to trip off automatically when your rated power exceeds 1625W to make this outlet strip from circuit overload Extension Cord with Multiple Outlets: 6 widely spaced AC outlets are separated enough to fit big plugs and have 3 USB ports that could charge up to 9 electrical devices simultaneously without blocking each other; Could be as a desktop power strip to make your various needs USB Charging Station: This power strip with USB has 3 USB charging ports, provides 5V 2.4A max each port, 3A 15W in total; Could charge for all your required USB devices, such as cellphone, laptop, tablet, camera, etc Suitable for Any Occasions: Our convenient multiple outlet power hub is suitable for the office, bedroom, living room, and college dorm room'},
#  {'id': 'B096BND451',
#   'text': 'iPhone Charger Lightning Cable 3Pack Quick Charger Rapid Cord Apple MFi Certified Compatible iPhone 11 Pro X XR XS MAX 8 Plus 7 6s 5s 5c Air Mini iPod '},
#  {'id': 'B0B64X77P7',
#   'text': '4 in 1 Ethernet Adapter and 3 Ports USB OTG Hub for Fire TV Stick 4K/Chromecast/Google Home Mini/Raspberry Pi Zero and Other Streaming TV Sticks,Micro USB OTG Cable HUB with Powered Network Adapter Add extra wired Ethernet & USB 3 ports extra storage to your streaming device for connecting wired network,flash drive,wireless keyboard or whatever USB peripherals,Stable work at the same time.(please note: Not compatible with Fire Stick 1, Roku Stick/Express,Fire HD 10,Google Home Mini cellphones, tablets, and Laptops,USB only for charging.) Support 10/100M wired network Ethernet connection, faster and more stable，and 3 ports (480Mbps) of Simultaneous data transfer possible.no buffering, no lag. 4-in-1 integrated design, no need to combine, the signal transmission is more stable. The length is 3.3 ft. It is easy to operate and allows you to place it anywhere without worrying about loose connections. Plug & Play,no additional driver/software needed. Just need to connect it to an available devices and LAN network, it will be activated. Compatible with Fire TV Stick 4K,Streaming TV Sticks,Google Home Mini, Media Players,Chromecast Ultra / 3 / 2 / 1 / Audio,Raspberry Pi Zero, and Support Micro USB port TV stick,etc.'}]

# %% [markdown]
# ### Render a prompt to generate synthetic Eval reference dataset

# %%
output_schema = {
    "type": "array",
    "items": {
        "type": "object",
        "properties": {
            "question": {
                "type": "string",
                "description": "Suggested question.",
            },
            "chunk_id": {
                "type": "array",
                "description": "IDs of the chunks that could be used to answer the question.",
            },
            "answer_example": {
                "type": "string",
                "description": "Suggested answer grounded in the context.",
            },
            "reasoning": {
                "type": "string",
                "description": "Reasoning why the question could be answered by the chunks.",
            },
        },
    },
}

SYSTEM_PROMPT = f"""
I am building a RAG application. I have a collection of 50 chunks of text.
The RAG application will act as a shopping assistant that can answer questions about the stock of the products we have available.
I will provide all of the available products to you with IDs of each chunk.
I want you to come up with 30 questions to which the answers could be grounded in the chunk context.
The questions should imitate a potential real user of this RAG system.
As an output I need you to provide me the list of questions and the IDs of the chunks that could be used to answer them.
Also, provide an example answer to the question given the context of the chunks
Also, provide the reason why you chose the chunks to answer the questions.
Construct 10 questions that could use multiple chunk in the answer.
Construct 15 questions that could use single chunk in the answer.
Construct 5 questions that cannnot be answered by the available chunks.

<OUTPUT JSON SCHEMA>
{json.dumps(output_schema, indent=2)}
</OUTPUT JSON SCHEMA>

I need to be able to parse the json output.
"""

USER_PROMPT =f"""
Here is the list of chunks, each list element is a dictionary with id and text fields:
{all_context}
"""

# %%
print(SYSTEM_PROMPT)
# Out:
# I am building a RAG application. I have a collection of 50 chunks of text.
# The RAG application will act as a shopping assistant that can answer questions about the stock of the products we have available.
# I will provide all of the available products to you with IDs of each chunk.
# I want you to come up with 30 questions to which the answers could be grounded in the chunk context.
# The questions should imitate a potential real user of this RAG system.
# As an output I need you to provide me the list of questions and the IDs of the chunks that could be used to answer them.
# Also, provide an example answer to the question given the context of the chunks
# Also, provide the reason why you chose the chunks to answer the questions.
# Construct 10 questions that could use multiple chunk in the answer.
# Construct 15 questions that could use single chunk in the answer.
# Construct 5 questions that cannnot be answered by the available chunks.
#
# <OUTPUT JSON SCHEMA>
# {
#   "type": "array",
#   "items": {
#     "type": "object",
#     "properties": {
#       "question": {
#         "type": "string",
#         "description": "Suggested question."
#       },
#       "chunk_id": {
#         "type": "array",
#         "description": "IDs of the chunks that could be used to answer the question."
#       },
#       "answer_example": {
#         "type": "string",
#         "description": "Suggested answer grounded in the context."
#       },
#       "reasoning": {
#         "type": "string",
#         "description": "Reasoning why the question could be answered by the chunks."
#       }
#     }
#   }
# }
# </OUTPUT JSON SCHEMA>
#
# I need to be able to parse the json output.

# %%
print(USER_PROMPT)
# Out:
# Here is the list of chunks, each list element is a dictionary with id and text fields:
# [{'id': 'B01N1P97SL', 'text': 'BOVKE Travel Carrying Case for Samaung T7 Shield / T7 / T7 Touch Portable SSD 500GB 1TB 2TB USB 3.2 External Solid State Drives, Extra Mesh Pocket for USB Cables and More Accessories, Black Case Only! ( samsung ssd & accessories not included )This external hard drive case perfectly fit for: Samsung T7 Shield Portable SSD, Samsung T7 Portable SSD, Samsung T7 Touch 500GB 1TB 2TB USB 3.2 Portable Solid State Drives, provide excellent protection, keeps the solid state external hard drives safe from damage and prolongs the service life of your T7 external ssd. This samsung t7 case bag is featured with 2 elastic bands inside, securely store the samsung t7 shield portable ssd, and the T7 Carrying Case can prevent the Samsung external ssd from falling, protects your external solid state drives from tossing around while on the go, gives your portable ssd great protection. This T7 shield hard drive carrying case comes with a mesh pocket to accommodate the USB cables of the Samsung T7 Touch Portable SSD drive and other small accessories. The double zippers of the t7 case are smooth enough for easy opening and closing, offer you excellent using experience. This samsung ssd case is made of hard EVA and PU material, with good waterproof and shockproof, protects your samsung portable ssd from extrusion, dust and splashing, Interior velevt lining is ultra soft, provides great protection for your Samsung T7 ssd external hard drive from scratches, bumping and droping. Dimension: 5.42 x 3.01 x 1.21 inches, compact and lightweight, this Samsung T7 shield ssd case holder comes with a sturdy lanyard and a carabiner to provide various ways to carry, the samsung t7 storage case can be put in your pocket or bag, or you can also hang this T7 ssd bag on your backpack, convenient to use.'}, {'id': 'B0B778L1DZ', 'text': 'SunFounder Ultimate Starter Kit Compatible with Arduino UNO IDE Scratch, 3 in 1 IoT/Smart Car/Basic Kit with Online Tutorials, Video Courses, 192 Items, 87 Projects, Suitable for Age 8+ Beginners Expert-Designed Courses: Teaming up with Circuit Basics, SunFounder 3-in-1 Starter Kit offers comprehensive videos and online tutorials for well-rounded learning. Suitable for age 8+ beginners. Complete Component Kit: Our kit includes high quality sensors, actuators, power supplies, and an Arduino-compatible Uno for diverse projects and skill-building. Progressive Learning Journey: With Circuit Basics, the courses cater to your skill level, covering essentials and advancing to complex topics like IoT, robot cars, and sensor integration. Engaging Projects: Apply your knowledge through hands-on projects, ranging from simple LED blinking to advanced robot car, IoT applications, for skill development and confidence-building. Dedicated Support: Benefit from our ongoing assistance, including a community forum and timely technical help for a seamless learning experience.'}, {'id': 'B0B5GPCS2V', 'text': "Gyehuo for Airpod Case, Compatible with Apple AirPods 2nd & 1st Generation Case (Cow) 【Perfectly Fit】 Compatible with Apple AirPods 1st & AirPods 2nd generation case. The AirPods case cover fits tightly without worrying about the AirPod case coming loose or coming off 【360° Full Protection】This AirPods case protective cover made of premium flexible material,protects your AirPods against bumps, drops and scratches 【Fashion Design】The cute AirPods case is protected by a protective PET film. Bright and lovely patterns don't fade with time 【Convenient Charging & Portable Keychain】 Charge your airpods without removing the cover. Comes with a metal Keychain, making it convenient and secure to carry your AirPod 2 & 1 anywhere 【Our Service】The airpod case is returnable in 30 days, please don’t hesitate to contact us if you have any question about our product. We will always offer the best solutions"}, {'id': 'B0BRQRS9BM', 'text': "KNOWSQT Wired Computer Keyboard - Milk Tea Colorful Full-Size Round Keycaps Typewriter Keyboards for W ...

# %%
response = openai.chat.completions.create(
    model="gpt-5-mini",
    messages=[
        {"role": "system", "content": SYSTEM_PROMPT},
        {"role": "user", "content": USER_PROMPT},
    ],
    reasoning_effort="minimal",
)
# Out:
# '[\n  {\n    "question": "Does the BOVKE carrying case fit the Samsung T7 Shield and other T7 models?",\n    "chunk_id": [\n      "B01N1P97SL"\n    ],\n    "answer_example": "Yes. The BOVKE Travel Carrying Case is designed to perfectly fit the Samsung T7 Shield, Samsung T7, and Samsung T7 Touch (500GB/1TB/2TB) portable SSDs and provides interior elastic bands and a mesh pocket for cables.",\n    "reasoning": "Chunk B01N1P97SL explicitly lists compatible Samsung T7 models and describes the case features and fit."\n  },\n  {\n    "question": "What materials and protection does the Samsung T7 carrying case offer?",\n    "chunk_id": [\n      "B01N1P97SL"\n    ],\n    "answer_example": "The case is made of hard EVA and PU material with an ultra-soft velvet interior lining; it\'s waterproof and shockproof to protect the Samsung T7 from extrusion, dust, splashes, scratches, bumps, and drops.",\n    "reasoning": "Chunk B01N1P97SL details the construction materials and protective features of the case."\n  },\n  {\n    "question": "How many items and projects are included in the SunFounder Ultimate Starter Kit?",\n    "chunk_id": [\n      "B0B778L1DZ"\n    ],\n    "answer_example": "The kit includes 192 items and supports 87 projects, along with online tutorials and video courses.",\n    "reasoning": "Chunk B0B778L1DZ lists the total items (192) and projects (87) and mentions tutorials."\n  },\n  {\n    "question": "Is the SunFounder starter kit suitable for young beginners?",\n    "chunk_id": [\n      "B0B778L1DZ"\n    ],\n    "answer_example": "Yes — it’s marked suitable for ages 8+ and designed for beginners with progressive learning resources and expert-designed courses.",\n    "reasoning": "Chunk B0B778L1DZ explicitly states suitability for age 8+ and beginner-focused courses."\n  },\n  {\n    "question": "Will the Gyehuo AirPods cow design case allow charging without removal?",\n    "chunk_id": [\n      "B0B5GPCS2V"\n    ],\n    "answer_example": "Yes. The Gyehuo AirPods case permits charging without removing the cover and includes a metal keychain for portability.",\n    "reasoning": "Chunk B0B5GPCS2V mentions convenient charging without removing the cover and the included keychain."\n  },\n  {\n    "question": "Does the KNOWSQT wired keyboard require drivers to work on Windows?",\n    "chunk_id": [\n      "B0BRQRS9BM"\n    ],\n    "answer_example": "No. It’s a plug-and-play USB wired keyboard and doesn’t require additional software installation for use.",\n    "reasoning": "Chunk B0BRQRS9BM states USB plug-and-play and no software installation needed."\n  },\n  {\n    "question": "Are the BLACKSYNCZE USB-C to Lightning cables MFi certified and what charging speed do they support?",\n    "chunk_id": [\n      "B0BQXLF477"\n    ],\n    "answer_example": "Yes — they are MFi certified with a C94 connector and support 20W PD fast charging, capable of charging an iPhone 12/13 to ~50% in about 30 minutes.",\n    "reasoning": "Chunk B0BQXLF477 specifies MFi certification, C94, and 20W PD fast-charging performance."\n  },\n  {\n    "question": "How many ARGB fans come preinstalled in the KEDIERS C590 PC case?",\n    "chunk_id": [\n      "B0B2JT5B86"\n    ],\n    "answer_example": "The KEDIERS C590 case comes with 9 pre-installed 120mm ARGB fans and an ARGB controller; synchronization requires connecting the 5V-3PIN cable to the motherboard.",\n    "reasoning": "Chunk B0B2JT5B86 describes the 9 pre-installed ARGB fans and synchronization requirement."\n  },\n  {\n    "question": "Can the Blood Glucose Monitor Smart Watch measure blood sugar without blood?",\n    "chunk_id": [\n      "B0CGV9LQB8"\n    ],\n    "answer_example": "Yes. The smartwatch advertises non-invasive blood glucose testing using a built-in blood sugar monitoring chip and algorithm without the need for blood samples.",\n    "reasoning": "Chunk B0CGV9LQB8 clearly states the watch offers non-invasive blood glucose testing."\n  },\n  {\n    "question": "Will the 140W USB-C c ...

# %%
print(response.choices[0].message.content)
# Out:
# [
#   {
#     "question": "Does the BOVKE carrying case fit the Samsung T7 Shield and other T7 models?",
#     "chunk_id": [
#       "B01N1P97SL"
#     ],
#     "answer_example": "Yes. The BOVKE Travel Carrying Case is designed to perfectly fit the Samsung T7 Shield, Samsung T7, and Samsung T7 Touch (500GB/1TB/2TB) portable SSDs and provides interior elastic bands and a mesh pocket for cables.",
#     "reasoning": "Chunk B01N1P97SL explicitly lists compatible Samsung T7 models and describes the case features and fit."
#   },
#   {
#     "question": "What materials and protection does the Samsung T7 carrying case offer?",
#     "chunk_id": [
#       "B01N1P97SL"
#     ],
#     "answer_example": "The case is made of hard EVA and PU material with an ultra-soft velvet interior lining; it's waterproof and shockproof to protect the Samsung T7 from extrusion, dust, splashes, scratches, bumps, and drops.",
#     "reasoning": "Chunk B01N1P97SL details the construction materials and protective features of the case."
#   },
#   {
#     "question": "How many items and projects are included in the SunFounder Ultimate Starter Kit?",
#     "chunk_id": [
#       "B0B778L1DZ"
#     ],
#     "answer_example": "The kit includes 192 items and supports 87 projects, along with online tutorials and video courses.",
#     "reasoning": "Chunk B0B778L1DZ lists the total items (192) and projects (87) and mentions tutorials."
#   },
#   {
#     "question": "Is the SunFounder starter kit suitable for young beginners?",
#     "chunk_id": [
#       "B0B778L1DZ"
#     ],
#     "answer_example": "Yes — it’s marked suitable for ages 8+ and designed for beginners with progressive learning resources and expert-designed courses.",
#     "reasoning": "Chunk B0B778L1DZ explicitly states suitability for age 8+ and beginner-focused courses."
#   },
#   {
#     "question": "Will the Gyehuo AirPods cow design case allow charging without removal?",
#     "chunk_id": [
#       "B0B5GPCS2V"
#     ],
#     "answer_example": "Yes. The Gyehuo AirPods case permits charging without removing the cover and includes a metal keychain for portability.",
#     "reasoning": "Chunk B0B5GPCS2V mentions convenient charging without removing the cover and the included keychain."
#   },
#   {
#     "question": "Does the KNOWSQT wired keyboard require drivers to work on Windows?",
#     "chunk_id": [
#       "B0BRQRS9BM"
#     ],
#     "answer_example": "No. It’s a plug-and-play USB wired keyboard and doesn’t require additional software installation for use.",
#     "reasoning": "Chunk B0BRQRS9BM states USB plug-and-play and no software installation needed."
#   },
#   {
#     "question": "Are the BLACKSYNCZE USB-C to Lightning cables MFi certified and what charging speed do they support?",
#     "chunk_id": [
#       "B0BQXLF477"
#     ],
#     "answer_example": "Yes — they are MFi certified with a C94 connector and support 20W PD fast charging, capable of charging an iPhone 12/13 to ~50% in about 30 minutes.",
#     "reasoning": "Chunk B0BQXLF477 specifies MFi certification, C94, and 20W PD fast-charging performance."
#   },
#   {
#     "question": "How many ARGB fans come preinstalled in the KEDIERS C590 PC case?",
#     "chunk_id": [
#       "B0B2JT5B86"
#     ],
#     "answer_example": "The KEDIERS C590 case comes with 9 pre-installed 120mm ARGB fans and an ARGB controller; synchronization requires connecting the 5V-3PIN cable to the motherboard.",
#     "reasoning": "Chunk B0B2JT5B86 describes the 9 pre-installed ARGB fans and synchronization requirement."
#   },
#   {
#     "question": "Can the Blood Glucose Monitor Smart Watch measure blood sugar without blood?",
#     "chunk_id": [
#       "B0CGV9LQB8"
#     ],
#     "answer_example": "Yes. The smartwatch advertises non-invasive blood glucose testing using a built-in blood sugar monitoring chip and algorithm without the need for blood samples.",
#     "reasoning": "Chunk B0CGV9LQB8 clearly states the watch offers non-invasive blood glucose testing."
#   },
#   {
#     "question": "Will the 140W USB-C charger work with MacBook Pro 16 (2021) and other devices?",
#     "chunk_id": [
#       "B0BKJGRZGP"
#     ],
#     "answer_example": "Yes. The 140W PD 3.1 charger supports MacBook Pro 16\" (2021), MacBook Air/Pro, many Windows laptops, iPads, and phones — negotiating up to various wattages (127W/96W/90W/67W/65W/45W/30W) depending on device.",
#     "reasoning": "Chunk B0BKJGRZGP lists MacBook compatibility and PD 3.1 adaptive outputs and supported devices."
#   },
#   {
#     "question": "Which Dymo label maker models are compatible with the 91338 metallic refill tape?",
#     "chunk_id": [
#       "B08LYX8BZ3"
#     ],
#     "answer_example": "The metallic 12mm x 4m tape (91338 replacement) is compatible with Dymo LT-100H, LT-100T, LT-110T, LT-200B, LT-100H Plus, LT-100T Plus, QX50, XR, XM, and 2000 models.",
#     "reasoning": "Chunk B08LYX8BZ3 enumerates the compatible Dymo label printer models for the tape refill."
#   },
#   {
#     "question": "What is the advertised battery life and driver configuration for the Tronsmart wireless earbuds?",
#     "chunk_id": [
#       "B0B3HYZ427"
#     ],
#     "answer_example": "They use a dual-driver setup (10mm dynamic + balanced armature) and offer about 7 hours from a single charge and up to 32 hours total with the charging case.",
#     "reasoning": "Chunk B0B3HYZ427 describes the dual-driver design and battery/playtime specs."
#   },
#   {
#     "question": "Does the EIGIIS military smartwatch support Bluetooth calling and how many sport modes?",
#     "chunk_id": [
#       "B0CH4ZTTJJ"
#     ],
#     "answer_example": "Yes — it supports Bluetooth calling with a built-in speaker and microphone and offers over 100 sport modes.",
#     "reasoning": "Chunk B0CH4ZTTJJ explicitly lists Bluetooth calling capability and 100+ sport modes."
#   },
#   {
#     "question": "What is the read/write speed rating of the TRIDENITE 256GB NVMe M.2 SSD?",
#     "chunk_id": [
#       "B0B7N2DVRQ"
#     ],
#     "answer_example": "The TRIDENITE 256GB NVMe M.2 (PCIe Gen3x4) SSD lists sequential speeds up to approximately Read 1700 MB/s and Write 1000 MB/s.",
#     "reasoning": "Chunk B0B7N2DVRQ includes the listed CrystalDiskMark sequential read/write speeds."
#   },
#   {
#     "question": "How many USB flash drives and what capacity are included in the Vansuny pack?",
#     "chunk_id": [
#       "B0C1Z4MNJT"
#     ],
#     "answer_example": "The Vansuny pack includes 5 USB 3.0 flash drives, each 64GB capacity, with up to 70 MB/s read speeds.",
#     "reasoning": "Chunk B0C1Z4MNJT specifies 5x 64GB drives and USB 3.0 speeds."
#   },
#   {
#     "question": "Can the EZDIY-FAB 24-pin 90° ATX adapter help with limited-height PC cases?",
#     "chunk_id": [
#       "B0B931CQN2"
#     ],
#     "answer_example": "Yes. The 90° right-angle ATX 24-pin adapter reroutes the PSU cable horizontally, preventing pressure on the motherboard connector and solving PSU installation in limited-height chassis.",
#     "reasoning": "Chunk B0B931CQN2 explains the right-angle design purpose for cramped case installations."
#   },
#   {
#     "question": "Does the 20pcs Magnetic Cable Ties set have magnets and are they reusable?",
#     "chunk_id": [
#       "B0BGRWNKZ1"
#     ],
#     "answer_example": "Yes — each silicone cable tie has two built-in magnets on the ends, is soft/elastic and highly reusable, and can attach to metal surfaces for organization.",
#     "reasoning": "Chunk B0BGRWNKZ1 describes the magnet design, material, and reusability."
#   },
#   {
#     "question": "Are the Ulirath AirPods 3 skeleton cases wireless-charging compatible without removal?",
#     "chunk_id": [
#       "B0BHKMQ7PN"
#     ],
#     "answer_example": "Yes. The ultra-thin TPU skeleton case for AirPods 3 maintains wireless charging compatibility; the package also includes a carabiner for carrying.",
#     "reasoning": "Chunk B0BHKMQ7PN states the thin design doesn't compromise wireless charging and mentions the carabiner."
#   },
#   {
#     "question": "What cores and integrated graphics are in the Intel i9-12900KS?",
#     "chunk_id": [
#       "B0B8TYRD53"
#     ],
#     "answer_example": "The Intel Core i9-12900KS is a 16-core (hexadeca-core) CPU at 2.50 GHz with built-in Intel UHD Graphics 770 and combined on-chip cache (14 MB L2 + 30 MB L3).",
#     "reasoning": "Chunk B0B8TYRD53 lists core count, base frequency, cache, and integrated GPU details."
#   },
#   {
#     "question": "Do the 3-pack silicone bands fit Fitbit Inspire 2 and what's the wrist size range?",
#     "chunk_id": [
#       "B0B4RYF7BD"
#     ],
#     "answer_example": "Yes — these replacement silicone sport bands are made for Fitbit Inspire 2/Ace 3 and fit wrist sizes from approximately 5.1\" to 8.1\" (130mm–205mm).",
#     "reasoning": "Chunk B0B4RYF7BD details compatibility and the wrist size range."
#   },
#   {
#     "question": "Can the ARMIDO WiFi PTZ bulb camera support both 2.4GHz and 5GHz networks?",
#     "chunk_id": [
#       "B0B8QV4DTS"
#     ],
#     "answer_example": "The listing states support for both 2.4GHz and 5GHz Wi-Fi for the ARMIDO Wireless WiFi PTZ 1080p light socket bulb security camera.",
#     "reasoning": "Chunk B0B8QV4DTS includes a short description mentioning 2.4Ghz and 5Ghz support."
#   },
#   {
#     "question": "Does the CoStySee headphone stand auto-sleep AirPods Max when placed on the stand?",
#     "chunk_id": [
#       "B09TZPTR9N"
#     ],
#     "answer_example": "Yes — the CoStySee stand includes a magnetic silicone pad that can trigger Bluetooth disconnect/sleep mode for AirPods Max when placed on the stand (feature is AirPods Max–specific).",
#     "reasoning": "Chunk B09TZPTR9N explains the magnetic pad and Bluetooth disconnect mode specifically for AirPods Max."
#   },
#   {
#     "question": "Will the AZMKIMI universal remote work with a Roku Express stick or Roku TV?",
#     "chunk_id": [
#       "B0B45TXPPJ"
#     ],
#     "answer_example": "No. The AZMKIMI remote is compatible with Roku players (1/2/3/4/Express/Express+/Premier/Premier+/Ultra) but not with Roku sticks or built-in Roku TVs.",
#     "reasoning": "Chunk B0B45TXPPJ explicitly states incompatibility with Roku stick or Roku TV."
#   },
#   {
#     "question": "Is the Twozoh right-angled Micro HDMI adapter suitable for GoPro Hero 7?",
#     "chunk_id": [
#       "B09WDFDG7Z"
#     ],
#     "answer_example": "Yes. The Micro HDMI (Type D) male to HDMI (Type A) female adapter supports devices like the GoPro Hero 7 Black and others that have a Micro HDMI port.",
#     "reasoning": "Chunk B09WDFDG7Z lists GoPro Hero models among compatible devices for Micro HDMI to HDMI."
#   },
#   {
#     "question": "What mounting and viewing angle features does the LopBast 100-inch projector screen offer?",
#     "chunk_id": [
#       "B09Y5P41L8"
#     ],
#     "answer_example": "The LopBast 100\" manual pull-down screen (16:9, 1.2 gain) supports wall or ceiling installation, has a manual self-locking and slow-retract mechanism, 160° viewing angle, and supports 1080p/4K/Full HD projection.",
#     "reasoning": "Chunk B09Y5P41L8 details size, gain, mounting options, locking/retract mechanism, viewing angle, and resolution support."
#   },
#   {
#     "question": "Is the ACdream folio leather case compatible with Fire HD 8 (10th & 12th Gen)?",
#     "chunk_id": [
#       "B0899NYH3J"
#     ],
#     "answer_example": "Yes. ACdream case is an exact fit for Amazon All-New Fire HD 8 & 8 Plus 12th and 10th Generation (2022/2020), providing card slots, hand strap, pen holder, and auto wake/sleep.",
#     "reasoning": "Chunk B0899NYH3J specifies exact compatibility with those Fire HD 8 generations and lists features."
#   },
#   {
#     "question": "What Wi-Fi bands and maximum theoretical throughput does the Intel AX210 adapter support?",
#     "chunk_id": [
#       "B0B4T696W5"
#     ],
#     "answer_example": "The Intel AX210 is a tri-band Wi-Fi 6E adapter (2.4GHz, 5GHz, 6GHz) with combined maximum speeds up to 5374 Mbps (2400 Mbps @6GHz + 2400 Mbps @5GHz + 574 Mbps @2.4GHz) and supports Bluetooth 5.2/5.3 features.",
#     "reasoning": "Chunk B0B4T696W5 lists tri-band operation, the 5374 Mbps aggregated figure, and Bluetooth details."
#   },
#   {
#     "question": "What is the advertised battery runtime and charging features of the Bluetooth earbud set with 2200mAh case?",
#     "chunk_id": [
#       "B0C3ZQ7KHJ"
#     ],
#     "answer_example": "The earbuds offer ~10–12 hours per earbud on a single charge and up to 90 hours total using the 2200mAh charging case; the case supports Type-C and wireless charging and includes a dual LED power display.",
#     "reasoning": "Chunk B0C3ZQ7KHJ outlines playtime per charge, total hours with the charging case, charging methods, and LED display."
#   },
#   {
#     "question": "Can the Heymell 150W soundbar connect to a TV via HDMI ARC and does it support multiple sound modes?",
#     "chunk_id": [
#       "B0BQGWMZ53"
#     ],
#     "answer_example": "Yes. The Heymell 150W soundbar supports HDMI ARC (and Optical/AUX/Bluetooth) and offers 8 sound modes, including auto modes like Music, Movie, News, and Game, plus manual bass/treble adjustments.",
#     "reasoning": "Chunk B0BQGWMZ53 lists HDMI ARC support and enumerates the available sound modes."
#   },
#   {
#     "question": "Is the COO case compatible with iPad 10.2\" 9th generation and does it have an Apple Pencil holder?",
#     "chunk_id": [
#       "B09XTS6YYW"
#     ],
#     "answer_example": "Yes. The COO PU leather trifold case is compatible with iPad 10.2\" 7th/8th/9th gen and iPad Air 3/Pro 10.5, and it includes a built-in Apple Pencil holder and auto sleep/wake feature.",
#     "reasoning": "Chunk B09XTS6YYW lists device compatibility and mentions the pencil holder and auto sleep/wake."
#   },
#   {
#     "question": "Does the VOFUOE bone conduction headset have IPX rating and how long is battery life?",
#     "chunk_id": [
#       "B0B2W7QJXT"
#     ],
#     "answer_example": "Yes — the VOFUOE bone conduction headphones are IPX5 sweat-resistant and offer about 4–6 hours of continuous playback from the 180mAh battery.",
#     "reasoning": "Chunk B0B2W7QJXT provides IPX5 rating and battery runtime information."
#   },
#   {
#     "question": "Is the Unipows Bluetooth keyboard rechargeable and compatible with Mac devices?",
#     "chunk_id": [
#       "B09XKDCJSV"
#     ],
#     "answer_example": "Yes. The Unipows keyboard has a built-in rechargeable battery and is fully compatible with many Mac devices (MacBook, MacBook Air/Pro, iMac), though it notes incompatibility with Mac mini.",
#     "reasoning": "Chunk B09XKDCJSV indicates rechargeable battery and Mac compatibility with a noted exception."
#   },
#   {
#     "question": "Can the LP&No.1 turntable work as a Bluetooth speaker and which record speeds does it play?",
#     "chunk_id": [
#       "B0C2BV9PB1"
#     ],
#     "answer_example": "Yes. This turntable can act as a Bluetooth speaker (Bluetooth input) and plays 33 1/3, 45, and 78 RPM records via its 3-speed belt-drive mechanism and includes separable speakers.",
#     "reasoning": "Chunk B0C2BV9PB1 states Bluetooth functionality and the supported record speeds and speaker configuration."
#   },
#   {
#     "question": "Does the Google Nest Cam store event video if Wi‑Fi is down and is a subscription required for more history?",
#     "chunk_id": [
#       "B0BWFJGXM2"
#     ],
#     "answer_example": "If Wi‑Fi goes down Nest Cam can store up to 1 hour of recorded events locally; it provides 3 hours of free event video history and requires a Nest Aware subscription for extended history (up to 60 days) and advanced features like familiar face alerts.",
#     "reasoning": "Chunk B0BWFJGXM2 covers local storage during outages, free short history, and optional Nest Aware subscription benefits."
#   },
#   {
#     "question": "What are the main features of the Logitech MX Keys bundle?",
#     "chunk_id": [
#       "B083C4FDM8"
#     ],
#     "answer_example": "The bundle includes the Logitech MX Keys advanced wireless illuminated keyboard with spherically dished keys and smart illumination, plus an MX palm rest made of memory foam for long-hours comfort and support.",
#     "reasoning": "Chunk B083C4FDM8 describes both the MX Keys keyboard features and the included palm rest benefits."
#   },
#   {
#     "question": "Does the Devinal RCA Y splitter work for subwoofer connections and is it gold-plated?",
#     "chunk_id": [
#       "B08FZJP2TL"
#     ],
#     "answer_example": "Yes. The Devinal RCA Y splitter is designed for subwoofer/amplifier/home theater use and features gold-plated RCA plugs for improved corrosion resistance and signal transfer.",
#     "reasoning": "Chunk B08FZJP2TL lists use cases including subwoofers and notes gold-plated connectors."
#   },
#   {
#     "question": "Is the Gexmil genuine leather iPad Air case compatible with iPad Air 5 and does it support sleep/wake?",
#     "chunk_id": [
#       "B0B1CS593J"
#     ],
#     "answer_example": "Yes. The Gexmil cowhide folio leather case is made for iPad Air 5th and 4th Gen (10.9\") and supports auto sleep/wake as well as multiple stand angles and precise cutouts.",
#     "reasoning": "Chunk B0B1CS593J specifies compatibility with iPad Air 5/4 and mentions auto sleep/wake and features."
#   },
#   {
#     "question": "Will the ROCWARE RC08 webcam work plug-and-play on older Windows systems like Windows 7?",
#     "chunk_id": [
#       "B0BKZ2SX5H"
#     ],
#     "answer_example": "Yes. The ROCWARE RC08 supports plug-and-play USB connection and claims compatibility with Windows XP (SP2/SP3), Vista, 7, 8, 10 and modern systems without extra drivers.",
#     "reasoning": "Chunk B0BKZ2SX5H lists Windows compatibility down to XP/Vista/7 and describes plug-and-play operation."
#   },
#   {
#     "question": "Is the Samsung Galaxy Tab A8 kids case compatible with the 2022 SM-X200 model and does it include a tempered glass screen protector?",
#     "chunk_id": [
#       "B09W9JMJ3L"
#     ],
#     "answer_example": "Yes. The Blosomeet kids case is compatible with the 10.5\" Galaxy Tab A8 2022 models SM-X200/X205/X207 and includes a tempered glass screen protector, rotating stand, hand strap, shoulder strap, and pencil holder.",
#     "reasoning": "Chunk B09W9JMJ3L identifies model compatibility and the included tempered glass and accessories."
#   },
#   {
#     "question": "Can the HCMOUNTING heavy-duty TV wall mount support a 75-inch TV weighing 150 lbs and what VESA sizes does it fit?",
#     "chunk_id": [
#       "B09PV64F8J"
#     ],
#     "answer_example": "Yes. The HCMOUNTING long dual arm mount supports TVs up to 179 lbs and 42\"–90\" sizes, and fits VESA patterns up to 800x400mm, so a 75\" TV at 150 lbs should be supported if VESA matches and studs are used.",
#     "reasoning": "Chunk B09PV64F8J lists max weight (179 lbs), supported screen sizes and VESA up to 800x400mm, plus installation notes for studs."
#   },
#   {
#     "question": "Are the rose gold birthday backdrop and tablecloth reusable and what sizes are they?",
#     "chunk_id": [
#       "B09QPQRZCZ"
#     ],
#     "answer_example": "The vinyl floral backdrop (about 150 x 100 cm / 59 x 39.4 in) and plastic tablecloth (approx. 273 x 137 cm / 107.5 x 54 in) are described as durable and washable (backdrop washable), though the tablecloth is disposable.",
#     "reasoning": "Chunk B09QPQRZCZ provides dimensions and materials, noting the backdrop is washable and the tablecloth disposable."
#   },
#   {
#     "question": "Is the BAGSMART laptop backpack machine washable and what laptop size does it fit?",
#     "chunk_id": [
#       "B09BCFY3F2"
#     ],
#     "answer_example": "Yes — the BAGSMART quilted laptop backpack is machine-washable (gentle cycle), fits up to a 15.6\" laptop, and includes an anti-theft back pocket, padded straps, and organized internal pockets.",
#     "reasoning": "Chunk B09BCFY3F2 indicates fabric is machine washable, fits 15.6\" laptops, and lists organizational and anti-theft features."
#   },
#   {
#     "question": "Does the TESSAN 15ft flat plug extension cord have surge protection and how many USB ports?",
#     "chunk_id": [
#       "B09V24G4F8"
#     ],
#     "answer_example": "Yes. The TESSAN flat extension has 1700 joules surge protection, 6 widely spaced AC outlets, and 3 USB ports (each up to 5V/2.4A, total 3A/15W).",
#     "reasoning": "Chunk B09V24G4F8 lists surge joules, outlet count, and USB port specs."
#   },
#   {
#     "question": "Are the iPhone MFi-certified 3-pack lightning cables guaranteed compatible with iPhone 11/12/13 series?",
#     "chunk_id": [
#       "B096BND451"
#     ],
#     "answer_example": "The listing presents a 3-pack of MFi-certified lightning cables claiming compatibility with iPhone 11/12/13 series and older models, indicating they should work without pop-up errors.",
#     "reasoning": "Chunk B096BND451 identifies the product as MFi-certified lightning cables compatible with those iPhone models."
#   },
#   {
#     "question": "Does the 4-in-1 Ethernet adapter support Fire TV Stick 4K and provide simultaneous USB data transfer?",
#     "chunk_id": [
#       "B0B64X77P7"
#     ],
#     "answer_example": "Yes. The 4-in-1 Ethernet Adapter is designed for Fire TV Stick 4K and similar streaming sticks, supports 10/100M wired Ethernet, and offers 3 USB ports with simultaneous 480 Mbps data transfer capability.",
#     "reasoning": "Chunk B0B64X77P7 explicitly states compatibility with Fire TV Stick 4K, Ethernet speed, and 3-port USB simultaneous transfer."
#   },
#   {
#     "question": "Can the ARMIDO wireless WiFi PTZ 1080p bulb camera be used outdoors and does it support motion tracking?",
#     "chunk_id": [
#       "B0BK841MXT",
#       "B0B8QV4DTS"
#     ],
#     "answer_example": "Partially. The ARMIDO listing (B0B8QV4DTS) indicates it supports PTZ 1080p and motion detection; a separate bulb-camera listing (B0BK841MXT) describes a 3MP outdoor light-bulb security camera with motion detection, pan/tilt, and night vision. Together they suggest the line includes outdoor-capable bulb cameras with motion detection and tracking.",
#     "reasoning": "B0BK841MXT explicitly covers an outdoor 3MP bulb camera with motion detection and pan/tilt and mentions installation in E27 sockets; B0B8QV4DTS notes PTZ 1080p and motion detection. Combined they support answering whether outdoor PTZ bulb cameras with motion tracking exist in the inventory."
#   },
#   {
#     "question": "Which earbuds cases in the product list have a security lock or anti-lost keychain?",
#     "chunk_id": [
#       "B0B7FFK66G",
#       "B0B5GPCS2V"
#     ],
#     "answer_example": "The TRIDENITE-styled protective case (SKTDWEI listing B0B7FFK66G) includes a safety lock design and a keychain/lanyard to prevent loss. The Gyehuo AirPods cow design case (B0B5GPCS2V) also includes a metal keychain for carrying.",
#     "reasoning": "Chunk B0B7FFK66G describes a security-lock case with keychain; chunk B0B5GPCS2V mentions a metal keychain — combining them answers the comparative question."
#   },
#   {
#     "question": "Which listed products explicitly include a warranty or customer service guarantee?",
#     "chunk_id": [
#       "B0BRQRS9BM",
#       "B0BQXLF477",
#       "B0B4T696W5",
#       "B09TZPTR9N"
#     ],
#     "answer_example": "Several listings include guarantees: the KNOWSQT keyboard (B0BRQRS9BM) promises 1-year warranty and 12-hour response; BLACKSYNCZE cables (B0BQXLF477) include a full lifetime warranty and 24/7 service; the Intel AX210 adapter (B0B4T696W5) offers one-year warranty and lifetime tech support; CoStySee headphone stand (B09TZPTR9N) includes 60-day returns and 12-month warranty.",
#     "reasoning": "Each of these chunks includes explicit warranty/service statements, making them useful to answer warranty/customer service questions."
#   },
#   {
#     "question": "Can I use the Dymo metallic label tape outdoors and what surface prep is recommended?",
#     "chunk_id": [
#       "B08LYX8BZ3"
#     ],
#     "answer_example": "The metallic label tape is water-resistant, tear- and wear-resistant and sticks well to flat, dry surfaces. The seller recommends cleaning the surface of oil or dirt and flattening the label to ensure adhesion.",
#     "reasoning": "Chunk B08LYX8BZ3 mentions water resistance and advises on cleaning surfaces before application."
#   },
#   {
#     "question": "Is there any product that provides a flashlight feature integrated into a smartwatch?",
#     "chunk_id": [
#       "B0CH4ZTTJJ"
#     ],
#     "answer_example": "Yes. The EIGIIS military smart watch (B0CH4ZTTJJ) includes a small LED flashlight on the side intended for outdoor use.",
#     "reasoning": "Chunk B0CH4ZTTJJ explicitly mentions the built-in flashlight feature."
#   },
#   {
#     "question": "Which items explicitly state they are not compatible with certain generations/models?",
#     "chunk_id": [
#       "B0899NYH3J",
#       "B0B45TXPPJ",
#       "B0B1CS593J",
#       "B09W9JMJ3L"
#     ],
#     "answer_example": "Yes — ACdream Fire HD 8 case (B0899NYH3J) warns it’s only for 10th/12th Gen Fire HD 8 and won't fit older generations; the AZMKIMI universal remote (B0B45TXPPJ) is not for Roku stick or Roku TV; Gexmil leather iPad case (B0B1CS593J) indicates it’s only for iPad Air 5/4 models; the Blosomeet Galaxy Tab A8 case (B09W9JMJ3L) is only for the 10.5\" 2022 SM-X200/X205/X207 and not other tablets.",
#     "reasoning": "Each chunk explicitly provides a compatibility restriction or warning, useful for answering compatibility constraints."
#   },
#   {
#     "question": "Can the 3MP light bulb security camera and the 2-pack 3MP bulb cameras be placed in a standard E27 socket and do they support cloud or SD storage?",
#     "chunk_id": [
#       "B0BK841MXT"
#     ],
#     "answer_example": "Yes. The 3MP light bulb security camera is designed to install into a standard E27 bulb base and supports micro SD card storage and optional (paid) cloud storage per the product description.",
#     "reasoning": "Chunk B0BK841MXT specifies E27 installation and notes support for micro SD and cloud storage options."
#   },
#   {
#     "question": "Which products explicitly mention IPX or waterproof ratings?",
#     "chunk_id": [
#       "B0CGV9LQB8",
#       "B0B3HYZ427",
#       "B0B2W7QJXT",
#       "B0BK841MXT"
#     ],
#     "answer_example": "Several items mention water resistance: the blood glucose monitor smartwatch (B0CGV9LQB8) is IP68 waterproof; Tronsmart wireless earbuds (B0B3HYZ427) are IPX5; VOFUOE bone conduction headset (B0B2W7QJXT) is IPX5; the 3MP light bulb security camera (B0BK841MXT) supports outdoor use and night vision (waterproof rating not explicitly given but described as for outdoor installation).",
#     "reasoning": "Chunks include explicit IPX/IP68 ratings for wearables and earbuds; the bulb camera chunk describes outdoor suitability."
#   },
#   {
#     "question": "Which products mention built-in microphones or two-way audio?",
#     "chunk_id": [
#       "B0BWFJGXM2",
#       "B0BKZ2SX5H",
#       "B0BK841MXT",
#       "B0C3ZQ7KHJ"
#     ],
#     "answer_example": "Products with built-in mics/two-way audio: Google Nest Cam (B0BWFJGXM2) has a speaker and mic for talk/listen; ROCWARE RC08 webcam (B0BKZ2SX5H) has a built-in stereo microphone with noise reduction; the 3MP bulb security camera (B0BK841MXT) supports two-way audio; the Bluetooth headphones/earbuds with charging case (B0C3ZQ7KHJ) have dual beamforming mics for clear calls.",
#     "reasoning": "Each chunk describes microphone or two-way audio capabilities useful for answering audio feature queries."
#   },
#   {
#     "question": "Can the 4-in-1 Ethernet adapter be used with a Google Chromecast Ultra and will it add wired ethernet?",
#     "chunk_id": [
#       "B0B64X77P7"
#     ],
#     "answer_example": "Yes. The 4-in-1 adapter lists compatibility with Chromecast Ultra and can add a 10/100M wired Ethernet connection to supported streaming devices.",
#     "reasoning": "Chunk B0B64X77P7 explicitly cites Chromecast Ultra compatibility and wired Ethernet support."
#   },
#   {
#     "question": "Which items in the list explicitly advertise fast or PD charging for phones or laptops?",
#     "chunk_id": [
#       "B0BQXLF477",
#       "B0BKJGRZGP"
#     ],
#     "answer_example": "The BLACKSYNCZE USB-C to Lightning cable (B0BQXLF477) advertises 20W PD fast charging for iPhones; the 140W USB-C PD 3.1 charger (B0BKJGRZGP) supports up to 140W/28V for MacBook Pro and other PD-enabled laptops.",
#     "reasoning": "Both chunks explicitly describe PD fast charging capabilities for phones and laptops respectively."
#   },
#   {
#     "question": "Which 5 products in the catalog cannot be answered from the available chunks (product not listed or missing details)?",
#     "chunk_id": [],
#     "answer_example": "These sample user questions cannot be answered from the provided chunks: (1) 'Do you have the latest Apple AirPods Pro 2 in stock and what colors are available?' — Not covered; (2) 'What is the exact return policy period for purchases made through your store?' — No unified store return policy is provided; (3) 'Can you confirm serial numbers or warranty registration status for my specific Intel CPU purchase?' — Serial/warranty registration details are not in chunks; (4) 'Which products include USB-C to MagSafe 3 cable in the box?' — Charger listing explicitly states cable not included but no product lists including MagSafe cable are present; (5) 'Are any of your laptops preinstalled with Windows 11 Pro versus Home?' — No laptops or OS preinstall details are in the chunks.",
#     "reasoning": "These questions require information that is not present in any of the provided chunk texts: specific stock of Apple AirPods Pro 2, a global return policy, product serial/warranty registration details, product SKUs including MagSafe cables, or OS preinstall information for laptops."
#   },
#   {
#     "question": "Can I mount the 100\" LopBast projector screen to the ceiling and will it support 4K input from a Fire TV Cube?",
#     "chunk_id": [
#       "B09Y5P41L8",
#       "B0B64X77P7"
#     ],
#     "answer_example": "Yes — the LopBast 100\" manual screen supports wall and ceiling installation and is compatible with 4K video. If you use a Fire TV Cube or other 4K source (which may require a downstream HDMI connection), the screen will display 4K input as it supports 4K/Ultra HD projection.",
#     "reasoning": "Chunk B09Y5P41L8 covers mounting and 4K support for the screen; chunk B0B64X77P7 is included to indicate compatible HDMI/streaming device context (Fire TV Stick/streaming devices compatibility), supporting the 4K source scenario."
#   }
# ]

# %%
json_output = response.choices[0].message.content
json_output = json.loads(json_output)

# %%
json_output
# Out:
# [{'question': 'Does the BOVKE carrying case fit the Samsung T7 Shield and other T7 models?',
#   'chunk_id': ['B01N1P97SL'],
#   'answer_example': 'Yes. The BOVKE Travel Carrying Case is designed to perfectly fit the Samsung T7 Shield, Samsung T7, and Samsung T7 Touch (500GB/1TB/2TB) portable SSDs and provides interior elastic bands and a mesh pocket for cables.',
#   'reasoning': 'Chunk B01N1P97SL explicitly lists compatible Samsung T7 models and describes the case features and fit.'},
#  {'question': 'What materials and protection does the Samsung T7 carrying case offer?',
#   'chunk_id': ['B01N1P97SL'],
#   'answer_example': "The case is made of hard EVA and PU material with an ultra-soft velvet interior lining; it's waterproof and shockproof to protect the Samsung T7 from extrusion, dust, splashes, scratches, bumps, and drops.",
#   'reasoning': 'Chunk B01N1P97SL details the construction materials and protective features of the case.'},
#  {'question': 'How many items and projects are included in the SunFounder Ultimate Starter Kit?',
#   'chunk_id': ['B0B778L1DZ'],
#   'answer_example': 'The kit includes 192 items and supports 87 projects, along with online tutorials and video courses.',
#   'reasoning': 'Chunk B0B778L1DZ lists the total items (192) and projects (87) and mentions tutorials.'},
#  {'question': 'Is the SunFounder starter kit suitable for young beginners?',
#   'chunk_id': ['B0B778L1DZ'],
#   'answer_example': 'Yes — it’s marked suitable for ages 8+ and designed for beginners with progressive learning resources and expert-designed courses.',
#   'reasoning': 'Chunk B0B778L1DZ explicitly states suitability for age 8+ and beginner-focused courses.'},
#  {'question': 'Will the Gyehuo AirPods cow design case allow charging without removal?',
#   'chunk_id': ['B0B5GPCS2V'],
#   'answer_example': 'Yes. The Gyehuo AirPods case permits charging without removing the cover and includes a metal keychain for portability.',
#   'reasoning': 'Chunk B0B5GPCS2V mentions convenient charging without removing the cover and the included keychain.'},
#  {'question': 'Does the KNOWSQT wired keyboard require drivers to work on Windows?',
#   'chunk_id': ['B0BRQRS9BM'],
#   'answer_example': 'No. It’s a plug-and-play USB wired keyboard and doesn’t require additional software installation for use.',
#   'reasoning': 'Chunk B0BRQRS9BM states USB plug-and-play and no software installation needed.'},
#  {'question': 'Are the BLACKSYNCZE USB-C to Lightning cables MFi certified and what charging speed do they support?',
#   'chunk_id': ['B0BQXLF477'],
#   'answer_example': 'Yes — they are MFi certified with a C94 connector and support 20W PD fast charging, capable of charging an iPhone 12/13 to ~50% in about 30 minutes.',
#   'reasoning': 'Chunk B0BQXLF477 specifies MFi certification, C94, and 20W PD fast-charging performance.'},
#  {'question': 'How many ARGB fans come preinstalled in the KEDIERS C590 PC case?',
#   'chunk_id': ['B0B2JT5B86'],
#   'answer_example': 'The KEDIERS C590 case comes with 9 pre-installed 120mm ARGB fans and an ARGB controller; synchronization requires connecting the 5V-3PIN cable to the motherboard.',
#   'reasoning': 'Chunk B0B2JT5B86 describes the 9 pre-installed ARGB fans and synchronization requirement.'},
#  {'question': 'Can the Blood Glucose Monitor Smart Watch measure blood sugar without blood?',
#   'chunk_id': ['B0CGV9LQB8'],
#   'answer_example': 'Yes. The smartwatch advertises non-invasive blood glucose testing using a built-in blood sugar monitoring chip and algorithm without the need for blood samples.',
#   'reasoning': 'Chunk B0CGV9LQB8 clearly states the watch offers non-invasive blood glucose testing.'},
#  {'question': 'Will the 140W USB-C charger work with MacBook Pro 16 (2021) and other devices?',
#   'chunk_id': ['B0BKJGRZGP'],
#   'answer_example': 'Yes. The 140W PD 3.1 charger supports MacBook Pro 16" (2021), MacBook Air/Pro, many Windows laptops, iPads, and phones — negotiating up to various wattages (127W/96W/90W/67W/65W/45W/30W) depending on device.',
#   'reasoning': 'Chunk B0BKJGRZGP lists MacBook compatibility and PD 3.1 adaptive outputs and supported devices.'},
#  {'question': 'Which Dymo label maker models are compatible with the 91338 metallic refill tape?',
#   'chunk_id': ['B08LYX8BZ3'],
#   'answer_example': 'The metallic 12mm x 4m tape (91338 replacement) is compatible with Dymo LT-100H, LT-100T, LT-110T, LT-200B, LT-100H Plus, LT-100T Plus, QX50, XR, XM, and 2000 models.',
#   'reasoning': 'Chunk B08LYX8BZ3 enumerates the compatible Dymo label printer models for the tape refill.'},
#  {'question': 'What is the advertised battery life and driver configuration for the Tronsmart wireless earbuds?',
#   'chunk_id': ['B0B3HYZ427'],
#   'answer_example': 'They use a dual-driver setup (10mm dynamic + balanced armature) and offer about 7 hours from a single charge and up to 32 hours total with the charging case.',
#   'reasoning': 'Chunk B0B3HYZ427 describes the dual-driver design and battery/playtime specs.'},
#  {'question': 'Does the EIGIIS military smartwatch support Bluetooth calling and how many sport modes?',
#   'chunk_id': ['B0CH4ZTTJJ'],
#   'answer_example': 'Yes — it supports Bluetooth calling with a built-in speaker and microphone and offers over 100 sport modes.',
#   'reasoning': 'Chunk B0CH4ZTTJJ explicitly lists Bluetooth calling capability and 100+ sport modes.'},
#  {'question': 'What is the read/write speed rating of the TRIDENITE 256GB NVMe M.2 SSD?',
#   'chunk_id': ['B0B7N2DVRQ'],
#   'answer_example': 'The TRIDENITE 256GB NVMe M.2 (PCIe Gen3x4) SSD lists sequential speeds up to approximately Read 1700 MB/s and Write 1000 MB/s.',
#   'reasoning': 'Chunk B0B7N2DVRQ includes the listed CrystalDiskMark sequential read/write speeds.'},
#  {'question': 'How many USB flash drives and what capacity are included in the Vansuny pack?',
#   'chunk_id': ['B0C1Z4MNJT'],
#   'answer_example': 'The Vansuny pack includes 5 USB 3.0 flash drives, each 64GB capacity, with up to 70 MB/s read speeds.',
#   'reasoning': 'Chunk B0C1Z4MNJT specifies 5x 64GB drives and USB 3.0 speeds.'},
#  {'question': 'Can the EZDIY-FAB 24-pin 90° ATX adapter help with limited-height PC cases?',
#   'chunk_id': ['B0B931CQN2'],
#   'answer_example': 'Yes. The 90° right-angle ATX 24-pin adapter reroutes the PSU cable horizontally, preventing pressure on the motherboard connector and solving PSU installation in limited-height chassis.',
#   'reasoning': 'Chunk B0B931CQN2 explains the right-angle design purpose for cramped case installations.'},
#  {'question': 'Does the 20pcs Magnetic Cable Ties set have magnets and are they reusable?',
#   'chunk_id': ['B0BGRWNKZ1'],
#   'answer_example': 'Yes — each silicone cable tie has two built-in magnets on the ends, is soft/elastic and highly reusable, and can attach to metal surfaces for organization.',
#   'reasoning': 'Chunk B0BGRWNKZ1 describes the magnet design, material, and reusability.'},
#  {'question': 'Are the Ulirath AirPods 3 skeleton cases wireless-charging compatible without removal?',
#   'chunk_id': ['B0BHKMQ7PN'],
#   'answer_example': 'Yes. The ultra-thin TPU skeleton case for AirPods 3 maintains wireless charging compatibility; the package also includes a carabiner for carrying.',
#   'reasoning': "Chunk B0BHKMQ7PN states the thin design doesn't compromise wireless charging and mentions the carabiner."},
#  {'question': 'What cores and integrated graphics are in the Intel i9-12900KS?',
#   'chunk_id': ['B0B8TYRD53'],
#   'answer_example': 'The Intel Core i9-12900KS is a 16-core (hexadeca-core) CPU at 2.50 GHz with built-in Intel UHD Graphics 770 and combined on-chip cache (14 MB L2 + 30 MB L3).',
#   'reasoning': 'Chunk B0B8TYRD53 lists core count, base frequency, cache, and integrated GPU details.'},
#  {'question': "Do the 3-pack silicone bands fit Fitbit Inspire 2 and what's the wrist size range?",
#   'chunk_id': ['B0B4RYF7BD'],
#   'answer_example': 'Yes — these replacement silicone sport bands are made for Fitbit Inspire 2/Ace 3 and fit wrist sizes from approximately 5.1" to 8.1" (130mm–205mm).',
#   'reasoning': 'Chunk B0B4RYF7BD details compatibility and the wrist size range.'},
#  {'question': 'Can the ARMIDO WiFi PTZ bulb camera support both 2.4GHz and 5GHz networks?',
#   'chunk_id': ['B0B8QV4DTS'],
#   'answer_example': 'The listing states support for both 2.4GHz and 5GHz Wi-Fi for the ARMIDO Wireless WiFi PTZ 1080p light socket bulb security camera.',
#   'reasoning': 'Chunk B0B8QV4DTS includes a short description mentioning 2.4Ghz and 5Ghz support.'},
#  {'question': 'Does the CoStySee headphone stand auto-sleep AirPods Max when placed on the stand?',
#   'chunk_id': ['B09TZPTR9N'],
#   'answer_example': 'Yes — the CoStySee stand includes a magnetic silicone pad that can trigger Bluetooth disconnect/sleep mode for AirPods Max when placed on the stand (feature is AirPods Max–specific).',
#   'reasoning': 'Chunk B09TZPTR9N explains the magnetic pad and Bluetooth disconnect mode specifically for AirPods Max.'},
#  {'question': 'Will the AZMKIMI universal remote work with a Roku Express stick or Roku TV?',
#   'chunk_id': ['B0B45TXPPJ'],
#   'answer_example': 'No. The AZMKIMI remote is compatible with Roku players (1/2/3/4/Express/Express+/Premier/Premier+/Ultra) but not with Roku sticks or built-in Roku TVs.',
#   'reasoning': 'Chunk B0B45TXPPJ explicitly states incompatibility with Roku stick or Roku TV.'},
#  {'question': 'Is the Twozoh right-angled Micro HDMI adapter suitable for GoPro Hero 7?',
#   'chunk_id': ['B09WDFDG7Z'],
#   'answer_example': 'Yes. The Micro HDMI (Type D) male to HDMI (Type A) female adapter supports devices like the GoPro Hero 7 Black and others that have a Micro HDMI port.',
#   'reasoning': 'Chunk B09WDFDG7Z lists GoPro Hero models among compatible devices for Micro HDMI to HDMI.'},
#  {'question': 'What mounting and viewing angle features does the LopBast 100-inch projector screen offer?',
#   'chunk_id': ['B09Y5P41L8'],
#   'answer_example': 'The LopBast 100" manual pull-down screen (16:9, 1.2 gain) supports wall or ceiling installation, has a manual self-locking and slow-retract mechanism, 160° viewing angle, and supports 1080p/4K/Full HD projection.',
#   'reasoning': 'Chunk B09Y5P41L8 details size, gain, mounting options, locking/retract mechanism, viewing angle, and resolution support.'},
#  {'question': 'Is the ACdream folio leather case compatible with Fire HD 8 (10th & 12th Gen)?',
#   'chunk_id': ['B0899NYH3J'],
#   'answer_example': 'Yes. ACdream case is an exact fit for Amazon All-New Fire HD 8 & 8 Plus 12th and 10th Generation (2022/2020), providing card slots, hand strap, pen holder, and auto wake/sleep.',
#   'reasoning': 'Chunk B0899NYH3J specifies exact compatibility with those Fire HD 8 generations and lists features.'},
#  {'question': 'What Wi-Fi bands and maximum theoretical throughput does the Intel AX210 adapter support?',
#   'chunk_id': ['B0B4T696W5'],
#   'answer_example': 'The Intel AX210 is a tri-band Wi-Fi 6E adapter (2.4GHz, 5GHz, 6GHz) with combined maximum speeds up to 5374 Mbps (2400 Mbps @6GHz + 2400 Mbps @5GHz + 574 Mbps @2.4GHz) and supports Bluetooth 5.2/5.3 features.',
#   'reasoning': 'Chunk B0B4T696W5 lists tri-band operation, the 5374 Mbps aggregated figure, and Bluetooth details.'},
#  {'question': 'What is the advertised battery runtime and charging features of the Bluetooth earbud set with 2200mAh case?',
#   'chunk_id': ['B0C3ZQ7KHJ'],
#   'answer_example': 'The earbuds offer ~10–12 hours per earbud on a single charge and up to 90 hours total using the 2200mAh charging case; the case supports Type-C and wireless charging and includes a dual LED power display.',
#   'reasoning': 'Chunk B0C3ZQ7KHJ outlines playtime per charge, total hours with the charging case, charging methods, and LED display.'},
#  {'question': 'Can the Heymell 150W soundbar connect to a TV via HDMI ARC and does it support multiple sound modes?',
#   'chunk_id': ['B0BQGWMZ53'],
#   'answer_example': 'Yes. The Heymell 150W soundbar supports HDMI ARC (and Optical/AUX/Bluetooth) and offers 8 sound modes, including auto modes like Music, Movie, News, and Game, plus manual bass/treble adjustments.',
#   'reasoning': 'Chunk B0BQGWMZ53 lists HDMI ARC support and enumerates the available sound modes.'},
#  {'question': 'Is the COO case compatible with iPad 10.2" 9th generation and does it have an Apple Pencil holder?',
#   'chunk_id': ['B09XTS6YYW'],
#   'answer_example': 'Yes. The COO PU leather trifold case is compatible with iPad 10.2" 7th/8th/9th gen and iPad Air 3/Pro 10.5, and it includes a built-in Apple Pencil holder and auto sleep/wake feature.',
#   'reasoning': 'Chunk B09XTS6YYW lists device compatibility and mentions the pencil holder and auto sleep/wake.'},
#  {'question': 'Does the VOFUOE bone conduction headset have IPX rating and how long is battery life?',
#   'chunk_id': ['B0B2W7QJXT'],
#   'answer_example': 'Yes — the VOFUOE bone conduction headphones are IPX5 sweat-resistant and offer about 4–6 hours of continuous playback from the 180mAh battery.',
#   'reasoning': 'Chunk B0B2W7QJXT provides IPX5 rating and battery runtime information.'},
#  {'question': 'Is the Unipows Bluetooth keyboard rechargeable and compatible with Mac devices?',
#   'chunk_id': ['B09XKDCJSV'],
#   'answer_example': 'Yes. The Unipows keyboard has a built-in rechargeable battery and is fully compatible with many Mac devices (MacBook, MacBook Air/Pro, iMac), though it notes incompatibility with Mac mini.',
#   'reasoning': 'Chunk B09XKDCJSV indicates rechargeable battery and Mac compatibility with a noted exception.'},
#  {'question': 'Can the LP&No.1 turntable work as a Bluetooth speaker and which record speeds does it play?',
#   'chunk_id': ['B0C2BV9PB1'],
#   'answer_example': 'Yes. This turntable can act as a Bluetooth speaker (Bluetooth input) and plays 33 1/3, 45, and 78 RPM records via its 3-speed belt-drive mechanism and includes separable speakers.',
#   'reasoning': 'Chunk B0C2BV9PB1 states Bluetooth functionality and the supported record speeds and speaker configuration.'},
#  {'question': 'Does the Google Nest Cam store event video if Wi‑Fi is down and is a subscription required for more history?',
#   'chunk_id': ['B0BWFJGXM2'],
#   'answer_example': 'If Wi‑Fi goes down Nest Cam can store up to 1 hour of recorded events locally; it provides 3 hours of free event video history and requires a Nest Aware subscription for extended history (up to 60 days) and advanced features like familiar face alerts.',
#   'reasoning': 'Chunk B0BWFJGXM2 covers local storage during outages, free short history, and optional Nest Aware subscription benefits.'},
#  {'question': 'What are the main features of the Logitech MX Keys bundle?',
#   'chunk_id': ['B083C4FDM8'],
#   'answer_example': 'The bundle includes the Logitech MX Keys advanced wireless illuminated keyboard with spherically dished keys and smart illumination, plus an MX palm rest made of memory foam for long-hours comfort and support.',
#   'reasoning': 'Chunk B083C4FDM8 describes both the MX Keys keyboard features and the included palm rest benefits.'},
#  {'question': 'Does the Devinal RCA Y splitter work for subwoofer connections and is it gold-plated?',
#   'chunk_id': ['B08FZJP2TL'],
#   'answer_example': 'Yes. The Devinal RCA Y splitter is designed for subwoofer/amplifier/home theater use and features gold-plated RCA plugs for improved corrosion resistance and signal transfer.',
#   'reasoning': 'Chunk B08FZJP2TL lists use cases including subwoofers and notes gold-plated connectors.'},
#  {'question': 'Is the Gexmil genuine leather iPad Air case compatible with iPad Air 5 and does it support sleep/wake?',
#   'chunk_id': ['B0B1CS593J'],
#   'answer_example': 'Yes. The Gexmil cowhide folio leather case is made for iPad Air 5th and 4th Gen (10.9") and supports auto sleep/wake as well as multiple stand angles and precise cutouts.',
#   'reasoning': 'Chunk B0B1CS593J specifies compatibility with iPad Air 5/4 and mentions auto sleep/wake and features.'},
#  {'question': 'Will the ROCWARE RC08 webcam work plug-and-play on older Windows systems like Windows 7?',
#   'chunk_id': ['B0BKZ2SX5H'],
#   'answer_example': 'Yes. The ROCWARE RC08 supports plug-and-play USB connection and claims compatibility with Windows XP (SP2/SP3), Vista, 7, 8, 10 and modern systems without extra drivers.',
#   'reasoning': 'Chunk B0BKZ2SX5H lists Windows compatibility down to XP/Vista/7 and describes plug-and-play operation.'},
#  {'question': 'Is the Samsung Galaxy Tab A8 kids case compatible with the 2022 SM-X200 model and does it include a tempered glass screen protector?',
#   'chunk_id': ['B09W9JMJ3L'],
#   'answer_example': 'Yes. The Blosomeet kids case is compatible with the 10.5" Galaxy Tab A8 2022 models SM-X200/X205/X207 and includes a tempered glass screen protector, rotating stand, hand strap, shoulder strap, and pencil holder.',
#   'reasoning': 'Chunk B09W9JMJ3L identifies model compatibility and the included tempered glass and accessories.'},
#  {'question': 'Can the HCMOUNTING heavy-duty TV wall mount support a 75-inch TV weighing 150 lbs and what VESA sizes does it fit?',
#   'chunk_id': ['B09PV64F8J'],
#   'answer_example': 'Yes. The HCMOUNTING long dual arm mount supports TVs up to 179 lbs and 42"–90" sizes, and fits VESA patterns up to 800x400mm, so a 75" TV at 150 lbs should be supported if VESA matches and studs are used.',
#   'reasoning': 'Chunk B09PV64F8J lists max weight (179 lbs), supported screen sizes and VESA up to 800x400mm, plus installation notes for studs.'},
#  {'question': 'Are the rose gold birthday backdrop and tablecloth reusable and what sizes are they?',
#   'chunk_id': ['B09QPQRZCZ'],
#   'answer_example': 'The vinyl floral backdrop (about 150 x 100 cm / 59 x 39.4 in) and plastic tablecloth (approx. 273 x 137 cm / 107.5 x 54 in) are described as durable and washable (backdrop washable), though the tablecloth is disposable.',
#   'reasoning': 'Chunk B09QPQRZCZ provides dimensions and materials, noting the backdrop is washable and the tablecloth disposable.'},
#  {'question': 'Is the BAGSMART laptop backpack machine washable and what laptop size does it fit?',
#   'chunk_id': ['B09BCFY3F2'],
#   'answer_example': 'Yes — the BAGSMART quilted laptop backpack is machine-washable (gentle cycle), fits up to a 15.6" laptop, and includes an anti-theft back pocket, padded straps, and organized internal pockets.',
#   'reasoning': 'Chunk B09BCFY3F2 indicates fabric is machine washable, fits 15.6" laptops, and lists organizational and anti-theft features.'},
#  {'question': 'Does the TESSAN 15ft flat plug extension cord have surge protection and how many USB ports?',
#   'chunk_id': ['B09V24G4F8'],
#   'answer_example': 'Yes. The TESSAN flat extension has 1700 joules surge protection, 6 widely spaced AC outlets, and 3 USB ports (each up to 5V/2.4A, total 3A/15W).',
#   'reasoning': 'Chunk B09V24G4F8 lists surge joules, outlet count, and USB port specs.'},
#  {'question': 'Are the iPhone MFi-certified 3-pack lightning cables guaranteed compatible with iPhone 11/12/13 series?',
#   'chunk_id': ['B096BND451'],
#   'answer_example': 'The listing presents a 3-pack of MFi-certified lightning cables claiming compatibility with iPhone 11/12/13 series and older models, indicating they should work without pop-up errors.',
#   'reasoning': 'Chunk B096BND451 identifies the product as MFi-certified lightning cables compatible with those iPhone models.'},
#  {'question': 'Does the 4-in-1 Ethernet adapter support Fire TV Stick 4K and provide simultaneous USB data transfer?',
#   'chunk_id': ['B0B64X77P7'],
#   'answer_example': 'Yes. The 4-in-1 Ethernet Adapter is designed for Fire TV Stick 4K and similar streaming sticks, supports 10/100M wired Ethernet, and offers 3 USB ports with simultaneous 480 Mbps data transfer capability.',
#   'reasoning': 'Chunk B0B64X77P7 explicitly states compatibility with Fire TV Stick 4K, Ethernet speed, and 3-port USB simultaneous transfer.'},
#  {'question': 'Can the ARMIDO wireless WiFi PTZ 1080p bulb camera be used outdoors and does it support motion tracking?',
#   'chunk_id': ['B0BK841MXT', 'B0B8QV4DTS'],
#   'answer_example': 'Partially. The ARMIDO listing (B0B8QV4DTS) indicates it supports PTZ 1080p and motion detection; a separate bulb-camera listing (B0BK841MXT) describes a 3MP outdoor light-bulb security camera with motion detection, pan/tilt, and night vision. Together they suggest the line includes outdoor-capable bulb cameras with motion detection and tracking.',
#   'reasoning': 'B0BK841MXT explicitly covers an outdoor 3MP bulb camera with motion detection and pan/tilt and mentions installation in E27 sockets; B0B8QV4DTS notes PTZ 1080p and motion detection. Combined they support answering whether outdoor PTZ bulb cameras with motion tracking exist in the inventory.'},
#  {'question': 'Which earbuds cases in the product list have a security lock or anti-lost keychain?',
#   'chunk_id': ['B0B7FFK66G', 'B0B5GPCS2V'],
#   'answer_example': 'The TRIDENITE-styled protective case (SKTDWEI listing B0B7FFK66G) includes a safety lock design and a keychain/lanyard to prevent loss. The Gyehuo AirPods cow design case (B0B5GPCS2V) also includes a metal keychain for carrying.',
#   'reasoning': 'Chunk B0B7FFK66G describes a security-lock case with keychain; chunk B0B5GPCS2V mentions a metal keychain — combining them answers the comparative question.'},
#  {'question': 'Which listed products explicitly include a warranty or customer service guarantee?',
#   'chunk_id': ['B0BRQRS9BM', 'B0BQXLF477', 'B0B4T696W5', 'B09TZPTR9N'],
#   'answer_example': 'Several listings include guarantees: the KNOWSQT keyboard (B0BRQRS9BM) promises 1-year warranty and 12-hour response; BLACKSYNCZE cables (B0BQXLF477) include a full lifetime warranty and 24/7 service; the Intel AX210 adapter (B0B4T696W5) offers one-year warranty and lifetime tech support; CoStySee headphone stand (B09TZPTR9N) includes 60-day returns and 12-month warranty.',
#   'reasoning': 'Each of these chunks includes explicit warranty/service statements, making them useful to answer warranty/customer service questions.'},
#  {'question': 'Can I use the Dymo metallic label tape outdoors and what surface prep is recommended?',
#   'chunk_id': ['B08LYX8BZ3'],
#   'answer_example': 'The metallic label tape is water-resistant, tear- and wear-resistant and sticks well to flat, dry surfaces. The seller recommends cleaning the surface of oil or dirt and flattening the label to ensure adhesion.',
#   'reasoning': 'Chunk B08LYX8BZ3 mentions water resistance and advises on cleaning surfaces before application.'},
#  {'question': 'Is there any product that provides a flashlight feature integrated into a smartwatch?',
#   'chunk_id': ['B0CH4ZTTJJ'],
#   'answer_example': 'Yes. The EIGIIS military smart watch (B0CH4ZTTJJ) includes a small LED flashlight on the side intended for outdoor use.',
#   'reasoning': 'Chunk B0CH4ZTTJJ explicitly mentions the built-in flashlight feature.'},
#  {'question': 'Which items explicitly state they are not compatible with certain generations/models?',
#   'chunk_id': ['B0899NYH3J', 'B0B45TXPPJ', 'B0B1CS593J', 'B09W9JMJ3L'],
#   'answer_example': 'Yes — ACdream Fire HD 8 case (B0899NYH3J) warns it’s only for 10th/12th Gen Fire HD 8 and won\'t fit older generations; the AZMKIMI universal remote (B0B45TXPPJ) is not for Roku stick or Roku TV; Gexmil leather iPad case (B0B1CS593J) indicates it’s only for iPad Air 5/4 models; the Blosomeet Galaxy Tab A8 case (B09W9JMJ3L) is only for the 10.5" 2022 SM-X200/X205/X207 and not other tablets.',
#   'reasoning': 'Each chunk explicitly provides a compatibility restriction or warning, useful for answering compatibility constraints.'},
#  {'question': 'Can the 3MP light bulb security camera and the 2-pack 3MP bulb cameras be placed in a standard E27 socket and do they support cloud or SD storage?',
#   'chunk_id': ['B0BK841MXT'],
#   'answer_example': 'Yes. The 3MP light bulb security camera is designed to install into a standard E27 bulb base and supports micro SD card storage and optional (paid) cloud storage per the product description.',
#   'reasoning': 'Chunk B0BK841MXT specifies E27 installation and notes support for micro SD and cloud storage options.'},
#  {'question': 'Which products explicitly mention IPX or waterproof ratings?',
#   'chunk_id': ['B0CGV9LQB8', 'B0B3HYZ427', 'B0B2W7QJXT', 'B0BK841MXT'],
#   'answer_example': 'Several items mention water resistance: the blood glucose monitor smartwatch (B0CGV9LQB8) is IP68 waterproof; Tronsmart wireless earbuds (B0B3HYZ427) are IPX5; VOFUOE bone conduction headset (B0B2W7QJXT) is IPX5; the 3MP light bulb security camera (B0BK841MXT) supports outdoor use and night vision (waterproof rating not explicitly given but described as for outdoor installation).',
#   'reasoning': 'Chunks include explicit IPX/IP68 ratings for wearables and earbuds; the bulb camera chunk describes outdoor suitability.'},
#  {'question': 'Which products mention built-in microphones or two-way audio?',
#   'chunk_id': ['B0BWFJGXM2', 'B0BKZ2SX5H', 'B0BK841MXT', 'B0C3ZQ7KHJ'],
#   'answer_example': 'Products with built-in mics/two-way audio: Google Nest Cam (B0BWFJGXM2) has a speaker and mic for talk/listen; ROCWARE RC08 webcam (B0BKZ2SX5H) has a built-in stereo microphone with noise reduction; the 3MP bulb security camera (B0BK841MXT) supports two-way audio; the Bluetooth headphones/earbuds with charging case (B0C3ZQ7KHJ) have dual beamforming mics for clear calls.',
#   'reasoning': 'Each chunk describes microphone or two-way audio capabilities useful for answering audio feature queries.'},
#  {'question': 'Can the 4-in-1 Ethernet adapter be used with a Google Chromecast Ultra and will it add wired ethernet?',
#   'chunk_id': ['B0B64X77P7'],
#   'answer_example': 'Yes. The 4-in-1 adapter lists compatibility with Chromecast Ultra and can add a 10/100M wired Ethernet connection to supported streaming devices.',
#   'reasoning': 'Chunk B0B64X77P7 explicitly cites Chromecast Ultra compatibility and wired Ethernet support.'},
#  {'question': 'Which items in the list explicitly advertise fast or PD charging for phones or laptops?',
#   'chunk_id': ['B0BQXLF477', 'B0BKJGRZGP'],
#   'answer_example': 'The BLACKSYNCZE USB-C to Lightning cable (B0BQXLF477) advertises 20W PD fast charging for iPhones; the 140W USB-C PD 3.1 charger (B0BKJGRZGP) supports up to 140W/28V for MacBook Pro and other PD-enabled laptops.',
#   'reasoning': 'Both chunks explicitly describe PD fast charging capabilities for phones and laptops respectively.'},
#  {'question': 'Which 5 products in the catalog cannot be answered from the available chunks (product not listed or missing details)?',
#   'chunk_id': [],
#   'answer_example': "These sample user questions cannot be answered from the provided chunks: (1) 'Do you have the latest Apple AirPods Pro 2 in stock and what colors are available?' — Not covered; (2) 'What is the exact return policy period for purchases made through your store?' — No unified store return policy is provided; (3) 'Can you confirm serial numbers or warranty registration status for my specific Intel CPU purchase?' — Serial/warranty registration details are not in chunks; (4) 'Which products include USB-C to MagSafe 3 cable in the box?' — Charger listing explicitly states cable not included but no product lists including MagSafe cable are present; (5) 'Are any of your laptops preinstalled with Windows 11 Pro versus Home?' — No laptops or OS preinstall details are in the chunks.",
#   'reasoning': 'These questions require information that is not present in any of the provided chunk texts: specific stock of Apple AirPods Pro 2, a global return policy, product serial/warranty registration details, product SKUs including MagSafe cables, or OS preinstall information for laptops.'},
#  {'question': 'Can I mount the 100" LopBast projector screen to the ceiling and will it support 4K input from a Fire TV Cube?',
#   'chunk_id': ['B09Y5P41L8', 'B0B64X77P7'],
#   'answer_example': 'Yes — the LopBast 100" manual screen supports wall and ceiling installation and is compatible with 4K video. If you use a Fire TV Cube or other 4K source (which may require a downstream HDMI connection), the screen will display 4K input as it supports 4K/Ultra HD projection.',
#   'reasoning': 'Chunk B09Y5P41L8 covers mounting and 4K support for the screen; chunk B0B64X77P7 is included to indicate compatible HDMI/streaming device context (Fire TV Stick/streaming devices compatibility), supporting the 4K source scenario.'}]

# %%
len(json_output)
# Out:
# 58

# %%
points = qdrant_client.scroll(
    collection_name="Amazon-items-collection-00",
    scroll_filter=Filter(
        must=[
            FieldCondition(
                key="parent_asin",
                match=MatchValue(value="B0B64X77P7")
            )
        ]
    ),
    limit=1000,
    with_payload=True,
    with_vectors=False
)[0]

# %%
points[0].payload
# Out:
# {'description': '4 in 1 Ethernet Adapter and 3 Ports USB OTG Hub for Fire TV Stick 4K/Chromecast/Google Home Mini/Raspberry Pi Zero and Other Streaming TV Sticks,Micro USB OTG Cable HUB with Powered Network Adapter Add extra wired Ethernet & USB 3 ports extra storage to your streaming device for connecting wired network,flash drive,wireless keyboard or whatever USB peripherals,Stable work at the same time.(please note: Not compatible with Fire Stick 1, Roku Stick/Express,Fire HD 10,Google Home Mini cellphones, tablets, and Laptops,USB only for charging.) Support 10/100M wired network Ethernet connection, faster and more stable，and 3 ports (480Mbps) of Simultaneous data transfer possible.no buffering, no lag. 4-in-1 integrated design, no need to combine, the signal transmission is more stable. The length is 3.3 ft. It is easy to operate and allows you to place it anywhere without worrying about loose connections. Plug & Play,no additional driver/software needed. Just need to connect it to an available devices and LAN network, it will be activated. Compatible with Fire TV Stick 4K,Streaming TV Sticks,Google Home Mini, Media Players,Chromecast Ultra / 3 / 2 / 1 / Audio,Raspberry Pi Zero, and Support Micro USB port TV stick,etc.',
#  'images': 'https://m.media-amazon.com/images/I/41Uo3TTM14L._AC_.jpg',
#  'rating_number': 142,
#  'price': 12.99,
#  'average_rating': 4.3,
#  'parent_asin': 'B0B64X77P7'}

# %%
def get_description(parent_asin:str) -> str:

    points = qdrant_client.scroll(
        collection_name="Amazon-items-collection-00",
        scroll_filter=Filter(
            must=[
                FieldCondition(
                    key="parent_asin",
                    match=MatchValue(value=parent_asin)
                )
            ]
        ),
        limit=1000,
        with_payload=True,
        with_vectors=False
    )[0]

    return points[0].payload["description"]

# %%
get_description("B0B64X77P7")
# Out:
# '4 in 1 Ethernet Adapter and 3 Ports USB OTG Hub for Fire TV Stick 4K/Chromecast/Google Home Mini/Raspberry Pi Zero and Other Streaming TV Sticks,Micro USB OTG Cable HUB with Powered Network Adapter Add extra wired Ethernet & USB 3 ports extra storage to your streaming device for connecting wired network,flash drive,wireless keyboard or whatever USB peripherals,Stable work at the same time.(please note: Not compatible with Fire Stick 1, Roku Stick/Express,Fire HD 10,Google Home Mini cellphones, tablets, and Laptops,USB only for charging.) Support 10/100M wired network Ethernet connection, faster and more stable，and 3 ports (480Mbps) of Simultaneous data transfer possible.no buffering, no lag. 4-in-1 integrated design, no need to combine, the signal transmission is more stable. The length is 3.3 ft. It is easy to operate and allows you to place it anywhere without worrying about loose connections. Plug & Play,no additional driver/software needed. Just need to connect it to an available devices and LAN network, it will be activated. Compatible with Fire TV Stick 4K,Streaming TV Sticks,Google Home Mini, Media Players,Chromecast Ultra / 3 / 2 / 1 / Audio,Raspberry Pi Zero, and Support Micro USB port TV stick,etc.'

# %% [markdown]
# ### Create Eval dataset in Langsmith

# %%
client = Client(api_key=os.environ["LANGSMITH_API_KEY"])

# %%
dataset_name = "rag-evaluation-dataset-v3"
dataset = client.create_dataset(
    dataset_name=dataset_name,
    description="Evaluation dataset for RAG application"
)

# %%
for item in json_output:
    client.create_example(
        dataset_id=dataset.id,
        inputs={"question":item["question"]},
        outputs={
            "ground_truth": item["answer_example"],
            "reference_context_ids": item["chunk_id"],
            "reference_description": [get_description(id) for id in item["chunk_id"]]
        }
    )

# %%
from langsmith import Client

client = Client()
for dataset in client.list_datasets():
    print(f"{dataset.name} — {dataset.id}")
# Out:
# rag-evaluation-dataset-v3 — b9bb66b2-c479-4584-8177-f1b746173f48
# rag-evaluation-dataset-v2 — 0f8f7296-7d1a-4065-ab9d-cc13b7fb5701
# rag-evaluation-dataset — 30d87d53-8655-4fbd-89b9-cf4074690fc6

# %%
from langsmith import Client

client = Client()
dataset_id = "b9bb66b2-c479-4584-8177-f1b746173f48"

for example in client.list_examples(dataset_id=dataset_id):
    print("ID:", example.id)
    print("Inputs:", example.inputs)
    print("Outputs:", example.outputs)
    print("Reference IDs:", example.outputs.get("reference_context_ids"))

    print("-" * 40)
# Out:
# ID: c116a5df-386c-4dc0-92e6-0c4d32d25183
# Inputs: {'question': 'Can I mount the 100" LopBast projector screen to the ceiling and will it support 4K input from a Fire TV Cube?'}
# Outputs: {'ground_truth': 'Yes — the LopBast 100" manual screen supports wall and ceiling installation and is compatible with 4K video. If you use a Fire TV Cube or other 4K source (which may require a downstream HDMI connection), the screen will display 4K input as it supports 4K/Ultra HD projection.', 'reference_context_ids': ['B09Y5P41L8', 'B0B64X77P7'], 'reference_description': ["LopBast Screen 100INCH Manual Pull Down White Projector Screen 16:9 1.2 Gain Retractable Auto-Locking 4K 8K 3D Ultra HD for Home Theater Movie Office Game Projection Screen with Slow Retract Mechanism 【High Quality Material】 Metal housing design, can effectively prevent damage and deformation during transportation. The projector screen uses a composite fabric of multiple layers, make the surface smoother and flatter, fully black backed to eliminate light penetration, has excellent projection quality. 【Manual Self-Locking Device】 Use manual self-locking design, can pull down to lock the screen to the specified position exactly. The slow retract mechanism uses high-purity lubricating oil and sealed dust-proof structure, long-lasting durability. 【Visual Enjoyment】 The matte process of the screen makes the light reflected evenly and resists the interference of ambient light. A gain of 1.2 provides a brighter image. 100 inch, 160° panoramic viewing angle and 16:9 field of view, let you and your family enjoy a high-quality movie viewing experience. Screen supports 1080p, 4K and Full HD images. 【Use and Care】 You can easily install it on walls and ceilings or anywhere in your home. The material of the screen is not easy to get wet and moldy, edge is made by a special process, does not roll or warp over time. The projection screen is easy to clean with water. 【Use in multiple scenarios】 This portable projection screen is suitable for every scene. Home, school, office, church, classroom, backyard; on any venues: speeches, conferences, weddings, parties; suitable for any entertainment activity: sporting events, movies, games, etc., it's definitely your best choice.", '4 in 1 Ethernet Adapter and 3 Ports USB OTG Hub for Fire TV Stick 4K/Chromecast/Google Home Mini/Raspberry Pi Zero and Other Streaming TV Sticks,Micro USB OTG Cable HUB with Powered Network Adapter Add extra wired Ethernet & USB 3 ports extra storage to your streaming device for connecting wired network,flash drive,wireless keyboard or whatever USB peripherals,Stable work at the same time.(please note: Not compatible with Fire Stick 1, Roku Stick/Express,Fire HD 10,Google Home Mini cellphones, tablets, and Laptops,USB only for charging.) Support 10/100M wired network Ethernet connection, faster and more stable，and 3 ports (480Mbps) of Simultaneous data transfer possible.no buffering, no lag. 4-in-1 integrated design, no need to combine, the signal transmission is more stable. The length is 3.3 ft. It is easy to operate and allows you to place it anywhere without worrying about loose connections. Plug & Play,no additional driver/software needed. Just need to connect it to an available devices and LAN network, it will be activated. Compatible with Fire TV Stick 4K,Streaming TV Sticks,Google Home Mini, Media Players,Chromecast Ultra / 3 / 2 / 1 / Audio,Raspberry Pi Zero, and Support Micro USB port TV stick,etc.']}
# Reference IDs: ['B09Y5P41L8', 'B0B64X77P7']
# ----------------------------------------
# ID: d4789a6f-68cd-4acf-89ba-291427fc36af
# Inputs: {'question': 'Which 5 products in the catalog cannot be answered from the available chunks (product not listed or missing details)?'}
# Outputs: {'ground_truth': "These sample user questions cannot be answered from the provided chunks: (1) 'Do you have the latest Apple AirPods Pro 2 in stock and what colors are available?' — Not covered; (2) 'What is the exact return policy period for purchases made through your store?' — No unified store return policy is provided; (3) 'Can you confirm serial numbers or warranty registration status for my specific Intel CPU purchase?' — Serial/warranty registration details are not in chunks; (4) 'Which products include USB-C to MagSafe 3 cable in the box?' — Charger listing explicitly states cable not included but no product lists including MagSafe cable are present; (5) 'Are any of your laptops preinstalled with Windows 11 Pro versus Home?' — No laptops or OS preinstall details are in the chunks.", 'reference_context_ids': [], 'reference_description': []}
# Reference IDs: []
# ----------------------------------------
# ID: ea56565f-1436-4c6d-a74c-b194ce0341d1
# Inputs: {'question': 'Which items in the list explicitly advertise fast or PD charging for phones or laptops?'}
# Outputs: {'ground_truth': 'The BLACKSYNCZE USB-C to Lightning cable (B0BQXLF477) advertises 20W PD fast charging for iPhones; the 140W USB-C PD 3.1 charger (B0BKJGRZGP) supports up to 140W/28V for MacBook Pro and other PD-enabled laptops.', 'reference_context_ids': ['B0BQXLF477', 'B0BKJGRZGP'], 'reference_description': ['BLACKSYNCZE USB C to Lightning Cable 2Pack 6FT, [MFi Certified] iPhone Charger Cord USB C Nylon Braided Type C to Lightning Cable Fast Charging for iPhone 13 12 11 Pro Max XR XS X 8 7 6s, SE2020 [MFi Certified iPhone Cable] This USB C to Lightning Cable features an upgraded C94 connector and original MFi chip for seamless compatibility and no pop-up error messages; protects your devices from overcurrent and overvoltage while charging. [20W PD Fast Charging Cable] With 20W PD fast charging, this iPhone Charger Fast Charging Cable can charge an iPhone 13 or 12 up to 50% in just 30 minutes, which is 2.5 times faster than a standard lightning cable (5V/1A). [Durability & Flexibility] Includes built-in overvoltage and overcurrent protection and features a durable design with reinforced joints, silver-plated connectors, and a triple layer of braided nylon; withstands over 12,000 bends in laboratory tests. [Wide Compatibility] This Lightning Cable USB C is widely compatible with fast-charging support for iPhone 13 Pro Max, 13 Pro, 13, 13 Mini, 12 Pro Max, 12 Pro, 12, 12 Mini, 11 Pro Max, 11 Pro, 11 iPhone XR, XS, Max, XS, X, SE2020, iPhone 8 Plus, and 8; also supports standard charging for iPhone 7 Plus, 7, 6s Plus, 6s, 6 Plus, 6, 5s, 5c, 5 SE, etc. [What You Get] Includes 2 Pack 6FT BLACKSYNCZE Type C to Lightning Cable with full lifetime warranty and friendly 24/7 customer service.', "140W USB C Charger Power Adapter for MacBook Pro 16 inch 2023 2021, MacBook Pro 14 15 13, MacBook Air, PD 3.1 28V Great for M1 / M2 Laptop, Original Quality, Reduce Battery Aging, Temperature Control Fast Charge Your MacBook: thanks to a 140W / 28V / 5A max output and USB Power Delivery 3.1, you can full charge your 2021 MacBook Pro 16ʺ in only 1h 26 mins and charge it up to 50% in only 26 mins as fast as to full charge a cellphone. Notice: doesn't include USB C to MagSafe 3 Cable. Original Quality Helps to Keep MacBook Battery Health: built-in original dynamic software and hardware systems to keep Maximum Battery Capacity to 98%, intelligently learning your daily charging routine to reduce battery aging and intelligently monitoring temperature to safeguard your devices. Strong Power to Support “M” Series Chip: PD 3.1 provide you a higher charging efficiency than PD 3.0 to meet the high-speed processing capacity of M1, M1 Pro, M1 Max, M2 chip, choose MARSDOCK PD 3.1 charger if your MacBook use the “M” series chip. Universal Compatibility: thanks to the newest PD 3.1 protocol, it can intelligently output 127W, 96W, 90W, 67W, 65W, 45W, 30W according to your device and keep the peak charging performance at the mean time, widely compatible with MacBook Pro 16”, 15”, 14”, 13”, MacBook Air, Surface(127W/102W), Lenovo(65W/45W), HP, iPad Pro / Air / Mini, iPhone, Samsung Galaxy, Google Pixel... Superior Safety and Dependable Warranty: built-in multi safeguards to protect against overcharging, short circuiting, overheating, spark; enjoy worry-free 12-month warranty by refund or replacement and friendly customer service."]}
# Reference IDs: ['B0BQXLF477', 'B0BKJGRZGP']
# ----------------------------------------
# ID: 23ae717c-31fe-42df-836b-93c389f871cc
# Inputs: {'question': 'Can the 4-in-1 Ethernet adapter be used with a Google Chromecast Ultra and will it add wired ethernet?'}
# Outputs: {'ground_truth': 'Yes. The 4-in-1 adapter lists compatibility with Chromecast Ultra and can add a 10/100M wired Ethernet connection to supported streaming devices.', 'reference_context_ids': ['B0B64X77P7'], 'reference_description': ['4 in 1 Ethernet Adapter and 3 Ports USB OTG Hub for Fire TV Stick 4K/Chromecast/Google Home Mini/Raspberry Pi Zero and Other Streaming TV Sticks,Micro USB OTG Cable HUB with Powered Network Adapter Add extra wired Ethernet & USB 3 ports extra storage to your streaming device for connecting wired network,flash drive,wireless keyboard or whatever USB peripherals,Stable work at the same time.(please note: Not compatible with Fire Stick 1, Roku Stick/Express,Fire HD 10,Google Home Mini cellphones, tablets, and Laptops,USB only for charging.) Support 10/100M wired network Ethernet connection, faster and more stable，and 3 ports (480Mbps) of Simultaneous data transfer possible.no buffering, no lag. 4-in-1 integrated design, no need to combine, the signal transmission is more stable. The length is 3.3 ft. It is easy to operate and allows you to place it anywhere without worrying about loose connections. Plug & Play,no additional driver/software needed. Just need to connect it to an available devices and LAN network, it will be activated. Compatible with Fire TV Stick 4K,Streaming TV Sticks,Google Home Mini, Media Players,Chromecast Ultra / 3 / 2 / 1 / Audio,Raspberry Pi Zero, and Support Micro USB port TV stick,etc.']}
# Reference IDs: ['B0B64X77P7']
# ----------------------------------------
# ID: 157ea20b-90ca-44b3-bc51-2a47462c8e5f
# Inputs: {'question': 'Which products mention built-in microphones or two-way audio?'}
# Outputs: {'ground_truth': 'Products with built-in mics/two-way audio: Google Nest Cam (B0BWFJGXM2) has a speaker and mic for talk/listen; ROCWARE RC08 webcam (B0BKZ2SX5H) has a built-in stereo microphone with noise reduction; the 3MP bulb security camera (B0BK841MXT) supports two-way audio; the Bluetooth headphones/earbuds with charging case (B0C3ZQ7KHJ) have dual beamforming mics for clear calls.', 'reference_context_ids': ['B0BWFJGXM2', 'B0BKZ2SX5H', 'B0BK841MXT', 'B0C3ZQ7KHJ'], 'reference_description': ['Google indoor Nest Security Cam 1080p (Wired) - 2nd Generation - Snow Nest Cam has built-in intelligence and can tell the difference between a person, animal, and vehicle and send alerts directly through the Google Home app[1], no subscription required.Controller Type:Google Assistant.Connectivity protocol:Bluetooth;Wi-Fi.Power source type:Corded Electric Easily check in from anywhere 24/7 with 1080p HDR video[1] with night vision, and see what you missed with 3 hours of free event video history[2]; add a Nest Aware subscription (sold separately) for up to 60 days of video history[3] If your Wi-Fi goes down, Nest Cam will store up to 1 hour of recorded events so you can see what you missed [4] Take action in an instant if something happens; talk and listen with the built in speaker and mic on your security camera or call your local emergency service directly from the Google Home app (Nest Aware subscription required)[5] Set up Activity Zones to receive phone notifications about specific areas of your home and know when familiar faces arrive (Nest Aware subscription required for familiar face alerts)[1,6] Stream your live video feed hands-free on compatible smart displays with Google Assistant, and compatible smart displays, smart TVs, and tablets with Amazon Alexa Nest Cam requires the Google Home app and a free Google Account - it’s not compatible with the Nest app or the Nest site Nest Cam is designed to fit any home’s style; it comes in a range of colors and the built-in stand lets you place it on a wall or table Set up Home & Away Routines to automatically turn your Nest Cam off when you’re home, so no video is streamed or recorded until you leave[7] Please refer to the product description section below for all applicable legal disclaimers denoted by the bracketed numbers in the preceding bullet points (e.g., [1], [2], etc.)', 'ROCWARE RC08 Webcam with Microphone, Web Camera for Computer Camera, HD Webcam 1080p 2K Streaming Camera, Auto Focus Web cam with Built-in Mic, High-Performance Speaker, and Easy Plug-and-Play 【5x Faster ToF Auto-Focus web camera】 This webcam uses an upgraded version of ToF auto-focus technology, equipped with laser-assisted focusing and 4x digital zoom function. Compared to other web cam on the market, it only takes 0.2 seconds to focus. In the era of remote meetings, it enables precise distance measurement regardless of the features on the projection surface, allowing your audience to always focus on the main object or character of your content, eliminating unnecessary distractions and ensuring that the video image is always clear and smooth even in low-light conditions. It is ideal for PC video conferencing, Zoom meetings, online courses, webinars, and more. 【Amazing Sound Performance & Equipped with Privacy Protection Cover】 This webcam with microphone has undergone a complete speaker upgrade and is equipped with a high-performance speaker designed with a power of 2W, 82dB, and a coverage radius of up to 16.5 feet. The advanced sound chamber design inspired by air ducts and top audio technology makes the sound clearer and more natural, providing you with excellent sound effects. The audio performance of the RC08 is even better than the built-in speakers of a laptop computer. In addition, the hd webcam is equipped with a physical privacy shutter for the lens, providing individuals and large companies with added security and peace of mind. 【Built-in Stereo Microphone & Echo Cancellation Noise R ...
# Reference IDs: ['B0BWFJGXM2', 'B0BKZ2SX5H', 'B0BK841MXT', 'B0C3ZQ7KHJ']
# ----------------------------------------
# ID: a32a3a08-be12-4805-92f1-af981d370328
# Inputs: {'question': 'Which products explicitly mention IPX or waterproof ratings?'}
# Outputs: {'ground_truth': 'Several items mention water resistance: the blood glucose monitor smartwatch (B0CGV9LQB8) is IP68 waterproof; Tronsmart wireless earbuds (B0B3HYZ427) are IPX5; VOFUOE bone conduction headset (B0B2W7QJXT) is IPX5; the 3MP light bulb security camera (B0BK841MXT) supports outdoor use and night vision (waterproof rating not explicitly given but described as for outdoor installation).', 'reference_context_ids': ['B0CGV9LQB8', 'B0B3HYZ427', 'B0B2W7QJXT', 'B0BK841MXT'], 'reference_description': ['Blood Glucose Monitor Smart Watch for iPhone Android Bluetooth Calling 2023 Upgraded Non-invasive Blood Sugar Test Smartwatchs Men Women with Heart Rate Blood Oxygen Pressure HRV Fitness Tracker Watch 【New Upgraded Blood Sugar Monitor Watch】This smart watch offers non-invasive blood glucose testing, eliminating the need for needles or blood samples. The built-in blood sugar monitoring chip provides precise and safe readings.\u200b The core patented new algorithm evaluates the users health. stores data on the mobile phone, accurately calculates, comprehensively evaluates, and pushes personalized blood sugar interval values, so you can stay informed and take control of your health. 【24H Accurate Health Monitoring】Intelligent diabetic health watch, 1.92inch 280*350 HD touch screen, non-invasive blood sugar test, heart rate monitoring, blood pressure monitoring, blood oxygen monitoring and save the data results in the APP, which is convenient for viewing and analysis at anytime. And it will monitor your sleep status automatically and provides comprehensive sleep quality analysis. 【Activity & Fitness Tracker smartwatch with IP68 Waterproof】Track your health and fitness goals with the fitness & activity tracker. The tracker watch supports a variety of sports modes such as running, cycling, and hiking etc., and can monitor important data such as sports center rate distance, speed and calorie consumption in real time, helping you explore the larger world and constantly expand your boundaries and with an IP68 waterproof, the watch is perfect for swimming and any activity. 【Personalized Watch Dial with Practical Tools】The fitness watch for men women comes with theme dials and even upload your own photos, such as selfies or pictures of your pets, to create a truly personalized look. The smartwatch features practical tools such as remote take photo, stopwatch, timer, music control, breathing training, night mode, alarm clock and wrist up awake, weather forecast, giving more convenience and fun to your life. 【Multifunction Bluetooth Smart Watch】The smartwatch is compatible with smartphones that run on iOS 8.0 or Android OS 5.0 or higher. This fitness activity smart watch full screen for iPhone and Android phones includes a bunch of new features such as smart watch can call reminder, receive and notifications WhatsAPP, SMS, Facebook, Twitter, etc. messenger reminder by bluetooth and avoid missing important information.', 'Tronsmart Wireless Earbuds, Dual-Driver Earbuds Bluetooth 5.3 with 3 EQ Modes, in-Ear Bluetooth Headphones IPX5 Waterproof, Stereo Wireless Earphones 32Hrs Playtime for Music, Workout, etc. Black 🎶【Pure Sound Quality】-The wireless earbuds are equipped with a 10mm Dynamic Driver and a balanced Armature Driver, this dual driver technology could deliver high and low-frequency sound directly to your ear without interference. Its wide soundstage is detailed and spacious, the bass has a deep punch, mids are luscious, and treble sparkles. 🎼【3EQ Modes】-The 3EQ modes of these Bluetooth earbuds will upgrade your music experience. The Bass Booster enhances bass-heavy music, Pure makes voices stand out clearly, and the default EQ (Normal) delivers well-balanced sound. To switch to a different mode, quickly press the left bud 3 times. 🦻【One Step Pairing】-The moment you open the charging case, the Bluetooth Headphones will automatically connect to your devices (after being paired the first time). The specific touch control f ...
# Reference IDs: ['B0CGV9LQB8', 'B0B3HYZ427', 'B0B2W7QJXT', 'B0BK841MXT']
# ----------------------------------------
# ID: 17d717b9-4b43-4378-a1ae-0369050730d9
# Inputs: {'question': 'Can the 3MP light bulb security camera and the 2-pack 3MP bulb cameras be placed in a standard E27 socket and do they support cloud or SD storage?'}
# Outputs: {'ground_truth': 'Yes. The 3MP light bulb security camera is designed to install into a standard E27 bulb base and supports micro SD card storage and optional (paid) cloud storage per the product description.', 'reference_context_ids': ['B0BK841MXT'], 'reference_description': ['2 Pack 3MP Light Bulb Security Camera Wireless Outdoor, 360° Indoor WiFi Smart Light Socket Cameras for Home Security Cameras with Motion Detection and Alerts, 2-Way Audio, Compatible with Alexa 【3MP HD & Clear Night Vision】- 3MP surveillance light bulb security camera is able to provide clearer and more detailed images, which helps you get rid of blurred image quality. The WiFi Pan Tilt Camera Upgrade Hd Night Vision Function, and the infrared night vision and white light night vision can be switched freely, camera light bulb You Can See Clear Images Even In Complete Darkness.Only supports 2.4Ghz WiFi (5Ghz WiFi is not supported). 【Motion Detection & Real-time Alerts】This smart camera wifi outdoor build-in highly sensitive motion sensor detect moving object.If someone breaks into your home,The camera will follow him and sound an alarm.Give your home a protection. 【Two-Way Audio and High Quality Service】The security camera outdoor wifi built-in microphone and speaker, the bulb security camera can have a conversation between you and your visitor,If you have any question, please contact us.We provide lifetime technical support and services. 【Wireless and Easy To Install】This camera can be installed using a normal E27 bulb base(110V~240V),Our cameras also come with a connector that allows you to easily mount our cameras on the socket.Then use the mobile phone to download the APP, and use the APP to help the camera connect to the WIFI. No other operations are required. Note that it takes about 40s to connect the bulb security camera for the first time. 【Pan/Tilt Capacity & Remote Access】 - wireless security camera rotates 355° horizontally and flips 90° vertically, allowing you to control the viewing angle of the camera via the APP to realize 360° observation. You can remotely view the surveillance screen in the camera via the mobile APP anytime, anywhere. Bulb security camera supports cloud storage and micro SD card storage (the camera does not come with an SD card, and cloud storage needs to be paid).']}
# Reference IDs: ['B0BK841MXT']
# ----------------------------------------
# ID: b00a4900-d533-4499-833c-6f6780c3f19d
# Inputs: {'question': 'Which items explicitly state they are not compatible with certain generations/models?'}
# Outputs: {'ground_truth': 'Yes — ACdream Fire HD 8 case (B0899NYH3J) warns it’s only for 10th/12th Gen Fire HD 8 and won\'t fit older generations; the AZMKIMI universal remote (B0B45TXPPJ) is not for Roku stick or Roku TV; Gexmil leather iPad case (B0B1CS593J) indicates it’s only for iPad Air 5/4 models; the Blosomeet Galaxy Tab A8 case (B09W9JMJ3L) is only for the 10.5" 2022 SM-X200/X205/X207 and not other tablets.', 'reference_context_ids': ['B0899NYH3J', 'B0B45TXPPJ', 'B0B1CS593J', 'B09W9JMJ3L'], 'reference_description': ["ACdream Case for All-New Fire HD 8 & 8 Plus Tablet (12th Generation/10th Gen, 2022/2020 Release), Folio Leather Cover, Folding Stand, Auto Wake Sleep, Hand Strap, Card Slots, Black EXACT FIT: Our Fire HD 8 tablet case was designed and manufactured to be the precise fit ONLY for Amazon All-New Fire HD 8 & 8 Plus (12th Generation/10th Generation, 2022/2020 Release). The Kindle Fire case will NOT fit older Kindle Fire generations. The precise fit of this Fire 8 tablet case ensures that all buttons and ports are accessible and the camera lens is not obstructed. NOTE: Before ordering this tablet case please make sure that your Kindle Fire model is correct. STRONG PROTECTION: Does your Amazon Fire tablet need a case that will protect it and make the device look better? We have just what you're looking for. The Fire tablet cases are made with high-quality PU leather that will keep your tablet safe from scratches and other damage. Our Fire tablet 8 case will keep your Kindle Fire device safe and sound for years. This lightweight Kindle Fire 8 case is the perfect way to protect your device without adding bulk. STUNNING DESIGN: This Fire Tablet case has a beautiful design that is both functional and fashionable. Our Amazon Fire tablet case is the perfect way to show off your device's sleek style! With its upscale look and unique design, this Fire HD 8 case is perfect for any occasion. The quality of the PU leather material gives Kindle Fire hd 8 plus cover a luxurious feel! With multiple colors of tablet cover available, you'll be able to show off your individuality! SMART FEATURES: With a magnetic strip built-in, our Amazon Fire 8 tablet case automatically wakes up or goes to sleep when the lid is opened or closed. Two card pockets on the inside of our Kindle Fire HD 8 case, are ideal for storing credit cards or cash. The Amazon tablet case comes with an extra hand strap, so you can hold onto it easier. Our Amazon Fire HD 8 tablet case has a handy pen holder, so you can securely store your stylus or pen in there, for faster access. SECURE STAND: The Amazon Fire tablet 8 case has a built-in adjustable flip stand. Our Fire HD 8 plus cover lets you angle your screen to make typing or watching videos more comfortable. This Amazon Fire HD 8 case can be flipped to type with two hands by simply using the built-in stand. The Fire 8 case is great for watching videos on your tablet. Kindle Fire cover will keep the screen upright and stable, on any exterior!", 'AZMKIMI Universal Remote Replacement for Roku Player 1 2 3 4 Premiere/+ Express/+ Ultra with 9 More Learning Keys Programmed to Control TV/Soundbar/Receiver (NOT for Any Ro-ku Stick or Ro-ku TV) ★COMPATIBILITY---AZMKIMI universal replacement remote control compatible with Roku player 1, 2, 3, 4, Express, Express+, Premier, Premier+, Ultra (for keys Power, Mute, Vol+/-, Source, CH+/-). ★EASY TO USE---This universal replacement remote control compatible with Roku remote control including shortcut app keys, simplify your life. ★ONE FOR ALL REMOTE----There are 9 programmable buttons easy to program (Power, vol+/-, mute, A&B self-determined buttons). You can use the learning feature to fully customise this remote, by learning functions directly from your original remote control your devices all in one. You can set up it easily with the instruction. ★KINDLY NOTICE---Not for Roku stick or built-in Roku smart TV. Without earphone jack, pairing button, voice search and game. N ...
# Reference IDs: ['B0899NYH3J', 'B0B45TXPPJ', 'B0B1CS593J', 'B09W9JMJ3L']
# ----------------------------------------
# ID: cad28463-0f4a-4755-86fb-0d4cf711b167
# Inputs: {'question': 'Is there any product that provides a flashlight feature integrated into a smartwatch?'}
# Outputs: {'ground_truth': 'Yes. The EIGIIS military smart watch (B0CH4ZTTJJ) includes a small LED flashlight on the side intended for outdoor use.', 'reference_context_ids': ['B0CH4ZTTJJ'], 'reference_description': ['Military Smart Watch for Men with LED Flashlight 1.45” Rugged Waterproof Smart Watch with 100+ Sports Modes Fitness Tracker with Heart Rate Sleep Monitor Tactical Smartwatch for iPhone Samsung 【YOUR ADVENTURE COMPANION WITH FLASHLIGHT】- EIGIIS military smart watches for men has military-grade standard certification, including -40°C cold resistance, 240-hour moisture resistance, freezing rain resistance, 70°C heat resistance, 96-hour salt spray resistance, impact resistance, etc. In addition, the EIGIIS rugged smart watch is equipped with a small flashlight on the side, adding practical function for your outdoor adventure and helping you light the road in the wilderness. 【SUPPORTS 100+ SPORT MODES】- EIGIIS outdoor sports watch supports up to 100+ sports modes tailored for who love sports, including Running, Climbing, Cycling, Basketball, etc. Whether you’re sweating on the court or riding through the fields, this activity tracker watch can accompany you to enjoy the fun of sports and it will automatically records the steps, heart rate and calories burned. You can check your exercise data on the fitcloudpro app. (Note: The measurement data is FOR REFERENCE ONLY) 【BLUETOOTH CALLING & SMART NOTIFICATION】- With the built-in speaker and microphone, this smart watches for men can easily make and receive calls even when the phone is not nearby. In addition, EIGIIS smart watch with text and call can receive message from Skype, WhatsApp, Facebook, LINE, etc. Free up your hands from mobile phone and never miss important texts and calls, especially when driving, jogging, working out, etc. 【HEALTH MONITORING & SLEEP TRACKER】 - EIGIIS fitness tracker watch provides 24/7 heart rate and blood oxygen monitoring to help you better understand your body condition. Besides, EIGIIS men smart watch also has sleep tracker function to analyze your sleep quality. It will upload your data to FitCloudPro APP, keeps your health always in your eyes. FOR SPORTS OR AVIATION USE ONLY, NOT FOR MEDICAL USE. 【MORE PRACTICAL FUNCTIONS】- EIGIIS multifunctional smartwatch provides various functions to facilitate your life, including pedometer,alarm reminder, remote camera control, find your phone and voice assistant. In addition, EIGIIS Android smart watch is IP67 water resistant that allows you to wash your hands or dishes with the watch. (Note: Don’t use it while diving, sauna, shower,etc.) 【HIGH COMPATIBILITY AND AFTER-SALES SERVICE】- EIGIIS tactical smartwatch is compatible with iOS 10.0 and Andorid 8.0 or above devices. EIGIIS is committed to providing quality after-sales service. EIGIIS provides 12 months quality guarantee for the military smart watch. If you encounter any problems in the process of using the product, please contact us by email, we will definitely help you solve the problem.']}
# Reference IDs: ['B0CH4ZTTJJ']
# ----------------------------------------
# ID: 71f30677-7e0e-473e-b0ab-93a3c9b9fa7d
# Inputs: {'question': 'Can I use the Dymo metallic label tape outdoors and what surface prep is recommended?'}
# Outputs: {'ground_truth': 'The metallic label tape is water-resistant, tear- and wear-resistant and sticks well to flat, dry surfaces. The seller recommends cleaning the surface of oil or dirt and flattening the label to ensure adhesion.', 'reference_context_ids': ['B08LYX8BZ3'], 'reference_description': ['4-Pack Replace for Dymo Label Maker Refills Metallic Letratag Labeling Tape 91338, Black Print on Metallic Silver Tape, 12mm x 4m - 1/2" x 13\', Work with Dymo Label Maker LT-100H LT-110T QX50 LT-200B Package Includes: 4-Pack compatile with dymo letratag refills black on metallic silver label tape 91338. Width: 1/2 inch (12mm) each; Length: 13 feet (4m) each. Compatible with dymo label printer: LT-100H, LT-100T, LT-110T, LT-200B, LT-100H Plus, LT-100T Plus, QX50, XR, XM, 2000. Easy to Peel: Split back design makes the compatible with dymo letra tag labels 12mmx4m- 1/2 x 13 tape easy to peel and apply. Wonfoucs lt metallic plastic labels are water resistant, tear-resistant and wear resistant and create clear, highly visible text. These replacement for dymo letratag label maker refills 1/2 x 13 are suitable for long-lasting applications. Perfect for using in home, office, school and so on, labeling files, folders, shelves, books, cabinets, accessories, etc. Add texture to your labeling work with unique metallic silver look. Our compatible dymo metallic label maker refills stick well on flat and dry surfaces. So please clean the surface of the object to make it free of oil or dirty before you stick the tapes, then flattened the label tape.']}
# Reference IDs: ['B08LYX8BZ3']
# ----------------------------------------
# ID: e9224f21-5749-4c60-920d-d2db24a8905d
# Inputs: {'question': 'Which listed products explicitly include a warranty or customer service guarantee?'}
# Outputs: {'ground_truth': 'Several listings include guarantees: the KNOWSQT keyboard (B0BRQRS9BM) promises 1-year warranty and 12-hour response; BLACKSYNCZE cables (B0BQXLF477) include a full lifetime warranty and 24/7 service; the Intel AX210 adapter (B0B4T696W5) offers one-year warranty and lifetime tech support; CoStySee headphone stand (B09TZPTR9N) includes 60-day returns and 12-month warranty.', 'reference_context_ids': ['B0BRQRS9BM', 'B0BQXLF477', 'B0B4T696W5', 'B09TZPTR9N'], 'reference_description': ["KNOWSQT Wired Computer Keyboard - Milk Tea Colorful Full-Size Round Keycaps Typewriter Keyboards for Windows, Laptop, PC, Desktop, Mac ▥【Milk tea colorful Wired Computer Keyboard】most popular color of 2022, to attract more people's eyes, give you a different vision, enjoy a different keyboard experience, create a colorful desk, and be a pleasant mood for you! ▥【USB Cable Connection & More Stable】Cable length 65inch, plug and play, no need to install other software, no delays or Drop the line, Make your desk surface more neat and tidy, Keyboard just insert a single USB port to use your USB Wired Keyboard! ▥【Detachable Keycaps & Floating Button Design】All buttons can be disassembled, put in water to clean, and also equipped with a brush to clean the garbage on the keyboard. The floating button design gives you a soft and quiet feeling, and takes you back to the most original type of Typewriter Style! ▥【Wide Compatibility】Wired Computer Keyboard are perfectly compatible with Windows 10 / 8 / 7 / XP/ Vista operating system (USB 2.0 port). The Wired keyboard work with PC, Mac, Desktop, Laptop, Notebook, Chrome-Book, Computers, Smart TVs, etc. It is the best choice for personal offices and corporate businesses! ▥【Any Refunds and Questions will Reply to you within 12 Hours】 Whether it's exceeding Amazon's return time or receiving a defective product, Or anything product problem, please contact us through Amazon email for the first time, and we will provide you with satisfactory solutions. ❤1 Year Warranty❤", 'BLACKSYNCZE USB C to Lightning Cable 2Pack 6FT, [MFi Certified] iPhone Charger Cord USB C Nylon Braided Type C to Lightning Cable Fast Charging for iPhone 13 12 11 Pro Max XR XS X 8 7 6s, SE2020 [MFi Certified iPhone Cable] This USB C to Lightning Cable features an upgraded C94 connector and original MFi chip for seamless compatibility and no pop-up error messages; protects your devices from overcurrent and overvoltage while charging. [20W PD Fast Charging Cable] With 20W PD fast charging, this iPhone Charger Fast Charging Cable can charge an iPhone 13 or 12 up to 50% in just 30 minutes, which is 2.5 times faster than a standard lightning cable (5V/1A). [Durability & Flexibility] Includes built-in overvoltage and overcurrent protection and features a durable design with reinforced joints, silver-plated connectors, and a triple layer of braided nylon; withstands over 12,000 bends in laboratory tests. [Wide Compatibility] This Lightning Cable USB C is widely compatible with fast-charging support for iPhone 13 Pro Max, 13 Pro, 13, 13 Mini, 12 Pro Max, 12 Pro, 12, 12 Mini, 11 Pro Max, 11 Pro, 11 iPhone XR, XS, Max, XS, X, SE2020, iPhone 8 Plus, and 8; also supports standard charging for iPhone 7 Plus, 7, 6s Plus, 6s, 6 Plus, 6, 5s, 5c, 5 SE, etc. [What You Get] Includes 2 Pack 6FT BLACKSYNCZE Type C to Lightning Cable with full lifetime warranty and friendly 24/7 customer service.', 'Intel AX210 IEEE 802.11ax Bluetooth 5.2 Tri Band Wi-Fi/Bluetooth Combo Adapter for Notebook 【Wi-Fi 6E】With Intel Wi-Fi 6E technology network adapter provides strong performance and good compatibility, while reducing power consumption and improving service life. 【AX210 NGW Wireless LAN Card】Provides tri-band (6GHz, 5GHz and 2.4GHz) signal. Maximum speed up to 5374Mbps(2400Mbps @6GHz + 2400Mbps @5GHz + 574Mbps @2.4GHz). 【Bluetooth 5.3】Based on Bluetooth 5.2, Bluetooth 5.3 adds LE enhanced connection/Host set Controller key length function/LE channel h ...
# Reference IDs: ['B0BRQRS9BM', 'B0BQXLF477', 'B0B4T696W5', 'B09TZPTR9N']
# ----------------------------------------
# ID: 125d4631-b0eb-461b-a716-08e293262657
# Inputs: {'question': 'Which earbuds cases in the product list have a security lock or anti-lost keychain?'}
# Outputs: {'ground_truth': 'The TRIDENITE-styled protective case (SKTDWEI listing B0B7FFK66G) includes a safety lock design and a keychain/lanyard to prevent loss. The Gyehuo AirPods cow design case (B0B5GPCS2V) also includes a metal keychain for carrying.', 'reference_context_ids': ['B0B7FFK66G', 'B0B5GPCS2V'], 'reference_description': ["SKTDWEI Compatible with Samsung Galaxy Buds Pro Case/Galaxy Buds Live/Galaxy Buds 2/Galaxy Buds 2 Pro Protective Case with Lock Hard Shell Rugged Shockproof Cover with Keychain and Lanyard (Blue) 🎧【Compatible】：The security locks case covers specially designed for Samsung Galaxy Buds Live(2020)/Galaxy Buds Pro(2021)/Galaxy Buds 2 (2021)/Galaxy Buds 2 Pro (2022) wirless earphone . 🎧【Military Grade TPU 】：Made of high quality and environment-friendly PC material.soft and durable in use.Washable and easy to clean.Brighten your wife's, girlfriend's, husband's, boyfriend's or kid's day with a security locks case gift. 🎧【All-inclusive Protection】：The four corners are wrapped with a double-layer air cushion structure,Soft and lightweight protector protect your earbuds from slipping, cracking, scratching, dusting and washable,Gives the maximum protection. 🎧【Safety Lock Unique Design】：The earphone shell is composed of upper and lower shells with a split structure, and the front has a safety lock function. Press the lock button on the front to automatically open the top cover.The charging port is reserved, which can be charged without disassembling the case,The front LED is visible. 🎧【Anti-lost with Portable Keychain】：The cover comes with a keychain, which easily attach to your bag, purse or belt loop, you can carry your earbuds everywhere without losing them.You will get 1*Protective Case, 1*Carabiner Clip,1*Lanyard. (Charging Case NOT included.)", "Gyehuo for Airpod Case, Compatible with Apple AirPods 2nd & 1st Generation Case (Cow) 【Perfectly Fit】 Compatible with Apple AirPods 1st & AirPods 2nd generation case. The AirPods case cover fits tightly without worrying about the AirPod case coming loose or coming off 【360° Full Protection】This AirPods case protective cover made of premium flexible material,protects your AirPods against bumps, drops and scratches 【Fashion Design】The cute AirPods case is protected by a protective PET film. Bright and lovely patterns don't fade with time 【Convenient Charging & Portable Keychain】 Charge your airpods without removing the cover. Comes with a metal Keychain, making it convenient and secure to carry your AirPod 2 & 1 anywhere 【Our Service】The airpod case is returnable in 30 days, please don’t hesitate to contact us if you have any question about our product. We will always offer the best solutions"]}
# Reference IDs: ['B0B7FFK66G', 'B0B5GPCS2V']
# ----------------------------------------
# ID: b6aded32-540b-463f-ab29-4c2f040c8b43
# Inputs: {'question': 'Can the ARMIDO wireless WiFi PTZ 1080p bulb camera be used outdoors and does it support motion tracking?'}
# Outputs: {'ground_truth': 'Partially. The ARMIDO listing (B0B8QV4DTS) indicates it supports PTZ 1080p and motion detection; a separate bulb-camera listing (B0BK841MXT) describes a 3MP outdoor light-bulb security camera with motion detection, pan/tilt, and night vision. Together they suggest the line includes outdoor-capable bulb cameras with motion detection and tracking.', 'reference_context_ids': ['B0BK841MXT', 'B0B8QV4DTS'], 'reference_description': ['2 Pack 3MP Light Bulb Security Camera Wireless Outdoor, 360° Indoor WiFi Smart Light Socket Cameras for Home Security Cameras with Motion Detection and Alerts, 2-Way Audio, Compatible with Alexa 【3MP HD & Clear Night Vision】- 3MP surveillance light bulb security camera is able to provide clearer and more detailed images, which helps you get rid of blurred image quality. The WiFi Pan Tilt Camera Upgrade Hd Night Vision Function, and the infrared night vision and white light night vision can be switched freely, camera light bulb You Can See Clear Images Even In Complete Darkness.Only supports 2.4Ghz WiFi (5Ghz WiFi is not supported). 【Motion Detection & Real-time Alerts】This smart camera wifi outdoor build-in highly sensitive motion sensor detect moving object.If someone breaks into your home,The camera will follow him and sound an alarm.Give your home a protection. 【Two-Way Audio and High Quality Service】The security camera outdoor wifi built-in microphone and speaker, the bulb security camera can have a conversation between you and your visitor,If you have any question, please contact us.We provide lifetime technical support and services. 【Wireless and Easy To Install】This camera can be installed using a normal E27 bulb base(110V~240V),Our cameras also come with a connector that allows you to easily mount our cameras on the socket.Then use the mobile phone to download the APP, and use the APP to help the camera connect to the WIFI. No other operations are required. Note that it takes about 40s to connect the bulb security camera for the first time. 【Pan/Tilt Capacity & Remote Access】 - wireless security camera rotates 355° horizontally and flips 90° vertically, allowing you to control the viewing angle of the camera via the APP to realize 360° observation. You can remotely view the surveillance screen in the camera via the mobile APP anytime, anywhere. Bulb security camera supports cloud storage and micro SD card storage (the camera does not come with an SD card, and cloud storage needs to be paid).', 'ARMIDO Wireless WiFi PTZ 1080p Light Socket Bulb Security Camera Floodlight Night Vision Motion Detection Two-Way Audio 2.4Ghz and 5Ghz Support ']}
# Reference IDs: ['B0BK841MXT', 'B0B8QV4DTS']
# ----------------------------------------
# ID: 0b58c878-c30d-448b-bf29-20d66f59acaa
# Inputs: {'question': 'Does the 4-in-1 Ethernet adapter support Fire TV Stick 4K and provide simultaneous USB data transfer?'}
# Outputs: {'ground_truth': 'Yes. The 4-in-1 Ethernet Adapter is designed for Fire TV Stick 4K and similar streaming sticks, supports 10/100M wired Ethernet, and offers 3 USB ports with simultaneous 480 Mbps data transfer capability.', 'reference_context_ids': ['B0B64X77P7'], 'reference_description': ['4 in 1 Ethernet Adapter and 3 Ports USB OTG Hub for Fire TV Stick 4K/Chromecast/Google Home Mini/Raspberry Pi Zero and Other Streaming TV Sticks,Micro USB OTG Cable HUB with Powered Network Adapter Add extra wired Ethernet & USB 3 ports extra storage to your streaming device for connecting wired network,flash drive,wireless keyboard or whatever USB peripherals,Stable work at the same time.(please note: Not compatible with Fire Stick 1, Roku Stick/Express,Fire HD 10,Google Home Mini cellphones, tablets, and Laptops,USB only for charging.) Support 10/100M wired network Ethernet connection, faster and more stable，and 3 ports (480Mbps) of Simultaneous data transfer possible.no buffering, no lag. 4-in-1 integrated design, no need to combine, the signal transmission is more stable. The length is 3.3 ft. It is easy to operate and allows you to place it anywhere without worrying about loose connections. Plug & Play,no additional driver/software needed. Just need to connect it to an available devices and LAN network, it will be activated. Compatible with Fire TV Stick 4K,Streaming TV Sticks,Google Home Mini, Media Players,Chromecast Ultra / 3 / 2 / 1 / Audio,Raspberry Pi Zero, and Support Micro USB port TV stick,etc.']}
# Reference IDs: ['B0B64X77P7']
# ----------------------------------------
# ID: d46b9668-df91-4a5b-b6ea-32cfd527b83a
# Inputs: {'question': 'Are the iPhone MFi-certified 3-pack lightning cables guaranteed compatible with iPhone 11/12/13 series?'}
# Outputs: {'ground_truth': 'The listing presents a 3-pack of MFi-certified lightning cables claiming compatibility with iPhone 11/12/13 series and older models, indicating they should work without pop-up errors.', 'reference_context_ids': ['B096BND451'], 'reference_description': ['iPhone Charger Lightning Cable 3Pack Quick Charger Rapid Cord Apple MFi Certified Compatible iPhone 11 Pro X XR XS MAX 8 Plus 7 6s 5s 5c Air Mini iPod ']}
# Reference IDs: ['B096BND451']
# ----------------------------------------
# ID: 3701ea0c-e74a-45c0-9001-df8f6b699e46
# Inputs: {'question': 'Does the TESSAN 15ft flat plug extension cord have surge protection and how many USB ports?'}
# Outputs: {'ground_truth': 'Yes. The TESSAN flat extension has 1700 joules surge protection, 6 widely spaced AC outlets, and 3 USB ports (each up to 5V/2.4A, total 3A/15W).', 'reference_context_ids': ['B09V24G4F8'], 'reference_description': ['Flat Plug Extension Cord 15 Ft, TESSAN Surge Protector Power Strip with 6 Outlets and 3 USB Ports, 1700 Joules, Desktop Black Long Power Cord for Indoor Home Office School Dorm Room Essential 15ft Flat Extension Cord: The long power strip 15 ft cord flexibly provides sufficient cord length to cover your outlets to reach the remote places such as living room, office; 45° degree convenient space-saving low profile flat head fits in tight spaces like behind furniture, bookshelves, desks or anything Multiple Safety Protection: This power strip surge protector built-in 1700 joules protection reliably protects your electrical appliances from lightning, power surges, and spikes; An integrated circuit breaker enables you to trip off automatically when your rated power exceeds 1625W to make this outlet strip from circuit overload Extension Cord with Multiple Outlets: 6 widely spaced AC outlets are separated enough to fit big plugs and have 3 USB ports that could charge up to 9 electrical devices simultaneously without blocking each other; Could be as a desktop power strip to make your various needs USB Charging Station: This power strip with USB has 3 USB charging ports, provides 5V 2.4A max each port, 3A 15W in total; Could charge for all your required USB devices, such as cellphone, laptop, tablet, camera, etc Suitable for Any Occasions: Our convenient multiple outlet power hub is suitable for the office, bedroom, living room, and college dorm room']}
# Reference IDs: ['B09V24G4F8']
# ----------------------------------------
# ID: fe7cccc4-5b0e-4912-a731-f78a8569d8c4
# Inputs: {'question': 'Is the BAGSMART laptop backpack machine washable and what laptop size does it fit?'}
# Outputs: {'ground_truth': 'Yes — the BAGSMART quilted laptop backpack is machine-washable (gentle cycle), fits up to a 15.6" laptop, and includes an anti-theft back pocket, padded straps, and organized internal pockets.', 'reference_context_ids': ['B09BCFY3F2'], 'reference_description': ["BAGSMART Travel Laptop Backpack, Quilted Work Bookbag Fits 15.6 Inch Laptop, Laptop Backpack with Charging Port Hole, Lightweight Bookbag for College Work Business, Classic Black Quilted Fabrication: This functional collage backpack features a slouchy silhouette and quilted fabrication. It's lightweight yet durable and comes in a variety of colorful patterns. Versatile and made to carry-it-all, this bookbag can be toted to and from collage, taken on a hike, or thrown on before commuting. Smart Internal Organization: The laptop backpack has a spacious main compartment to hold all your daily essentials. Featuring plenty of organizational pockets, it will help you pack more efficiently while keeping the contents of your bag organized. Unparalleled Carrying Comfort: Its lightweight body (600g) is structured with contoured and padded shoulder straps for excellent fit and an air mesh back panel for ventilation, ensuring all-day comfort. Machine Washable Fabric: The back pack is made of sleek & lightweight quilted cotton. These solid colors bring style & function to your everyday life, allowing for a spin on a gentle cycle in the washing machine. Close at Hand, Far from Pickpockets: Keep pickpockets at bay by storing your valuables in the anti-theft pocket at the back. It's thoughtfully designed for stowing your wallet, passport, and other necessities. THIS ITEM IS NOT INTENDED FOR USE BY CHILDREN 12 AND UNDER"]}
# Reference IDs: ['B09BCFY3F2']
# ----------------------------------------
# ID: 60471033-e6ac-4e08-98a3-8bfc8dd5e0c1
# Inputs: {'question': 'Are the rose gold birthday backdrop and tablecloth reusable and what sizes are they?'}
# ...
# Reference IDs: ['B0CGV9LQB8']
# ----------------------------------------
# ID: 489fcced-66a6-4bf6-b9c0-4e13a2ac60eb
# Inputs: {'question': 'How many ARGB fans come preinstalled in the KEDIERS C590 PC case?'}
# Outputs: {'ground_truth': 'The KEDIERS C590 case comes with 9 pre-installed 120mm ARGB fans and an ARGB controller; synchronization requires connecting the 5V-3PIN cable to the motherboard.', 'reference_context_ids': ['B0B2JT5B86'], 'reference_description': ["KEDIERS PC Case - ATX Tower Tempered Glass Gaming Computer Case with 9 ARGB Fans,C590 [9 Pre-Installed 120mm ARGB Fans]-- Suitable for enhanced cooling. With the pre-installed ARGB controller you can sync it with the motherboard, each addressable ARGB fan offers 16.8 million colors for exceptional customizable lighting. You don't need to pay extra for fans. Only when the 5V-3PIN cable on the control board is connected to the motherboard can the ARGB light synchronization be realized. [2 Tempered glass]-- C590 gaming case is equipped 2 * 4mm thick tempered glass, which can clearly see the RGB lighting and the components in the building, Creating a good gaming atmosphere. [I/O Panel]-- 2 x USB3.0 Port, 1 x Type C, 1 x HD Audio, Reset Button, Power Button. [Cable Management]-- Back Bays: 3x 3.5'' HDD's and 3 x 2.5'' SSD's. Removable storage cable box;Designed reasonable back routing hole. [Remarkable Expansion]-- C590 Mid Tower Gaming Computer Case supports ATX/Micro-ATX/Mini-ITX motherboards. [Package]-- 1* computer case /9* ARGB FANS /1* Multifunctional RGB remote control."]}
# Reference IDs: ['B0B2JT5B86']
# ----------------------------------------
# ID: 7e6ed45d-8143-4df3-87da-3d7ebb77103e
# Inputs: {'question': 'Are the BLACKSYNCZE USB-C to Lightning cables MFi certified and what charging speed do they support?'}
# Outputs: {'ground_truth': 'Yes — they are MFi certified with a C94 connector and support 20W PD fast charging, capable of charging an iPhone 12/13 to ~50% in about 30 minutes.', 'reference_context_ids': ['B0BQXLF477'], 'reference_description': ['BLACKSYNCZE USB C to Lightning Cable 2Pack 6FT, [MFi Certified] iPhone Charger Cord USB C Nylon Braided Type C to Lightning Cable Fast Charging for iPhone 13 12 11 Pro Max XR XS X 8 7 6s, SE2020 [MFi Certified iPhone Cable] This USB C to Lightning Cable features an upgraded C94 connector and original MFi chip for seamless compatibility and no pop-up error messages; protects your devices from overcurrent and overvoltage while charging. [20W PD Fast Charging Cable] With 20W PD fast charging, this iPhone Charger Fast Charging Cable can charge an iPhone 13 or 12 up to 50% in just 30 minutes, which is 2.5 times faster than a standard lightning cable (5V/1A). [Durability & Flexibility] Includes built-in overvoltage and overcurrent protection and features a durable design with reinforced joints, silver-plated connectors, and a triple layer of braided nylon; withstands over 12,000 bends in laboratory tests. [Wide Compatibility] This Lightning Cable USB C is widely compatible with fast-charging support for iPhone 13 Pro Max, 13 Pro, 13, 13 Mini, 12 Pro Max, 12 Pro, 12, 12 Mini, 11 Pro Max, 11 Pro, 11 iPhone XR, XS, Max, XS, X, SE2020, iPhone 8 Plus, and 8; also supports standard charging for iPhone 7 Plus, 7, 6s Plus, 6s, 6 Plus, 6, 5s, 5c, 5 SE, etc. [What You Get] Includes 2 Pack 6FT BLACKSYNCZE Type C to Lightning Cable with full lifetime warranty and friendly 24/7 customer service.']}
# Reference IDs: ['B0BQXLF477']
# ----------------------------------------
# ID: 37c4dd8e-0af6-478f-9715-7467cb753491
# Inputs: {'question': 'Does the KNOWSQT wired keyboard require drivers to work on Windows?'}
# Outputs: {'ground_truth': 'No. It’s a plug-and-play USB wired keyboard and doesn’t require additional software installation for use.', 'reference_context_ids': ['B0BRQRS9BM'], 'reference_description': ["KNOWSQT Wired Computer Keyboard - Milk Tea Colorful Full-Size Round Keycaps Typewriter Keyboards for Windows, Laptop, PC, Desktop, Mac ▥【Milk tea colorful Wired Computer Keyboard】most popular color of 2022, to attract more people's eyes, give you a different vision, enjoy a different keyboard experience, create a colorful desk, and be a pleasant mood for you! ▥【USB Cable Connection & More Stable】Cable length 65inch, plug and play, no need to install other software, no delays or Drop the line, Make your desk surface more neat and tidy, Keyboard just insert a single USB port to use your USB Wired Keyboard! ▥【Detachable Keycaps & Floating Button Design】All buttons can be disassembled, put in water to clean, and also equipped with a brush to clean the garbage on the keyboard. The floating button design gives you a soft and quiet feeling, and takes you back to the most original type of Typewriter Style! ▥【Wide Compatibility】Wired Computer Keyboard are perfectly compatible with Windows 10 / 8 / 7 / XP/ Vista operating system (USB 2.0 port). The Wired keyboard work with PC, Mac, Desktop, Laptop, Notebook, Chrome-Book, Computers, Smart TVs, etc. It is the best choice for personal offices and corporate businesses! ▥【Any Refunds and Questions will Reply to you within 12 Hours】 Whether it's exceeding Amazon's return time or receiving a defective product, Or anything product problem, please contact us through Amazon email for the first time, and we will provide you with satisfactory solutions. ❤1 Year Warranty❤"]}
# Reference IDs: ['B0BRQRS9BM']
# ----------------------------------------
# ID: c8570c19-4a31-4207-9266-0bafe96a95dc
# Inputs: {'question': 'Will the Gyehuo AirPods cow design case allow charging without removal?'}
# Outputs: {'ground_truth': 'Yes. The Gyehuo AirPods case permits charging without removing the cover and includes a metal keychain for portability.', 'reference_context_ids': ['B0B5GPCS2V'], 'reference_description': ["Gyehuo for Airpod Case, Compatible with Apple AirPods 2nd & 1st Generation Case (Cow) 【Perfectly Fit】 Compatible with Apple AirPods 1st & AirPods 2nd generation case. The AirPods case cover fits tightly without worrying about the AirPod case coming loose or coming off 【360° Full Protection】This AirPods case protective cover made of premium flexible material,protects your AirPods against bumps, drops and scratches 【Fashion Design】The cute AirPods case is protected by a protective PET film. Bright and lovely patterns don't fade with time 【Convenient Charging & Portable Keychain】 Charge your airpods without removing the cover. Comes with a metal Keychain, making it convenient and secure to carry your AirPod 2 & 1 anywhere 【Our Service】The airpod case is returnable in 30 days, please don’t hesitate to contact us if you have any question about our product. We will always offer the best solutions"]}
# Reference IDs: ['B0B5GPCS2V']
# ----------------------------------------
# ID: d7957268-7b4b-48cf-9087-fc0dc1557a7b
# Inputs: {'question': 'Is the SunFounder starter kit suitable for young beginners?'}
# Outputs: {'ground_truth': 'Yes — it’s marked suitable for ages 8+ and designed for beginners with progressive learning resources and expert-designed courses.', 'reference_context_ids': ['B0B778L1DZ'], 'reference_description': ['SunFounder Ultimate Starter Kit Compatible with Arduino UNO IDE Scratch, 3 in 1 IoT/Smart Car/Basic Kit with Online Tutorials, Video Courses, 192 Items, 87 Projects, Suitable for Age 8+ Beginners Expert-Designed Courses: Teaming up with Circuit Basics, SunFounder 3-in-1 Starter Kit offers comprehensive videos and online tutorials for well-rounded learning. Suitable for age 8+ beginners. Complete Component Kit: Our kit includes high quality sensors, actuators, power supplies, and an Arduino-compatible Uno for diverse projects and skill-building. Progressive Learning Journey: With Circuit Basics, the courses cater to your skill level, covering essentials and advancing to complex topics like IoT, robot cars, and sensor integration. Engaging Projects: Apply your knowledge through hands-on projects, ranging from simple LED blinking to advanced robot car, IoT applications, for skill development and confidence-building. Dedicated Support: Benefit from our ongoing assistance, including a community forum and timely technical help for a seamless learning experience.']}
# Reference IDs: ['B0B778L1DZ']
# ----------------------------------------
# ID: 72a42438-e064-4872-b83b-68817581d632
# Inputs: {'question': 'How many items and projects are included in the SunFounder Ultimate Starter Kit?'}
# Outputs: {'ground_truth': 'The kit includes 192 items and supports 87 projects, along with online tutorials and video courses.', 'reference_context_ids': ['B0B778L1DZ'], 'reference_description': ['SunFounder Ultimate Starter Kit Compatible with Arduino UNO IDE Scratch, 3 in 1 IoT/Smart Car/Basic Kit with Online Tutorials, Video Courses, 192 Items, 87 Projects, Suitable for Age 8+ Beginners Expert-Designed Courses: Teaming up with Circuit Basics, SunFounder 3-in-1 Starter Kit offers comprehensive videos and online tutorials for well-rounded learning. Suitable for age 8+ beginners. Complete Component Kit: Our kit includes high quality sensors, actuators, power supplies, and an Arduino-compatible Uno for diverse projects and skill-building. Progressive Learning Journey: With Circuit Basics, the courses cater to your skill level, covering essentials and advancing to complex topics like IoT, robot cars, and sensor integration. Engaging Projects: Apply your knowledge through hands-on projects, ranging from simple LED blinking to advanced robot car, IoT applications, for skill development and confidence-building. Dedicated Support: Benefit from our ongoing assistance, including a community forum and timely technical help for a seamless learning experience.']}
# Reference IDs: ['B0B778L1DZ']
# ----------------------------------------
# ID: 10286d86-25d2-4bd0-ba93-1ecb406e6d97
# Inputs: {'question': 'What materials and protection does the Samsung T7 carrying case offer?'}
# Outputs: {'ground_truth': "The case is made of hard EVA and PU material with an ultra-soft velvet interior lining; it's waterproof and shockproof to protect the Samsung T7 from extrusion, dust, splashes, scratches, bumps, and drops.", 'reference_context_ids': ['B01N1P97SL'], 'reference_description': ['BOVKE Travel Carrying Case for Samaung T7 Shield / T7 / T7 Touch Portable SSD 500GB 1TB 2TB USB 3.2 External Solid State Drives, Extra Mesh Pocket for USB Cables and More Accessories, Black Case Only! ( samsung ssd & accessories not included )This external hard drive case perfectly fit for: Samsung T7 Shield Portable SSD, Samsung T7 Portable SSD, Samsung T7 Touch 500GB 1TB 2TB USB 3.2 Portable Solid State Drives, provide excellent protection, keeps the solid state external hard drives safe from damage and prolongs the service life of your T7 external ssd. This samsung t7 case bag is featured with 2 elastic bands inside, securely store the samsung t7 shield portable ssd, and the T7 Carrying Case can prevent the Samsung external ssd from falling, protects your external solid state drives from tossing around while on the go, gives your portable ssd great protection. This T7 shield hard drive carrying case comes with a mesh pocket to accommodate the USB cables of the Samsung T7 Touch Portable SSD drive and other small accessories. The double zippers of the t7 case are smooth enough for easy opening and closing, offer you excellent using experience. This samsung ssd case is made of hard EVA and PU material, with good waterproof and shockproof, protects your samsung portable ssd from extrusion, dust and splashing, Interior velevt lining is ultra soft, provides great protection for your Samsung T7 ssd external hard drive from scratches, bumping and droping. Dimension: 5.42 x 3.01 x 1.21 inches, compact and lightweight, this Samsung T7 shield ssd case holder comes with a sturdy lanyard and a carabiner to provide various ways to carry, the samsung t7 storage case can be put in your pocket or bag, or you can also hang this T7 ssd bag on your backpack, convenient to use.']}
# Reference IDs: ['B01N1P97SL']
# ----------------------------------------
# ID: 342e32cf-1597-474c-ab3a-f7b00025e9bc
# Inputs: {'question': 'Does the BOVKE carrying case fit the Samsung T7 Shield and other T7 models?'}
# Outputs: {'ground_truth': 'Yes. The BOVKE Travel Carrying Case is designed to perfectly fit the Samsung T7 Shield, Samsung T7, and Samsung T7 Touch (500GB/1TB/2TB) portable SSDs and provides interior elastic bands and a mesh pocket for cables.', 'reference_context_ids': ['B01N1P97SL'], 'reference_description': ['BOVKE Travel Carrying Case for Samaung T7 Shield / T7 / T7 Touch Portable SSD 500GB 1TB 2TB USB 3.2 External Solid State Drives, Extra Mesh Pocket for USB Cables and More Accessories, Black Case Only! ( samsung ssd & accessories not included )This external hard drive case perfectly fit for: Samsung T7 Shield Portable SSD, Samsung T7 Portable SSD, Samsung T7 Touch 500GB 1TB 2TB USB 3.2 Portable Solid State Drives, provide excellent protection, keeps the solid state external hard drives safe from damage and prolongs the service life of your T7 external ssd. This samsung t7 case bag is featured with 2 elastic bands inside, securely store the samsung t7 shield portable ssd, and the T7 Carrying Case can prevent the Samsung external ssd from falling, protects your external solid state drives from tossing around while on the go, gives your portable ssd great protection. This T7 shield hard drive carrying case comes with a mesh pocket to accommodate the USB cables of the Samsung T7 Touch Portable SSD drive and other small accessories. The double zippers of the t7 case are smooth enough for easy opening and closing, offer you excellent using experience. This samsung ssd case is made of hard EVA and PU material, with good waterproof and shockproof, protects your samsung portable ssd from extrusion, dust and splashing, Interior velevt lining is ultra soft, provides great protection for your Samsung T7 ssd external hard drive from scratches, bumping and droping. Dimension: 5.42 x 3.01 x 1.21 inches, compact and lightweight, this Samsung T7 shield ssd case holder comes with a sturdy lanyard and a carabiner to provide various ways to carry, the samsung t7 storage case can be put in your pocket or bag, or you can also hang this T7 ssd bag on your backpack, convenient to use.']}
# Reference IDs: ['B01N1P97SL']
# ----------------------------------------

# %%
from langsmith import Client

client = Client()
dataset_id = "b9bb66b2-c479-4584-8177-f1b746173f48"

for example in client.list_examples(dataset_id=dataset_id):
    ids = example.outputs.get("reference_context_ids") or []
    if not ids:
        print("Missing reference_context_ids:", example.id)
# Out:
# Missing reference_context_ids: d4789a6f-68cd-4acf-89ba-291427fc36af
