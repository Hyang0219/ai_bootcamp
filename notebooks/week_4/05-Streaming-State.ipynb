# %%
from pydantic import BaseModel, Field

from qdrant_client import QdrantClient
from qdrant_client.models import Prefetch, Filter, FieldCondition, MatchText, FusionQuery, Document

from langsmith import traceable, get_current_run_tree

from langgraph.graph import StateGraph, START, END
from langgraph.prebuilt import ToolNode
from langgraph.types import Send, Command

from langchain_core.messages import AIMessage, ToolMessage, convert_to_openai_messages

from jinja2 import Template
from typing import Literal, Dict, Any, Annotated, List, Optional, Sequence
from IPython.display import Image, display
from operator import add
from openai import OpenAI

import openai

import random
import ast
import inspect
import instructor
import json

from utils.utils import get_tool_descriptions, format_ai_message

# %% [markdown]
# ### Define Retrieval Tool

# %%
@traceable(
    name="embed_query",
    run_type="embedding",
    metadata={"ls_provider": "openai", "ls_model_name": "text-embedding-3-small"}
)
def get_embedding(text, model="text-embedding-3-small"):
    response = openai.embeddings.create(
        input=text,
        model=model,
    )

    current_run = get_current_run_tree()

    if current_run:
        current_run.metadata["usage_metadata"] = {
            "input_tokens": response.usage.prompt_tokens,
            "total_tokens": response.usage.total_tokens,
        }

    return response.data[0].embedding


@traceable(
    name="retrieve_data",
    run_type="retriever"
)
def retrieve_data(query, k=5):

    query_embedding = get_embedding(query)

    qdrant_client = QdrantClient(url="http://localhost:6333")

    results = qdrant_client.query_points(
        collection_name="Amazon-items-collection-01-hybrid-search",
        prefetch=[
            Prefetch(
                query=query_embedding,
                using="text-embedding-3-small",
                limit=20
            ),
            Prefetch(
                query=Document(
                    text=query,
                    model="qdrant/bm25"
                ),
                using="bm25",
                limit=20
            )
        ],
        query=FusionQuery(fusion="rrf"),
        limit=k,
    )

    retrieved_context_ids = []
    retrieved_context = []
    similarity_scores = []
    retrieved_context_ratings = []

    for result in results.points:
        retrieved_context_ids.append(result.payload["parent_asin"])
        retrieved_context.append(result.payload["description"])
        retrieved_context_ratings.append(result.payload["average_rating"])
        similarity_scores.append(result.score)

    return {
        "retrieved_context_ids": retrieved_context_ids,
        "retrieved_context": retrieved_context,
        "retrieved_context_ratings": retrieved_context_ratings,
        "similarity_scores": similarity_scores,
    }


@traceable(
    name="format_retrieved_context",
    run_type="prompt"
)
def process_context(context):

    formatted_context = ""

    for id, chunk, rating in zip(context["retrieved_context_ids"], context["retrieved_context"], context["retrieved_context_ratings"]):
        formatted_context += f"- ID: {id}, rating: {rating}, description: {chunk}\n"

    return formatted_context


def get_formatted_context(query: str, top_k: int = 5) -> str:

    """Get the top k context, each representing an inventory item for a given query.
    
    Args:
        query: The query to get the top k context for
        top_k: The number of context chunks to retrieve, works best with 5 or more
    
    Returns:
        A string of the top k context chunks with IDs and average ratings prepending each chunk, each representing an inventory item for a given query.
    """

    context = retrieve_data(query, top_k)
    formatted_context = process_context(context)

    return formatted_context

# %% [markdown]
# #### State and Pydantic Model for Structured Outputs

# %%
class ToolCall(BaseModel):
    name: str
    arguments: dict

class RAGUsedContext(BaseModel):
    id: str = Field(description="The ID of the item used to answer the question")
    description: str = Field(description="Short description of the item used to answer the question")
    
class AgentResponse(BaseModel):
    answer: str = Field(description="Answer to the question.")
    references: list[RAGUsedContext] = Field(description="List of items used to answer the question.")
    final_answer: bool = False
    tool_calls: List[ToolCall] = []

class State(BaseModel):
    messages: Annotated[List[Any], add] = []
    question_relevant: bool = False
    iteration: int = 0
    answer: str = ""
    available_tools: List[Dict[str, Any]] = []
    tool_calls: List[ToolCall] = []
    final_answer: bool = False
    references: Annotated[List[RAGUsedContext], add] = []

# %%
@traceable(
    name="agent_node",
    run_type="llm",
    metadata={"ls_provider": "openai", "ls_model_name": "gpt-4.1-mini"}
)
def agent_node(state: State) -> dict:

   prompt_template =  """You are a shopping assistant that can answer questions about the products in stock.

You will be given a conversation history and a list of tools you can use to answer the latest query.

<Available tools>
{{ available_tools | tojson }}
</Available tools>

When making tool calls, use this exact format:
{
    "name": "tool_name",
    "arguments": {
        "parameter1": "value1",
        "parameter2": "value2",
    }
}

CRITICAL: All parameters must go inside the "arguments" object, not at the top level of the tool call.

Examples:
- Get formatted item context:
{
    "name": "get_formatted_item_context",
    "arguments": {
        "query": "Kool kids toys.",
        "top_k": 5
    }
}

CRITICAL RULES:
- If tool_calls has values, final_answer MUST be false
(You cannot call tools and exit the graph in the same response)
- If final_answer is true, tool_calls MUST be []
(You must wait for tool results before exiting the graph)
- If you need tool results before answering, set:
tool_calls=[...], final_answer=false
- After receiving tool results, you can then set:
tool_calls=[], final_answer=true
- Use names specificly provided in the available tools. Don't add any additional text to the names.

Instructions:
- You need to answer the question based on the outputs from the tools using the available tools only.
- Do not suggest the same tool call more than once.
- If the question can be decomposed into multiple sub-questions, suggest all of them.
- If multipple tool calls can be used at once to answer the question, suggest all of them.
- Do not explain your next steps in the answer, instead use tools to answer the question.
- Never use word context and refer to it as the available products.
- You should only answer questions about the products in stock. If the question is not about the products in stock, you should ask for clarification.
- As an output you need to return the following:

* answer: The answer to the question based on your current knowledge and the tool results.
* references: The list of the indexes from the chunks returned from all tool calls that were used to answer the question. If more than one chunk was used to compile the answer from a single tool call, be sure to return all of them.
* Each reference should have an id and a short description of the item based on the retrieved context.
* final_answer: True if you have all the information needed to provide a complete answer, False otherwise.

- The answer to the question should contain detailed information about the product and should be returned with detailed specification in bullet points.
- The short description should have the name of the item.
- If the user's request requires using a tool, set tool_calls with the appropriate function names and arguments.
"""

   template = Template(prompt_template)
   
   prompt = template.render(
      available_tools=state.available_tools
   )

   messages = state.messages

   conversation = []

   for message in messages:
        conversation.append(convert_to_openai_messages(message))

   client = instructor.from_openai(OpenAI())

   response, raw_response = client.chat.completions.create_with_completion(
        model="gpt-4.1-mini",
        response_model=AgentResponse,
        messages=[{"role": "system", "content": prompt}, *conversation],
        temperature=0.5,
   )

   ai_message = format_ai_message(response)

   return {
      "messages": [ai_message],
      "tool_calls": response.tool_calls,
      "iteration": state.iteration + 1,
      "answer": response.answer,
      "final_answer": response.final_answer,
      "references": response.references
   }

# %% [markdown]
# #### Tool Router Edge

# %%
def tool_router(state: State) -> str:
    """Decide whether to continue or end"""
    
    if state.final_answer:
        return "end"
    elif state.iteration > 2:
        return "end"
    elif len(state.tool_calls) > 0:
        return "tools"
    else:
        return "end"

# %% [markdown]
# #### Intent Router

# %%
class IntentRouterResponse(BaseModel):
    question_relevant: bool
    answer: str

# %%
@traceable(
    name="intent_router_node",
    run_type="llm",
    metadata={"ls_provider": "openai", "ls_model_name": "gpt-4.1-mini"}
)
def intent_router_node(state: State):

   prompt_template =  """You are part of a shopping assistant that can answer questions about products in stock.

Instructions:
- You will be given a question and you need to clasify it into relevant or not relevant.
- If the question is not relevant, return False in field "question_relevant" and set "answer" to explanation why it is not relevant.
- If the question is relevant, return True in field "question_relevant" and set "answer" to "".
- You should only answer questions about the products in stock. If the question is not about the products in stock, you should ask for clarification.
"""

   template = Template(prompt_template)
   
   prompt = template.render()

   messages = state.messages

   conversation = []

   for message in messages:
        conversation.append(convert_to_openai_messages(message))

   client = instructor.from_openai(OpenAI())

   response, raw_response = client.chat.completions.create_with_completion(
        model="gpt-4.1-mini",
        response_model=IntentRouterResponse,
        messages=[{"role": "system", "content": prompt}, *conversation],
        temperature=0.5,
   )

   return {
      "question_relevant": response.question_relevant,
      "answer": response.answer
      }

# %%
def intent_router_conditional_edges(state: State):

    if state.question_relevant:
        return "agent_node"
    else:
        return "end"

# %% [markdown]
# #### Graph

# %%
workflow = StateGraph(State)

tools = [get_formatted_context]
tool_node = ToolNode(tools)
tool_descriptions = get_tool_descriptions(tools)

workflow.add_node("agent_node", agent_node)
workflow.add_node("tool_node", tool_node)
workflow.add_node("intent_router_node", intent_router_node)

workflow.add_edge(START, "intent_router_node")

workflow.add_conditional_edges(
    "intent_router_node",
    intent_router_conditional_edges,
    {
        "agent_node": "agent_node",
        "end": END
    }
)

workflow.add_conditional_edges(
    "agent_node",
    tool_router,
    {
        "tools": "tool_node",
        "end": END
    }
)

workflow.add_edge("tool_node", "agent_node")

graph = workflow.compile()

# %%
display(Image(graph.get_graph().draw_mermaid_png()))

# %% [markdown]
# ### Persistent State

# %%
from langgraph.checkpoint.postgres import PostgresSaver

# %% [markdown]
# #### Set up the database (once)

# %%
with PostgresSaver.from_conn_string("postgresql://langgraph_user:langgraph_password@localhost:5432/langgraph_db") as checkpointer:

    checkpointer.setup()

# %% [markdown]
# ### Multi-turn Conversation

# %%
initial_state = {
    "messages": [{"role": "user", "content": "Can I get earphones for myself, a laptop bag for my wife and something cool for my kids?"}],
    "available_tools": tool_descriptions
}
config = {
    "configurable": {
        "thread_id": "test0000000001"
    }
}

with PostgresSaver.from_conn_string("postgresql://langgraph_user:langgraph_password@localhost:5432/langgraph_db") as checkpointer:

    graph = workflow.compile(checkpointer=checkpointer)

    answer_1 = graph.invoke(initial_state, config)

# %%
answer_1
# Out:
# {'messages': [{'role': 'user',
#    'content': 'Can I get earphones for myself, a laptop bag for my wife and something cool for my kids?'},
#   AIMessage(content='I will find earphones for you, a laptop bag for your wife, and something cool for your kids from the available products.', additional_kwargs={}, response_metadata={}, tool_calls=[{'name': 'get_formatted_context', 'args': {'query': 'earphones', 'top_k': 5}, 'id': 'call_0', 'type': 'tool_call'}, {'name': 'get_formatted_context', 'args': {'query': 'laptop bag', 'top_k': 5}, 'id': 'call_1', 'type': 'tool_call'}, {'name': 'get_formatted_context', 'args': {'query': 'cool kids items', 'top_k': 5}, 'id': 'call_2', 'type': 'tool_call'}], invalid_tool_calls=[]),
#   ToolMessage(content='- ID: B0B978S5FH, rating: 3.3, description: Earbuds for Wired Headphones Wired Earphones with Microphone Noise Isolating Headsets for Cell Phone White.  \n- ID: B0C3GVF5H9, rating: 4.1, description: MuveAcoustics Link Earbud Headphones True Wireless Bluetooth, in-Ear, Earphones ENC Noise Canceling Microphone, 24H Playtime, IPX5, for Small Ears, Travel, Commute, Home Office, Black. Weatherproof in most scenarios: The Bluetooth earphones may be protected from liquids, including accidental splashes and excessive sweating, thanks to the IPX5-rated LINK wireless earphones. The Link earphones are typically suitable for any activity or setting. Just take them before going to the gym, working out outside, riding a bike, doing Pilates, or travelling!Sound That Inspires : The MuveAcoustics LINK Wireless bluetooth earbuds have a powerful and deep bass that helps you feel every note, immersing you in a world of sound that is both rich and high-fidelity.Instant\xa0Wireless Experience : MvueAcoustics LINK earbuds wireless bluetooth earphones push the boundaries of true wireless earphone technology. It pairs swiftly with your device after the first pairing and has a Bluetooth range of up to 33 feet.All Day Quality Sound\xa0 : The LINK earphones bluetooth wireless can be used for 8 hours when fully charged. The convenient, all-day compact wireless charging case for your earbuds can recharge them twice for 16 additional listening hours!Easy Hands-Free Talking : With the LINK true wireless earbuds\' hands-free calling feature and environmental noise cancelling, talking without using your hands is now simple and effortless. It\'s offered by the LINK true wireless earbuds.Wireless Charging: It is recommended that you use a Qi-standard wireless charging pad to charge the case for your earbuds. Close the charging case\'s lid and place the back of the case in the middle of the charging pad\'s surface. For the best charging results, line up the middle of the charging case with the middle of the charging pad.\u200b \n- ID: B09PG1T4L8, rating: 3.3, description: Wireless Earbuds. Wireless Earbuds.Wireless Earbuds.Wireless Earbuds.Wireless Earbuds.Wireless Earbuds. \n- ID: B09Q2RFL96, rating: 4.3, description: Custom Airpods Case with Keychain, Custom Airpods Pro Case Personalized Airpods Pro Protective Cover with Your Name & Photo for Men Women. ❤️High-quality material: High-quality PC material, bright colors, clearly visible customized patterns; no hindrance to charging; no yellowing, dust-proof, scratch-resistant, and drop-resistant.❤️Compatible with: AirPods Pro suitable for women and men. It is recommended to check your AirPods model before ordering. It fits perfectly with your AirPods charging base and protects your AirPods from damage.❤️Customized earphone sleeve: You can click the "Customize Now" button, upload your favorite picture or add text to design your Airpod earphone sleeve.❤️Package includes: Customized Airpod Pro earphone sleeve + top cover + keychain, which is convenient to carry, and it is recommended to wipe it clean with clean water regularly.❤️Ideal gift: Customized Airpods earphone sleeves are ideal for gift giving, with your photo printed or photos of friends, love, family, ideal gifts for friends, family on birthdays, Christmas, Valentine\'s Day. \n- ID: B0CG9ZWRMC, rating: 4.9, description: 2 Pack Earbuds Wired in Ear Wired Headphones,Earphones with Microphone for 3.5mm Jack Ear Buds Noise Isolation & Volume Control Compatible with iPhone/iPad/Computer/MP3/4 and Other 3.5mm Jack Devices. 【Excellent Sound Quality】Our wired ear buds are equipped with a premium shockproof membrane and advanced sound devices, surpassing conventional headphones wired in sensitivity and noise reduction. Experience an exceptional combination of powerful bass and crystal-clear stereo, allowing you to enjoy music like never before.【Unparalleled Comfort】The wired headphones 3.5mm jack feature an ergonomic design that perfectly conf ...
#   ToolMessage(content='- ID: B0BFDRRB65, rating: 4.5, description: Keyli Laptop Bag for Women Large PU Leather Laptop Briefcase with USB Charging Port Computer Shoulder tote Bags Purse 4pc. PU LeatherImportedUSB Charging Port & Retractable Key Holder：Laptop Tote Bag for Women come with usb charging port and detachable card keychain badge holder The USB charging port helps you charge your phone while walking or shopping conveniently.Large Capacity：The laptop bag for women has an independent laptop compartment fits under 15.6 inch laptop and Ipad/tablet, A large main pocket specially designed for documents, books, gadgets. A middle opening pocket and a middle zipper pocket can store all your personal belongings.Stylish & Widely-Used Tote Handbag：This stylish Satchel Purse is designed with versatility, this fashionable and lightweight leather handbag suitable for work, school, shopping, travel, and other occasions as womens laptop bag, teacher tote bag, nursing handbag or women crossbody work bag, etc.Waterproof Material & High Quality：This women black tote bag is 16.7"W x 12.5"H x 6.5"D inches.It\'s made of high-quality cross pattern PU leather is water-resistant, the extra large tote bag for women using the polished gold tone hardware, smooth zippers,27-47 inch adjustable Strap.Additional Clutch Bag & cosmetic bag: comes with a small makeup organizer and Clutch Bag, made of soft PU leather, and can be used as cosmetic organizer or electronic organizer. the additional Clutch bag is perfectly poised and beautiful style anywhere you go. \n- ID: B0B2PLM3T5, rating: 4.6, description: ESTARER Men\'s Laptop Messenger Bag, 17-17.3 Inch Laptop Backpack, Water Resistant Canvas Computer Bag Shoulder Bag, 3 in 1 Convertible Laptop Briefcases (Dark Grey). 【Large Capacity】This laptop backpack fit most computer & notebook & tablets up to 17"-17.3" such as alienware 17, surface pro, dell series, chromebook. Roomy space for organizing and carring some thin clothes, charger, headphone, file or other accessories.【Padded Laptop Sleeve】Our laptop messenger bag is all around padded design. Laptop padded compartment with secure velcro strap closure to ensure your laptop, wallet, phone and other stuff security.【Plenty of Functional Pockets 】2 x main compartments w/accessories pockets(for wallet/card/pen/phone.ect), 1 x separated padded
additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[])],
#  'question_relevant': True,
#  'iteration': 2,
#  'answer': "Here are some options for you based on your requests:\n\nEarphones for yourself:\n- MuveAcoustics Link Earbud Headphones: True wireless Bluetooth earbuds with ENC noise canceling microphone, 24-hour playtime, IPX5 water resistance, and wireless charging. Suitable for travel, commute, and home office use.\n- Wired Earbuds with Microphone: Wired earphones with noise isolation and volume control, compatible with devices with 3.5mm jack. Comes with a storage bag and offers excellent sound quality and comfort.\n\nLaptop bag for your wife:\n- Keyli Laptop Bag for Women: Large PU leather laptop briefcase with USB charging port, detachable card keychain badge holder, water-resistant material, and multiple compartments including a laptop compartment for up to 15.6-inch laptops. Comes with additional clutch and cosmetic bags.\n- ESTARER Men's Laptop Messenger Bag: Water-resistant canvas laptop backpack with padded laptop sleeve, multiple compartments, convertible 3-in-1 design (shoulder bag, backpack, briefcase), fits laptops up to 17.3 inches.\n- ETRONIK Lunch Backpack for Women: 15.6-inch laptop backpack with USB port, insulated lunch bag, multiple compartments, and breathable shoulder straps.\n\nSomething cool for your kids:\n- iClever Kids Headphones Cat Ear: LED light-up cat ear headphones with 85dBA safe volume, stereo sound, foldable design, and comfortable fit. Compatible with phones, tablets, and laptops.\n- Kids Headphones with Mic for School: Volume-limited foldable on-ear headphones with built-in mic, suitable for kids aged 3-16, comfortable padded ear pads, and compatible with all 3.5mm audio jack devices.\n- 200PCS Trippy Mixed Stickers: Vinyl waterproof stickers for decorating water bottles, laptops, skateboards, and more. A fun and creative gift for kids.\n\nIf you want more details or want to choose specific items, please let me know!",
#  'available_tools': [{'name': 'get_formatted_context',
#    'description': 'Get the top k context, each representing an inventory item for a given query.',
#    'parameters': {'type': 'object',
#     'properties': {'query': {'type': 'string',
#       'description': 'The query to get the top k context for'},
#      'top_k': {'type': 'integer',
#       'description': 'The number of context chunks to retrieve, works best with 5 or more',
#       'default': 5}}},
#    'required': ['query'],
#    'returns': {'type': 'string',
#     'description': 'A string of the top k context chunks with IDs and average ratings prepending each chunk, each representing an inventory item for a given query.'}}],
#  'tool_calls': [],
#  'final_answer': True,
#  'references': [RAGUsedContext(id='B0C3GVF5H9', description='MuveAcoustics Link Earbud Headphones True Wireless Bluetooth Earphones'),
#   RAGUsedContext(id='B0CG9ZWRMC', description='2 Pack Earbuds Wired in Ear Wired Headphones with Microphone'),
#   RAGUsedContext(id='B0BFDRRB65', description='Keyli Laptop Bag for Women Large PU Leather Laptop Briefcase with USB Charging Port'),
#   RAGUsedContext(id='B0B2PLM3T5', description="ESTARER Men's Laptop Messenger Bag, Water Resistant Canvas Computer Bag"),
#   RAGUsedContext(id='B0BKZRQS92', description='ETRONIK Lunch Backpack for Women, 15.6 inch Laptop Backpack with USB Port'),
#   RAGUsedContext(id='B0C9LCT2B2', description='iClever Kids Headphones Cat Ear, LED Light Up, 85dBA Safe Volume'),
#   RAGUsedContext(id='B0B5RMVD1Q', description='Kids Headphones with Mic for School, Volume Limited Foldable On-Ear Headphones'),
#   RAGUsedContext(id='B09XN87KLT', description='200PCS Trippy Mixed Stickers for Water Bottles, Vinyl Waterproof Skateboard Stickers')]}

# %%
print(answer_1["answer"])
# Out:
# Here are some options for you based on your requests:
#
# Earphones for yourself:
# - MuveAcoustics Link Earbud Headphones: True wireless Bluetooth earbuds with ENC noise canceling microphone, 24-hour playtime, IPX5 water resistance, and wireless charging. Suitable for travel, commute, and home office use.
# - Wired Earbuds with Microphone: Wired earphones with noise isolation and volume control, compatible with devices with 3.5mm jack. Comes with a storage bag and offers excellent sound quality and comfort.
#
# Laptop bag for your wife:
# - Keyli Laptop Bag for Women: Large PU leather laptop briefcase with USB charging port, detachable card keychain badge holder, water-resistant material, and multiple compartments including a laptop compartment for up to 15.6-inch laptops. Comes with additional clutch and cosmetic bags.
# - ESTARER Men's Laptop Messenger Bag: Water-resistant canvas laptop backpack with padded laptop sleeve, multiple compartments, convertible 3-in-1 design (shoulder bag, backpack, briefcase), fits laptops up to 17.3 inches.
# - ETRONIK Lunch Backpack for Women: 15.6-inch laptop backpack with USB port, insulated lunch bag, multiple compartments, and breathable shoulder straps.
#
# Something cool for your kids:
# - iClever Kids Headphones Cat Ear: LED light-up cat ear headphones with 85dBA safe volume, stereo sound, foldable design, and comfortable fit. Compatible with phones, tablets, and laptops.
# - Kids Headphones with Mic for School: Volume-limited foldable on-ear headphones with built-in mic, suitable for kids aged 3-16, comfortable padded ear pads, and compatible with all 3.5mm audio jack devices.
# - 200PCS Trippy Mixed Stickers: Vinyl waterproof stickers for decorating water bottles, laptops, skateboards, and more. A fun and creative gift for kids.
#
# If you want more details or want to choose specific items, please let me know!

# %% [markdown]
# ### State Streaming

# %%
initial_state = {
    "messages": [{"role": "user", "content": "Can I get earphones for myself, a laptop bag for my wife and something cool for my kids?"}],
    "available_tools": tool_descriptions
}
config = {
    "configurable": {
        "thread_id": "test0000000007"
    }
}

with PostgresSaver.from_conn_string("postgresql://langgraph_user:langgraph_password@localhost:5432/langgraph_db") as checkpointer:

    graph = workflow.compile(checkpointer=checkpointer)

    for chunk in graph.stream(
        initial_state,
        config=config,
        stream_mode=["updates","debug"]
    ):
        print(chunk)
# Out:
# ('debug', {'step': -1, 'timestamp': '2026-02-17T20:33:34.953798+00:00', 'type': 'checkpoint', 'payload': {'config': {'configurable': {'checkpoint_ns': '', 'thread_id': 'test0000000007', 'checkpoint_id': '1f10c3fe-e879-6aa6-bfff-30ee7cec7fbb'}}, 'parent_config': None, 'values': {'messages': [], 'references': []}, 'metadata': {'source': 'input', 'step': -1, 'parents': {}}, 'next': ['__start__'], 'tasks': [{'id': 'be493e02-ac1e-70d0-76c5-b05d41ea4a27', 'name': '__start__', 'interrupts': (), 'state': None}]}})
# ('debug', {'step': 0, 'timestamp': '2026-02-17T20:33:34.954649+00:00', 'type': 'checkpoint', 'payload': {'config': {'configurable': {'checkpoint_ns': '', 'thread_id': 'test0000000007', 'checkpoint_id': '1f10c3fe-e87c-65da-8000-caa4b9a14ace'}}, 'parent_config': {'configurable': {'checkpoint_ns': '', 'thread_id': 'test0000000007', 'checkpoint_id': '1f10c3fe-e879-6aa6-bfff-30ee7cec7fbb'}}, 'values': {'messages': [{'role': 'user', 'content': 'Can I get earphones for myself, a laptop bag for my wife and something cool for my kids?'}], 'available_tools': [{'name': 'get_formatted_context', 'description': 'Get the top k context, each representing an inventory item for a given query.', 'parameters': {'type': 'object', 'properties': {'query': {'type': 'string', 'description': 'The query to get the top k context for'}, 'top_k': {'type': 'integer', 'description': 'The number of context chunks to retrieve, works best with 5 or more', 'default': 5}}}, 'required': ['query'], 'returns': {'type': 'string', 'description': 'A string of the top k context chunks with IDs and average ratings prepending each chunk, each representing an inventory item for a given query.'}}], 'references': []}, 'metadata': {'source': 'loop', 'step': 0, 'parents': {}}, 'next': ['intent_router_node'], 'tasks': [{'id': '94e8f9a9-869c-51a7-d743-df5ed8611744', 'name': 'intent_router_node', 'interrupts': (), 'state': None}]}})
# ('debug', {'step': 1, 'timestamp': '2026-02-17T20:33:34.954659+00:00', 'type': 'task', 'payload': {'id': '94e8f9a9-869c-51a7-d743-df5ed8611744', 'name': 'intent_router_node', 'input': State(messages=[{'role': 'user', 'content': 'Can I get earphones for myself, a laptop bag for my wife and something cool for my kids?'}], question_relevant=False, iteration=0, answer='', available_tools=[{'name': 'get_formatted_context', 'description': 'Get the top k context, each representing an inventory item for a given query.', 'parameters': {'type': 'object', 'properties': {'query': {'type': 'string', 'description': 'The query to get the top k context for'}, 'top_k': {'type': 'integer', 'description': 'The number of context chunks to retrieve, works best with 5 or more', 'default': 5}}}, 'required': ['query'], 'returns': {'type': 'string', 'description': 'A string of the top k context chunks with IDs and average ratings prepending each chunk, each representing an inventory item for a given query.'}}], tool_calls=[], final_answer=False, references=[]), 'triggers': ('branch:to:intent_router_node',)}})
# ('updates', {'intent_router_node': {'question_relevant': True, 'answer': ''}})
# ('debug', {'step': 1, 'timestamp': '2026-02-17T20:33:36.120817+00:00', 'type': 'task_result', 'payload': {'id': '94e8f9a9-869c-51a7-d743-df5ed8611744', 'name': 'intent_router_node', 'error': None, 'result': {'question_relevant': True, 'answer': ''}, 'interrupts': []}})
# ('debug', {'step': 1, 'timestamp': '2026-02-17T20:33:36.121246+00:00', 'type': 'checkpoint', 'payload': {'config': {'configurable': {'checkpoint_ns': '', 'thread_id': 'test0000000007', 'checkpoint_id': '1f10c3fe-f39c-63d4-8001-5157fcdc4785'}}, 'parent_config': {'configurable': {'checkpoint_ns': '', 'thread_id': 'test0000000007', 'checkpoint_id': '1f10c3fe-e87c-65da-8000-caa4b9a14ace'}}, 'values': {'messages': [{'role': 'user', 'content': 'Can I get earphones for myself, a laptop bag for my wife and something cool for my kids?'}], 'question_relevant': True, 'answer': '', 'available_tools': [{'name': 'get_formatted_context', 'description': 'Get the top k context, each representing an inventory item for a given query.', 'parameters': {'type': 'object', 'properties': {'query': {'type': 'string', 'description': 'The query to get the top k context for'}, 'top_k': {'type': 'integer', 'description': 'The number of context chunks to retrieve, works best with 5 or more', 'default': 5}}}, 'required': ['query'], 'returns': {'type': 'string', 'description': 'A string of the top k context chunks with IDs and average ratings prepending each chunk, each representing an inventory item for a given query.'}}], 'references': []}, 'metadata': {'source': 'loop', 'step': 1, 'parents': {}}, 'next': ['agent_node'], 'tasks': [{'id': '33273ff4-3ec9-8e44-65e3-64915b8163cd', 'name': 'agent_node', 'interrupts': (), 'state': None}]}})
# ('debug', {'step': 2, 'timestamp': '2026-02-17T20:33:36.121260+00:00', 'type': 'task', 'payload': {'id': '33273ff4-3ec9-8e44-65e3-64915b8163cd', 'name': 'agent_node', 'input': State(messages=[{'role': 'user', 'content': 'Can I get earphones for myself, a laptop bag for my wife and something cool for my kids?'}], question_relevant=True, iteration=0, answer='', available_tools=[{'name': 'get_formatted_context', 'description': 'Get the top k context, each representing an inventory item for a given query.', 'parameters': {'type': 'object', 'properties': {'query': {'type': 'string', 'description': 'The query to get the top k context for'}, 'top_k': {'type': 'integer', 'description': 'The number of context chunks to retrieve, works best with 5 or more', 'default': 5}}}, 'required': ['query'], 'returns': {'type': 'string', 'description': 'A string of the top k context chunks with IDs and average ratings prepending each chunk, each representing an inventory item for a given query.'}}], tool_calls=[], final_answer=False, references=[]), 'triggers': ('branch:to:agent_node',)}})
# ('updates', {'agent_node': {'messages': [AIMessage(content='I will find earphones for you, a laptop bag for your wife, and something cool for your kids from the available products.', additional_kwargs={}, response_metadata={}, tool_calls=[{'name': 'get_formatted_context', 'args': {'query': 'earphones', 'top_k': 5}, 'id': 'call_0', 'type': 'tool_call'}, {'name': 'get_formatted_context', 'args': {'query': 'laptop bag', 'top_k': 5}, 'id': 'call_1', 'type': 'tool_call'}, {'name': 'get_formatted_context', 'args': {'query': 'cool kids items', 'top_k': 5}, 'id': 'call_2', 'type': 'tool_call'}], invalid_tool_calls=[])], 'tool_calls': [ToolCall(name='get_formatted_context', arguments={'query': 'earphones', 'top_k': 5}), ToolCall(name='get_formatted_context', arguments={'query': 'laptop bag', 'top_k': 5}), ToolCall(name='get_formatted_context', arguments={'query': 'cool kids items', 'top_k': 5})], 'iteration': 1, 'answer': 'I will find earphones for you, a laptop bag for your wife, and something cool for your kids from the available products.', 'final_answer': False, 'references': []}})
# ('debug', {'step': 2, 'timestamp': '2026-02-17T20:33:38.544828+00:00', 'type': 'task_result', 'payload': {'id': '33273ff4-3ec9-8e44-65e3-64915b8163cd', 'name': 'agent_node', 'error': None, 'result': {'messages': [AIMessage(content='I will find earphones for you, a laptop bag for your wife, and something cool for your kids from the available products.', additional_kwargs={}, response_metadata={}, tool_calls=[{'name': 'get_formatted_context', 'args': {'query': 'earphones', 'top_k': 5}, 'id': 'call_0', 'type': 'tool_call'}, {'name': 'get_formatted_context', 'args': {'query': 'laptop bag', 'top_k': 5}, 'id': 'call_1', 'type': 'tool_call'}, {'name': 'get_formatted_context', 'args': {'query': 'cool kids items', 'top_k': 5}, 'id': 'call_2', 'type': 'tool_call'}], invalid_tool_calls=[])], 'tool_calls': [ToolCall(name='get_formatted_context', arguments={'query': 'earphones', 'top_k': 5}), ToolCall(name='get_formatted_context', arguments={'query': 'laptop bag', 'top_k': 5}), ToolCall(name='get_formatted_context', arguments={'query': 'cool kids items', 'top_k': 5})], 'iteration': 1, 'answer': 'I will find earphones for you, a laptop bag for your wife, and something cool for your kids from the available products.', 'final_answer': False, 'references': []}, 'interrupts': []}})
# ('debug', {'step': 2, 'timestamp': '2026-02-17T20:33:38.545555+00:00', 'type': 'checkpoint', 'payload': {'config': {'configurable': {'checkpoint_ns': '', 'thread_id': 'test0000000007', 'checkpoint_id': '1f10c3ff-0aba-6516-8002-3efcfd32c6dd'}}, 'parent_config': {'configurable': {'checkpoint_ns': '', 'thread_id': 'test0000000007', 'checkpoint_id': '1f10c3fe-f39c-63d4-8001-5157fcdc4785'}}, 'values': {'messages': [{'role': 'user', 'content': 'Can I get earphones for myself, a laptop bag for my wife and something cool for my kids?'}, AIMessage(content='I will find earphones for you, a laptop bag for your wife, and something cool for your kids from the available products.', additional_kwargs={}, response_metadata={}, tool_calls=[{'name': 'get_formatted_context', 'args': {'query': 'earphones', 'top_k': 5}, 'id': 'call_0', 'type': 'tool_call'}, {'name': 'get_formatted_context', 'args': {'query': 'laptop bag', 'top_k': 5}, 'id': 'call_1', 'type': 'tool_call'}, {'name': 'get_formatted_context', 'args': {'query': 'cool kids items', 'top_k': 5}, 'id': 'call_2', 'type': 'tool_call'}], invalid_tool_calls=[])], 'question_relevant': True, 'iteration': 1, 'answer': 'I will find earphones for you, a laptop bag for your wife, and something cool for your kids from the available products.', 'available_tools': [{'name': 'get_formatted_context', 'description': 'Get the top k context, each representing an inventory item for a given query.', 'parameters': {'type': 'object', 'properties': {'query': {'type': 'string', 'description': 'The query to get the top k context for'}, 'top_k': {'type': 'integer', 'description': 'The number of context chunks to retrieve, works best with 5 or more', 'default': 5}}}, 'required': ['query'], 'returns': {'type': 'string', 'description': 'A string of the top k context chunks with IDs and average ratings prepending each chunk, each representing an inventory item for a given query.'}}], 'tool_calls': [ToolCall(name='get_formatted_context', arguments={'query': 'earphones', 'top_k': 5}), ToolCall(name='get_formatted_context', arguments={'query': 'laptop bag', 'top_k': 5}), ToolCall(name='get_formatted_context', arguments={'query': 'cool kids items', 'top_k': 5})], 'final_answer': False, 'references': []}, 'metadata': {'source': 'loop', 'step': 2, 'parents': {}}, 'next': ['tool_node'], 'tasks': [{'id': '2d0ed939-06b7-f08c-fbaf-eb6c28416098', 'name': 'tool_node', 'interrupts': (), 'state': None}]}})
# ('debug', {'step': 3, 'timestamp': '2026-02-17T20:33:38.545573+00:00', 'type': 'task', 'payload': {'id': '2d0ed939-06b7-f08c-fbaf-eb6c28416098', 'name': 'tool_node', 'input': State(messages=[{'role': 'user', 'content': 'Can I get earphones for myself, a laptop bag for my wife and something cool for my kids?'}, AIMessage(content='I will find earphones for you, a laptop bag for your wife, and something cool for your kids from the available products.', additional_kwargs={}, response_metadata={}, tool_calls=[{'name': 'get_formatted_context', 'args': {'query': 'earphones', 'top_k': 5}, 'id': 'call_0', 'type': 'tool_call'}, {'name': 'get_formatted_context', 'args': {'query': 'laptop bag', 'top_k': 5}, 'id': 'call_1', 'type': 'tool_call'}, {'name': 'get_formatted_context', 'args': {'query': 'cool kids items', 'top_k': 5}, 'id': 'call_2', 'type': 'tool_call'}], invalid_tool_calls=[])], question_relevant=True, iteration=1, answer='I will find earphones for you, a laptop bag for your wife, and something cool for your kids from the available products.', available_tools=[{'name': 'get_formatted_context', 'description': 'Get the top k context, each representing an inventory item for a given query.', 'parameters': {'type': 'object', 'properties': {'query': {'type': 'string', 'description': 'The query to get the top k context for'}, 'top_k': {'type': 'integer', 'description': 'The number of context chunks to retrieve, works best with 5 or more', 'default': 5}}}, 'required': ['query'], 'returns': {'type': 'string', 'description': 'A string of the top k context chunks with IDs and average ratings prepending each chunk, each representing an inventory item for a given query.'}}], tool_calls=[ToolCall(name='get_formatted_context', arguments={'query': 'earphones', 'top_k': 5}), ToolCall(name='get_formatted_context', arguments={'query': 'laptop bag', 'top_k': 5}), ToolCall(name='get_formatted_context', arguments={'query': 'cool kids items', 'top_k': 5})], final_answer=False, references=[]), 'triggers': ('branch:to:tool_node',)}})
# ('updates', {'tool_node': {'messages': [ToolMessage(content='- ID: B0B978S5FH, rating: 3.3, description: Earbuds for Wired Headphones Wired Earphones with Microphone Noise Isolating Headsets for Cell Phone White.  \n- ID: B0C3GVF5H9, rating: 4.1, description: MuveAcoustics Link Earbud Headphones True Wireless Bluetooth, in-Ear, Earphones ENC Noise Canceling Microphone, 24H Playtime, IPX5, for Small Ears, Travel, Commute, Home Office, Black. Weatherproof in most scenarios: The Bluetooth earphones may be protected from liquids, including accidental splashes and excessive sweating, thanks to the IPX5-rated LINK wireless earphones. The Link earphones are typically suitable for any activity or setting. Just take them before going to the gym, working out outside, riding a bike, doing Pilates, or travelling!Sound That Inspires : The MuveAcoustics LINK Wireless bluetooth earbuds have a powerful and deep bass that helps you feel every note, immersing you in a world of sound that is both rich and high-fidelity.Instant\xa0Wireless Experience : MvueAcoustics LINK earbuds wireless bluetooth earphones push the boundaries of true wireless earphone technology. It pairs swiftly with your device after the first pairing and has a Bluetooth range of up to 33 feet.All Day Quality Sound\xa0 : The LINK earphones bluetooth wireless can be used for 8 hours when fully charged. The convenient, all-day compact wireless charging case for your earbuds can recharge them twice for 16 additional listening hours!Easy Hands-Free Talking : With the LINK true wireless earbuds\' hands-free calling feature and environmental noise cancelling, talking without using your hands is now simple and effortless. It\'s offered by the LINK true wireless earbuds.Wireless Charging: It is recommended that you use a Qi-standard wireless charging pad to charge the case for your earbuds. Close the charging case\'s lid and place the back of the case in the middle of the charging pad\'s surface. For the best charging results, line up the middle of the charging case with the middle of the charging pad.\u200b \n- ID: B09PG1T4L8, rating: 3.3, description: Wireless Earbuds. Wireless Earbuds.Wireless Earbuds.Wireless Earbuds.Wireless Earbuds.Wireless Earbuds. \n- ID: B09Q2RFL96, rating: 4.3, description: Custom Airpods Case with Keychain, Custom Airpods Pro Case Personalized Airpods Pro Protective Cover with Your Name & Photo for Men Women. ❤️High-quality material: High-quality PC material, bright colors, clearly visible customized patterns; no hindrance to charging; no yellowing, dust-proof, scratch-resistant, and drop-resistant.❤️Compatible with: AirPods Pro suitable for women and men. It is recommended to check your AirPods model before ordering. It fits perfectly with your AirPods charging base and protects your AirPods from damage.❤️Customized earphone sleeve: You can click the "Customize Now" button, upload your favorite picture or add text to design your Airpod earphone sleeve.❤️Package includes: Customized Airpod Pro earphone sleeve + top cover + keychain, which is convenient to carry, and it is recommended to wipe it clean with clean water regularly.❤️Ideal gift: Customized Airpods earphone sleeves are ideal for gift giving, with your photo printed or photos of friends, love, family, ideal gifts for friends, family on birthdays, Christmas, Valentine\'s Day. \n- ID: B0CG9ZWRMC, rating: 4.9, description: 2 Pack Earbuds Wired in Ear Wired Headphones,Earphones with Microphone for 3.5mm Jack Ear Buds Noise Isolation & Volume Control Compatible with iPhone/iPad/Computer/MP3/4 and Other 3.5mm Jack Devices. 【Excellent Sound Quality】Our wired ear buds are equipped with a premium shockproof membrane and advanced sound devices, surpassing conventional headphones wired in sensitivity and noise reduction. Experience an exceptional combination of powerful bass and crystal-clear stereo, allowing you to enjoy music like never before.【Unparalleled Comfort】The wired headphones 3.5mm jack feature a ...
# ('debug', {'step': 3, 'timestamp': '2026-02-17T20:33:39.265793+00:00', 'type': 'task_result', 'payload': {'id': '2d0ed939-06b7-f08c-fbaf-eb6c28416098', 'name': 'tool_node', 'error': None, 'result': {'messages': [ToolMessage(content='- ID: B0B978S5FH, rating: 3.3, description: Earbuds for Wired Headphones Wired Earphones with Microphone Noise Isolating Headsets for Cell Phone White.  \n- ID: B0C3GVF5H9, rating: 4.1, description: MuveAcoustics Link Earbud Headphones True Wireless Bluetooth, in-Ear, Earphones ENC Noise Canceling Microphone, 24H Playtime, IPX5, for Small Ears, Travel, Commute, Home Office, Black. Weatherproof in most scenarios: The Bluetooth earphones may be protected from liquids, including accidental splashes and excessive sweating, thanks to the IPX5-rated LINK wireless earphones. The Link earphones are typically suitable for any activity or setting. Just take them before going to the gym, working out outside, riding a bike, doing Pilates, or travelling!Sound That Inspires : The MuveAcoustics LINK Wireless bluetooth earbuds have a powerful and deep bass that helps you feel every note, immersing you in a world of sound that is both rich and high-fidelity.Instant\xa0Wireless Experience : MvueAcoustics LINK earbuds wireless bluetooth earphones push the boundaries of true wireless earphone technology. It pairs swiftly with your device after the first pairing and has a Bluetooth range of up to 33 feet.All Day Quality Sound\xa0 : The LINK earphones bluetooth wireless can be used for 8 hours when fully charged. The convenient, all-day compact wireless charging case for your earbuds can recharge them twice for 16 additional listening hours!Easy Hands-Free Talking : With the LINK true wireless earbuds\' hands-free calling feature and environmental noise cancelling, talking without using your hands is now simple and effortless. It\'s offered by the LINK true wireless earbuds.Wireless Charging: It is recommended that you use a Qi-standard wireless charging pad to charge the case for your earbuds. Close the charging case\'s lid and place the back of the case in the middle of the charging pad\'s surface. For the best charging results, line up the middle of the charging case with the middle of the charging pad.\u200b \n- ID: B09PG1T4L8, rating: 3.3, description: Wireless Earbuds. Wireless Earbuds.Wireless Earbuds.Wireless Earbuds.Wireless Earbuds.Wireless Earbuds. \n- ID: B09Q2RFL96, rating: 4.3, description: Custom Airpods Case with Keychain, Custom Airpods Pro Case Personalized Airpods Pro Protective Cover with Your Name & Photo for Men Women. ❤️High-quality material: High-quality PC material, bright colors, clearly visible customized patterns; no hindrance to charging; no yellowing, dust-proof, scratch-resistant, and drop-resistant.❤️Compatible with: AirPods Pro suitable for women and men. It is recommended to check your AirPods model before ordering. It fits perfectly with your AirPods charging base and protects your AirPods from damage.❤️Customized earphone sleeve: You can click the "Customize Now" button, upload your favorite picture or add text to design your Airpod earphone sleeve.❤️Package includes: Customized Airpod Pro earphone sleeve + top cover + keychain, which is convenient to carry, and it is recommended to wipe it clean with clean water regularly.❤️Ideal gift: Customized Airpods earphone sleeves are ideal for gift giving, with your photo printed or photos of friends, love, family, ideal gifts for friends, family on birthdays, Christmas, Valentine\'s Day. \n- ID: B0CG9ZWRMC, rating: 4.9, description: 2 Pack Earbuds Wired in Ear Wired Headphones,Earphones with Microphone for 3.5mm Jack Ear Buds Noise Isolation & Volume Control Compatible with iPhone/iPad/Computer/MP3/4 and Other 3.5mm Jack Devices. 【Excellent Sound Quality】Our wired ear buds are equipped with a premium shockproof membrane and advanced sound devices, surpassing conventional headphones wired in sensitivity and noise reduction. Experience an exce ...
# ('debug', {'step': 3, 'timestamp': '2026-02-17T20:33:39.265934+00:00', 'type': 'checkpoint', 'payload': {'config': {'configurable': {'checkpoint_ns': '', 'thread_id': 'test0000000007', 'checkpoint_id': '1f10c3ff-119a-6390-8003-2dccf1b836f4'}}, 'parent_config': {'configurable': {'checkpoint_ns': '', 'thread_id': 'test0000000007', 'checkpoint_id': '1f10c3ff-0aba-6516-8002-3efcfd32c6dd'}}, 'values': {'messages': [{'role': 'user', 'content': 'Can I get earphones for myself, a laptop bag for my wife and something cool for my kids?'}, AIMessage(content='I will find earphones for you, a laptop bag for your wife, and something cool for your kids from the available products.', additional_kwargs={}, response_metadata={}, tool_calls=[{'name': 'get_formatted_context', 'args': {'query': 'earphones', 'top_k': 5}, 'id': 'call_0', 'type': 'tool_call'}, {'name': 'get_formatted_context', 'args': {'query': 'laptop bag', 'top_k': 5}, 'id': 'call_1', 'type': 'tool_call'}, {'name': 'get_formatted_context', 'args': {'query': 'cool kids items', 'top_k': 5}, 'id': 'call_2', 'type': 'tool_call'}], invalid_tool_calls=[]), ToolMessage(content='- ID: B0B978S5FH, rating: 3.3, description: Earbuds for Wired Headphones Wired Earphones with Microphone Noise Isolating Headsets for Cell Phone White.  \n- ID: B0C3GVF5H9, rating: 4.1, description: MuveAcoustics Link Earbud Headphones True Wireless Bluetooth, in-Ear, Earphones ENC Noise Canceling Microphone, 24H Playtime, IPX5, for Small Ears, Travel, Commute, Home Office, Black. Weatherproof in most scenarios: The Bluetooth earphones may be protected from liquids, including accidental splashes and excessive sweating, thanks to the IPX5-rated LINK wireless earphones. The Link earphones are typically suitable for any activity or setting. Just take them before going to the gym, working out outside, riding a bike, doing Pilates, or travelling!Sound That Inspires : The MuveAcoustics LINK Wireless bluetooth earbuds have a powerful and deep bass that helps you feel every note, immersing you in a world of sound that is both rich and high-fidelity.Instant\xa0Wireless Experience : MvueAcoustics LINK earbuds wireless bluetooth earphones push the boundaries of true wireless earphone technology. It pairs swiftly with your device after the first pairing and has a Bluetooth range of up to 33 feet.All Day Quality Sound\xa0 : The LINK earphones bluetooth wireless can be used for 8 hours when fully charged. The convenient, all-day compact wireless charging case for your earbuds can recharge them twice for 16 additional listening hours!Easy Hands-Free Talking : With the LINK true wireless earbuds\' hands-free calling feature and environmental noise cancelling, talking without using your hands is now simple and effortless. It\'s offered by the LINK true wireless earbuds.Wireless Charging: It is recommended that you use a Qi-standard wireless charging pad to charge the case for your earbuds. Close the charging case\'s lid and place the back of the case in the middle of the charging pad\'s surface. For the best charging results, line up the middle of the charging case with the middle of the charging pad.\u200b \n- ID: B09PG1T4L8, rating: 3.3, description: Wireless Earbuds. Wireless Earbuds.Wireless Earbuds.Wireless Earbuds.Wireless Earbuds.Wireless Earbuds. \n- ID: B09Q2RFL96, rating: 4.3, description: Custom Airpods Case with Keychain, Custom Airpods Pro Case Personalized Airpods Pro Protective Cover with Your Name & Photo for Men Women. ❤️High-quality material: High-quality PC material, bright colors, clearly visible customized patterns; no hindrance to charging; no yellowing, dust-proof, scratch-resistant, and drop-resistant.❤️Compatible with: AirPods Pro suitable for women and men. It is recommended to check your AirPods model before ordering. It fits perfectly with your AirPods charging base and protects your AirPods from damage.❤️Customized earphone sleeve: You can click the "Customize Now" button, upload your favorite picture o ...
# ('debug', {'step': 4, 'timestamp': '2026-02-17T20:33:39.265938+00:00', 'type': 'task', 'payload': {'id': '1893858a-bd50-155c-b9d4-e0a429b8b248', 'name': 'agent_node', 'input': State(messages=[{'role': 'user', 'content': 'Can I get earphones for myself, a laptop bag for my wife and something cool for my kids?'}, AIMessage(content='I will find earphones for you, a laptop bag for your wife, and something cool for your kids from the available products.', additional_kwargs={}, response_metadata={}, tool_calls=[{'name': 'get_formatted_context', 'args': {'query': 'earphones', 'top_k': 5}, 'id': 'call_0', 'type': 'tool_call'}, {'name': 'get_formatted_context', 'args': {'query': 'laptop bag', 'top_k': 5}, 'id': 'call_1', 'type': 'tool_call'}, {'name': 'get_formatted_context', 'args': {'query': 'cool kids items', 'top_k': 5}, 'id': 'call_2', 'type': 'tool_call'}], invalid_tool_calls=[]), ToolMessage(content='- ID: B0B978S5FH, rating: 3.3, description: Earbuds for Wired Headphones Wired Earphones with Microphone Noise Isolating Headsets for Cell Phone White.  \n- ID: B0C3GVF5H9, rating: 4.1, description: MuveAcoustics Link Earbud Headphones True Wireless Bluetooth, in-Ear, Earphones ENC Noise Canceling Microphone, 24H Playtime, IPX5, for Small Ears, Travel, Commute, Home Office, Black. Weatherproof in most scenarios: The Bluetooth earphones may be protected from liquids, including accidental splashes and excessive sweating, thanks to the IPX5-rated LINK wireless earphones. The Link earphones are typically suitable for any activity or setting. Just take them before going to the gym, working out outside, riding a bike, doing Pilates, or travelling!Sound That Inspires : The MuveAcoustics LINK Wireless bluetooth earbuds have a powerful and deep bass that helps you feel every note, immersing you in a world of sound that is both rich and high-fidelity.Instant\xa0Wireless Experience : MvueAcoustics LINK earbuds wireless bluetooth earphones push the boundaries of true wireless earphone technology. It pairs swiftly with your device after the first pairing and has a Bluetooth range of up to 33 feet.All Day Quality Sound\xa0 : The LINK earphones bluetooth wireless can be used for 8 hours when fully charged. The convenient, all-day compact wireless charging case for your earbuds can recharge them twice for 16 additional listening hours!Easy Hands-Free Talking : With the LINK true wireless earbuds\' hands-free calling feature and environmental noise cancelling, talking without using your hands is now simple and effortless. It\'s offered by the LINK true wireless earbuds.Wireless Charging: It is recommended that you use a Qi-standard wireless charging pad to charge the case for your earbuds. Close the charging case\'s lid and place the back of the case in the middle of the charging pad\'s surface. For the best charging results, line up the middle of the charging case with the middle of the charging pad.\u200b \n- ID: B09PG1T4L8, rating: 3.3, description: Wireless Earbuds. Wireless Earbuds.Wireless Earbuds.Wireless Earbuds.Wireless Earbuds.Wireless Earbuds. \n- ID: B09Q2RFL96, rating: 4.3, description: Custom Airpods Case with Keychain, Custom Airpods Pro Case Personalized Airpods Pro Protective Cover with Your Name & Photo for Men Women. ❤️High-quality material: High-quality PC material, bright colors, clearly visible customized patterns; no hindrance to charging; no yellowing, dust-proof, scratch-resistant, and drop-resistant.❤️Compatible with: AirPods Pro suitable for women and men. It is recommended to check your AirPods model before ordering. It fits perfectly with your AirPods charging base and protects your AirPods from damage.❤️Customized earphone sleeve: You can click the "Customize Now" button, upload your favorite picture or add text to design your Airpod earphone sleeve.❤️Package includes: Customized Airpod Pro earphone sleeve + top cover + keychain, which is convenient to carry, and it is recommended to wipe it clean with clean water regul ...
# ('updates', {'agent_node': {'messages': [AIMessage(content="For earphones, there are several options:\n- MuveAcoustics Link Earbud Headphones True Wireless Bluetooth with ENC Noise Canceling Microphone, 24H Playtime, IPX5 rating for water resistance, suitable for travel and commute. (ID: B0C3GVF5H9)\n- 2 Pack Earbuds Wired in Ear Wired Headphones with Microphone for 3.5mm Jack, noise isolation, volume control, compatible with iPhone/iPad/Computer/MP3/4 and other 3.5mm jack devices. (ID: B0CG9ZWRMC)\n\nFor a laptop bag for your wife, options include:\n- ESTARER Men's Laptop Messenger Bag, water-resistant canvas, 3 in 1 convertible, fits laptops up to 17-17.3 inches. (ID: B0B2PLM3T5)\n- Keyli Laptop Bag for Women, large PU leather briefcase with USB charging port and detachable key holder, fits laptops under 15.6 inches. (ID
# ('debug', {'step': 4, 'timestamp': '2026-02-17T20:33:51.850069+00:00', 'type': 'checkpoint', 'payload': {'config': {'configurable': {'checkpoint_ns': '', 'thread_id': 'test0000000007', 'checkpoint_id': '1f10c3ff-899d-6004-8004-74bba885a772'}}, 'parent_config': {'configurable': {'checkpoint_ns': '', 'thread_id': 'test0000000007', 'checkpoint_id': '1f10c3ff-119a-6390-8003-2dccf1b836f4'}}, 'values': {'messages': [{'role': 'user', 'content': 'Can I get earphones for myself, a laptop bag for my wife and something cool for my kids?'}, AIMessage(content='I will find earphones for you, a laptop bag for your wife, and something cool for your kids from the available products.', additional_kwargs={}, response_metadata={}, tool_calls=[{'name': 'get_formatted_context', 'args': {'query': 'earphones', 'top_k': 5}, 'id': 'call_0', 'type': 'tool_call'}, {'name': 'get_formatted_context', 'args': {'query': 'laptop bag', 'top_k': 5}, 'id': 'call_1', 'type': 'tool_call'}, {'name': 'get_formatted_context', 'args': {'query': 'cool kids items', 'top_k': 5}, 'id': 'call_2', 'type': 'tool_call'}], invalid_tool_calls=[]), ToolMessage(content='- ID: B0B978S5FH, rating: 3.3, description: Earbuds for Wired Headphones Wired Earphones with Microphone Noise Isolating Headsets for Cell Phone White.  \n- ID: B0C3GVF5H9, rating: 4.1, description: MuveAcoustics Link Earbud Headphones True Wireless Bluetooth, in-Ear, Earphones ENC Noise Canceling Microphone, 24H Playtime, IPX5, for Small Ears, Travel, Commute, Home Office, Black. Weatherproof in most scenarios: The Bluetooth earphones may be protected from liquids, including accidental splashes and excessive sweating, thanks to the IPX5-rated LINK wireless earphones. The Link earphones are typically suitable for any activity or setting. Just take them before going to the gym, working out outside, riding a bike, doing Pilates, or travelling!Sound That Inspires : The MuveAcoustics LINK Wireless bluetooth earbuds have a powerful and deep bass that helps you feel every note, immersing you in a world of sound that is both rich and high-fidelity.Instant\xa0Wireless Experience : MvueAcoustics LINK earbuds wireless bluetooth earphones push the boundaries of true wireless earphone technology. It pairs swiftly with your device after the first pairing and has a Bluetooth range of up to 33 feet.All Day Quality Sound\xa0 : The LINK earphones bluetooth wireless can be used for 8 hours when fully charged. The convenient, all-day compact wireless charging case for your earbuds can recharge them twice for 16 additional listening hours!Easy Hands-Free Talking : With the LINK true wireless earbuds\' hands-free calling feature and environmental noise cancelling, talking without using your hands is now simple and effortless. It\'s offered by the LINK true wireless earbuds.Wireless Charging: It is recommended that you use a Qi-standard wireless charging pad to charge the case for your earbuds. Close the charging case\'s lid and place the back of the case in the middle of the charging pad\'s surface. For the best charging results, line up the middle of the charging case with the middle of the charging pad.\u200b \n- ID: B09PG1T4L8, rating: 3.3, description: Wireless Earbuds. Wireless Earbuds.Wireless Earbuds.Wireless Earbuds.Wireless Earbuds.Wireless Earbuds. \n- ID: B09Q2RFL96, rating: 4.3, description: Custom Airpods Case with Keychain, Custom Airpods Pro Case Personalized Airpods Pro Protective Cover with Your Name & Photo for Men Women. ❤️High-quality material: High-quality PC material, bright colors, clearly visible customized patterns; no hindrance to charging; no yellowing, dust-proof, scratch-resistant, and drop-resistant.❤️Compatible with: AirPods Pro suitable for women and men. It is recommended to check your AirPods model before ordering. It fits perfectly with your AirPods charging base and protects your AirPods from damage.❤️Customized earphone sleeve: You can click the "Customize Now" button, upload your favorite picture o ...

# %%
def process_graph_event(chunk):

    def _is_node_start(chunk):
        return chunk[1].get("type") == "task"

    def _is_node_end(chunk):
        return chunk[0] == "updates"

    def _tool_to_text(tool_call):
        if tool_call.name == "get_formatted_context":
            return f"Looking for items: {tool_call.arguments.get('query', '')}."
        elif tool_call.name == "get_formatted_reviews_context":
            return f"Fetching user reviews..."

    if _is_node_start(chunk):
        if chunk[1].get("payload", {}).get("name") == "intent_router_node":
            print("Analysing the question...")
        if chunk[1].get("payload", {}).get("name") == "agent_node":
            print("Planning...")
        if chunk[1].get("payload", {}).get("name") == "tool_node":
            message = " ".join([_tool_to_text(tool_call) for tool_call in chunk[1].get('payload', {}).get('input', {}).tool_calls])
            print(message)

# %%
initial_state = {
    "messages": [{"role": "user", "content": "Can I get earphones for myself, a laptop bag for my wife and something cool for my kids?"}],
    "available_tools": tool_descriptions
}
config = {
    "configurable": {
        "thread_id": "test0000000003"
    }
}

with PostgresSaver.from_conn_string("postgresql://langgraph_user:langgraph_password@localhost:5432/langgraph_db") as checkpointer:

    graph = workflow.compile(checkpointer=checkpointer)

    for chunk in graph.stream(
        initial_state,
        config=config,
        stream_mode=["updates","debug"]
    ):
        process_graph_event(chunk)
# Out:
# Analysing the question...
# Planning...
# Looking for items: earphones. Looking for items: laptop bag. Looking for items: cool kids items.
# Planning...

# %%
initial_state = {
    "messages": [{"role": "user", "content": "Can I get earphones for myself, a laptop bag for my wife and something cool for my kids?"}],
    "available_tools": tool_descriptions
}
config = {
    "configurable": {
        "thread_id": "test0000000011"
    }
}

with PostgresSaver.from_conn_string("postgresql://langgraph_user:langgraph_password@localhost:5432/langgraph_db") as checkpointer:

    graph = workflow.compile(checkpointer=checkpointer)

    for chunk in graph.stream(
        initial_state,
        config=config,
        stream_mode=["updates","debug","values"]
    ):
        print(chunk)
# Out:
# ('debug', {'step': -1, 'timestamp': '2026-02-17T20:58:34.545844+00:00', 'type': 'checkpoint', 'payload': {'config': {'configurable': {'checkpoint_ns': '', 'thread_id': 'test0000000011', 'checkpoint_id': '1f10c436-c5b2-6dbe-bfff-b59bf5f2855f'}}, 'parent_config': None, 'values': {'messages': [], 'references': []}, 'metadata': {'source': 'input', 'step': -1, 'parents': {}}, 'next': ['__start__'], 'tasks': [{'id': '8139101c-52d5-7a77-362e-d18898145407', 'name': '__start__', 'interrupts': (), 'state': None}]}})
# ('values', {'messages': [{'role': 'user', 'content': 'Can I get earphones for myself, a laptop bag for my wife and something cool for my kids?'}], 'available_tools': [{'name': 'get_formatted_context', 'description': 'Get the top k context, each representing an inventory item for a given query.', 'parameters': {'type': 'object', 'properties': {'query': {'type': 'string', 'description': 'The query to get the top k context for'}, 'top_k': {'type': 'integer', 'description': 'The number of context chunks to retrieve, works best with 5 or more', 'default': 5}}}, 'required': ['query'], 'returns': {'type': 'string', 'description': 'A string of the top k context chunks with IDs and average ratings prepending each chunk, each representing an inventory item for a given query.'}}], 'references': []})
# ('debug', {'step': 0, 'timestamp': '2026-02-17T20:58:34.546703+00:00', 'type': 'checkpoint', 'payload': {'config': {'configurable': {'checkpoint_ns': '', 'thread_id': 'test0000000011', 'checkpoint_id': '1f10c436-c5b5-6bea-8000-b7313972bb94'}}, 'parent_config': {'configurable': {'checkpoint_ns': '', 'thread_id': 'test0000000011', 'checkpoint_id': '1f10c436-c5b2-6dbe-bfff-b59bf5f2855f'}}, 'values': {'messages': [{'role': 'user', 'content': 'Can I get earphones for myself, a laptop bag for my wife and something cool for my kids?'}], 'available_tools': [{'name': 'get_formatted_context', 'description': 'Get the top k context, each representing an inventory item for a given query.', 'parameters': {'type': 'object', 'properties': {'query': {'type': 'string', 'description': 'The query to get the top k context for'}, 'top_k': {'type': 'integer', 'description': 'The number of context chunks to retrieve, works best with 5 or more', 'default': 5}}}, 'required': ['query'], 'returns': {'type': 'string', 'description': 'A string of the top k context chunks with IDs and average ratings prepending each chunk, each representing an inventory item for a given query.'}}], 'references': []}, 'metadata': {'source': 'loop', 'step': 0, 'parents': {}}, 'next': ['intent_router_node'], 'tasks': [{'id': '43994c49-9931-3205-3ccf-bc6f64c097dd', 'name': 'intent_router_node', 'interrupts': (), 'state': None}]}})
# ('debug', {'step': 1, 'timestamp': '2026-02-17T20:58:34.546710+00:00', 'type': 'task', 'payload': {'id': '43994c49-9931-3205-3ccf-bc6f64c097dd', 'name': 'intent_router_node', 'input': State(messages=[{'role': 'user', 'content': 'Can I get earphones for myself, a laptop bag for my wife and something cool for my kids?'}], question_relevant=False, iteration=0, answer='', available_tools=[{'name': 'get_formatted_context', 'description': 'Get the top k context, each representing an inventory item for a given query.', 'parameters': {'type': 'object', 'properties': {'query': {'type': 'string', 'description': 'The query to get the top k context for'}, 'top_k': {'type': 'integer', 'description': 'The number of context chunks to retrieve, works best with 5 or more', 'default': 5}}}, 'required': ['query'], 'returns': {'type': 'string', 'description': 'A string of the top k context chunks with IDs and average ratings prepending each chunk, each representing an inventory item for a given query.'}}], tool_calls=[], final_answer=False, references=[]), 'triggers': ('branch:to:intent_router_node',)}})
# ('updates', {'intent_router_node': {'question_relevant': True, 'answer': ''}})
# ('debug', {'step': 1, 'timestamp': '2026-02-17T20:58:35.221723+00:00', 'type': 'task_result', 'payload': {'id': '43994c49-9931-3205-3ccf-bc6f64c097dd', 'name': 'intent_router_node', 'error': None, 'result': {'question_relevant': True, 'answer': ''}, 'interrupts': []}})
# ('values', {'messages': [{'role': 'user', 'content': 'Can I get earphones for myself, a laptop bag for my wife and something cool for my kids?'}], 'question_relevant': True, 'answer': '', 'available_tools': [{'name': 'get_formatted_context', 'description': 'Get the top k context, each representing an inventory item for a given query.', 'parameters': {'type': 'object', 'properties': {'query': {'type': 'string', 'description': 'The query to get the top k context for'}, 'top_k': {'type': 'integer', 'description': 'The number of context chunks to retrieve, works best with 5 or more', 'default': 5}}}, 'required': ['query'], 'returns': {'type': 'string', 'description': 'A string of the top k context chunks with IDs and average ratings prepending each chunk, each representing an inventory item for a given query.'}}], 'references': []})
# ('debug', {'step': 1, 'timestamp': '2026-02-17T20:58:35.221964+00:00', 'type': 'checkpoint', 'payload': {'config': {'configurable': {'checkpoint_ns': '', 'thread_id': 'test0000000011', 'checkpoint_id': '1f10c436-cc26-66dc-8001-1c5ad512cd68'}}, 'parent_config': {'configurable': {'checkpoint_ns': '', 'thread_id': 'test0000000011', 'checkpoint_id': '1f10c436-c5b5-6bea-8000-b7313972bb94'}}, 'values': {'messages': [{'role': 'user', 'content': 'Can I get earphones for myself, a laptop bag for my wife and something cool for my kids?'}], 'question_relevant': True, 'answer': '', 'available_tools': [{'name': 'get_formatted_context', 'description': 'Get the top k context, each representing an inventory item for a given query.', 'parameters': {'type': 'object', 'properties': {'query': {'type': 'string', 'description': 'The query to get the top k context for'}, 'top_k': {'type': 'integer', 'description': 'The number of context chunks to retrieve, works best with 5 or more', 'default': 5}}}, 'required': ['query'], 'returns': {'type': 'string', 'description': 'A string of the top k context chunks with IDs and average ratings prepending each chunk, each representing an inventory item for a given query.'}}], 'references': []}, 'metadata': {'source': 'loop', 'step': 1, 'parents': {}}, 'next': ['agent_node'], 'tasks': [{'id': '98612e17-d405-62e1-1827-ebf2a0ad5e83', 'name': 'agent_node', 'interrupts': (), 'state': None}]}})
# ('debug', {'step': 2, 'timestamp': '2026-02-17T20:58:35.221971+00:00', 'type': 'task', 'payload': {'id': '98612e17-d405-62e1-1827-ebf2a0ad5e83', 'name': 'agent_node', 'input': State(messages=[{'role': 'user', 'content': 'Can I get earphones for myself, a laptop bag for my wife and something cool for my kids?'}], question_relevant=True, iteration=0, answer='', available_tools=[{'name': 'get_formatted_context', 'description': 'Get the top k context, each representing an inventory item for a given query.', 'parameters': {'type': 'object', 'properties': {'query': {'type': 'string', 'description': 'The query to get the top k context for'}, 'top_k': {'type': 'integer', 'description': 'The number of context chunks to retrieve, works best with 5 or more', 'default': 5}}}, 'required': ['query'], 'returns': {'type': 'string', 'description': 'A string of the top k context chunks with IDs and average ratings prepending each chunk, each representing an inventory item for a given query.'}}], tool_calls=[], final_answer=False, references=[]), 'triggers': ('branch:to:agent_node',)}})
# ('updates', {'agent_node': {'messages': [AIMessage(content='I will find earphones, a laptop bag, and something cool for kids from the available products for you.', additional_kwargs={}, response_metadata={}, tool_calls=[{'name': 'get_formatted_context', 'args': {'query': 'earphones', 'top_k': 5}, 'id': 'call_0', 'type': 'tool_call'}, {'name': 'get_formatted_context', 'args': {'query': 'laptop bag', 'top_k': 5}, 'id': 'call_1', 'type': 'tool_call'}, {'name': 'get_formatted_context', 'args': {'query': 'cool kids items', 'top_k': 5}, 'id': 'call_2', 'type': 'tool_call'}], invalid_tool_calls=[])], 'tool_calls': [ToolCall(name='get_formatted_context', arguments={'query': 'earphones', 'top_k': 5}), ToolCall(name='get_formatted_context', arguments={'query': 'laptop bag', 'top_k': 5}), ToolCall(name='get_formatted_context', arguments={'query': 'cool kids items', 'top_k': 5})], 'iteration': 1, 'answer': 'I will find earphones, a laptop bag, and something cool for kids from the available products for you.', 'final_answer': False, 'references': []}})
# ('debug', {'step': 2, 'timestamp': '2026-02-17T20:58:38.220894+00:00', 'type': 'task_result', 'payload': {'id': '98612e17-d405-62e1-1827-ebf2a0ad5e83', 'name': 'agent_node', 'error': None, 'result': {'messages': [AIMessage(content='I will find earphones, a laptop bag, and something cool for kids from the available products for you.', additional_kwargs={}, response_metadata={}, tool_calls=[{'name': 'get_formatted_context', 'args': {'query': 'earphones', 'top_k': 5}, 'id': 'call_0', 'type': 'tool_call'}, {'name': 'get_formatted_context', 'args': {'query': 'laptop bag', 'top_k': 5}, 'id': 'call_1', 'type': 'tool_call'}, {'name': 'get_formatted_context', 'args': {'query': 'cool kids items', 'top_k': 5}, 'id': 'call_2', 'type': 'tool_call'}], invalid_tool_calls=[])], 'tool_calls': [ToolCall(name='get_formatted_context', arguments={'query': 'earphones', 'top_k': 5}), ToolCall(name='get_formatted_context', arguments={'query': 'laptop bag', 'top_k': 5}), ToolCall(name='get_formatted_context', arguments={'query': 'cool kids items', 'top_k': 5})], 'iteration': 1, 'answer': 'I will find earphones, a laptop bag, and something cool for kids from the available products for you.', 'final_answer': False, 'references': []}, 'interrupts': []}})
# ('values', {'messages': [{'role': 'user', 'content': 'Can I get earphones for myself, a laptop bag for my wife and something cool for my kids?'}, AIMessage(content='I will find earphones, a laptop bag, and something cool for kids from the available products for you.', additional_kwargs={}, response_metadata={}, tool_calls=[{'name': 'get_formatted_context', 'args': {'query': 'earphones', 'top_k': 5}, 'id': 'call_0', 'type': 'tool_call'}, {'name': 'get_formatted_context', 'args': {'query': 'laptop bag', 'top_k': 5}, 'id': 'call_1', 'type': 'tool_call'}, {'name': 'get_formatted_context', 'args': {'query': 'cool kids items', 'top_k': 5}, 'id': 'call_2', 'type': 'tool_call'}], invalid_tool_calls=[])], 'question_relevant': True, 'iteration': 1, 'answer': 'I will find earphones, a laptop bag, and something cool for kids from the available products for you.', 'available_tools': [{'name': 'get_formatted_context', 'description': 'Get the top k context, each representing an inventory item for a given query.', 'parameters': {'type': 'object', 'properties': {'query': {'type': 'string', 'description': 'The query to get the top k context for'}, 'top_k': {'type': 'integer', 'description': 'The number of context chunks to retrieve, works best with 5 or more', 'default': 5}}}, 'required': ['query'], 'returns': {'type': 'string', 'description': 'A string of the top k context chunks with IDs and average ratings prepending each chunk, each representing an inventory item for a given query.'}}], 'tool_calls': [ToolCall(name='get_formatted_context', arguments={'query': 'earphones', 'top_k': 5}), ToolCall(name='get_formatted_context', arguments={'query': 'laptop bag', 'top_k': 5}), ToolCall(name='get_formatted_context', arguments={'query': 'cool kids items', 'top_k': 5})], 'final_answer': False, 'references': []})
# ('debug', {'step': 2, 'timestamp': '2026-02-17T20:58:38.221542+00:00', 'type': 'checkpoint', 'payload': {'config': {'configurable': {'checkpoint_ns': '', 'thread_id': 'test0000000011', 'checkpoint_id': '1f10c436-e8c0-6dc4-8002-3edd5cbb87ce'}}, 'parent_config': {'configurable': {'checkpoint_ns': '', 'thread_id': 'test0000000011', 'checkpoint_id': '1f10c436-cc26-66dc-8001-1c5ad512cd68'}}, 'values': {'messages': [{'role': 'user', 'content': 'Can I get earphones for myself, a laptop bag for my wife and something cool for my kids?'}, AIMessage(content='I will find earphones, a laptop bag, and something cool for kids from the available products for you.', additional_kwargs={}, response_metadata={}, tool_calls=[{'name': 'get_formatted_context', 'args': {'query': 'earphones', 'top_k': 5}, 'id': 'call_0', 'type': 'tool_call'}, {'name': 'get_formatted_context', 'args': {'query': 'laptop bag', 'top_k': 5}, 'id': 'call_1', 'type': 'tool_call'}, {'name': 'get_formatted_context', 'args': {'query': 'cool kids items', 'top_k': 5}, 'id': 'call_2', 'type': 'tool_call'}], invalid_tool_calls=[])], 'question_relevant': True, 'iteration': 1, 'answer': 'I will find earphones, a laptop bag, and something cool for kids from the available products for you.', 'available_tools': [{'name': 'get_formatted_context', 'description': 'Get the top k context, each representing an inventory item for a given query.', 'parameters': {'type': 'object', 'properties': {'query': {'type': 'string', 'description': 'The query to get the top k context for'}, 'top_k': {'type': 'integer', 'description': 'The number of context chunks to retrieve, works best with 5 or more', 'default': 5}}}, 'required': ['query'], 'returns': {'type': 'string', 'description': 'A string of the top k context chunks with IDs and average ratings prepending each chunk, each representing an inventory item for a given query.'}}], 'tool_calls': [ToolCall(name='get_formatted_context', arguments={'query': 'earphones', 'top_k': 5}), ToolCall(name='get_formatted_context', arguments={'query': 'laptop bag', 'top_k': 5}), ToolCall(name='get_formatted_context', arguments={'query': 'cool kids items', 'top_k': 5})], 'final_answer': False, 'references': []}, 'metadata': {'source': 'loop', 'step': 2, 'parents': {}}, 'next': ['tool_node'], 'tasks': [{'id': '967f3ed7-fb66-8635-19d4-b8ac3f306042', 'name': 'tool_node', 'interrupts': (), 'state': None}]}})
# ('debug', {'step': 3, 'timestamp': '2026-02-17T20:58:38.221558+00:00', 'type': 'task', 'payload': {'id': '967f3ed7-fb66-8635-19d4-b8ac3f306042', 'name': 'tool_node', 'input': State(messages=[{'role': 'user', 'content': 'Can I get earphones for myself, a laptop bag for my wife and something cool for my kids?'}, AIMessage(content='I will find earphones, a laptop bag, and something cool for kids from the available products for you.', additional_kwargs={}, response_metadata={}, tool_calls=[{'name': 'get_formatted_context', 'args': {'query': 'earphones', 'top_k': 5}, 'id': 'call_0', 'type': 'tool_call'}, {'name': 'get_formatted_context', 'args': {'query': 'laptop bag', 'top_k': 5}, 'id': 'call_1', 'type': 'tool_call'}, {'name': 'get_formatted_context', 'args': {'query': 'cool kids items', 'top_k': 5}, 'id': 'call_2', 'type': 'tool_call'}], invalid_tool_calls=[])], question_relevant=True, iteration=1, answer='I will find earphones, a laptop bag, and something cool for kids from the available products for you.', available_tools=[{'name': 'get_formatted_context', 'description': 'Get the top k context, each representing an inventory item for a given query.', 'parameters': {'type': 'object', 'properties': {'query': {'type': 'string', 'description': 'The query to get the top k context for'}, 'top_k': {'type': 'integer', 'description': 'The number of context chunks to retrieve, works best with 5 or more', 'default': 5}}}, 'required': ['query'], 'returns': {'type': 'string', 'description': 'A string of the top k context chunks with IDs and average ratings prepending each chunk, each representing an inventory item for a given query.'}}], tool_calls=[ToolCall(name='get_formatted_context', arguments={'query': 'earphones', 'top_k': 5}), ToolCall(name='get_formatted_context', arguments={'query': 'laptop bag', 'top_k': 5}), ToolCall(name='get_formatted_context', arguments={'query': 'cool kids items', 'top_k': 5})], final_answer=False, references=[]), 'triggers': ('branch:to:tool_node',)}})
# ('updates', {'tool_node': {'messages': [ToolMessage(content='- ID: B0B978S5FH, rating: 3.3, description: Earbuds for Wired Headphones Wired Earphones with Microphone Noise Isolating Headsets for Cell Phone White.  \n- ID: B0C3GVF5H9, rating: 4.1, description: MuveAcoustics Link Earbud Headphones True Wireless Bluetooth, in-Ear, Earphones ENC Noise Canceling Microphone, 24H Playtime, IPX5, for Small Ears, Travel, Commute, Home Office, Black. Weatherproof in most scenarios: The Bluetooth earphones may be protected from liquids, including accidental splashes and excessive sweating, thanks to the IPX5-rated LINK wireless earphones. The Link earphones are typically suitable for any activity or setting. Just take them before going to the gym, working out outside, riding a bike, doing Pilates, or travelling!Sound That Inspires : The MuveAcoustics LINK Wireless bluetooth earbuds have a powerful and deep bass that helps you feel every note, immersing you in a world of sound that is both rich and high-fidelity.Instant\xa0Wireless Experience : MvueAcoustics LINK earbuds wireless bluetooth earphones push the boundaries of true wireless earphone technology. It pairs swiftly with your device after the first pairing and has a Bluetooth range of up to 33 feet.All Day Quality Sound\xa0 : The LINK earphones bluetooth wireless can be used for 8 hours when fully charged. The convenient, all-day compact wireless charging case for your earbuds can recharge them twice for 16 additional listening hours!Easy Hands-Free Talking : With the LINK true wireless earbuds\' hands-free calling feature and environmental noise cancelling, talking without using your hands is now simple and effortless. It\'s offered by the LINK true wireless earbuds.Wireless Charging: It is recommended that you use a Qi-standard wireless charging pad to charge the case for your earbuds. Close the charging case\'s lid and place the back of the case in the middle of the charging pad\'s surface. For the best charging results, line up the middle of the charging case with the middle of the charging pad.\u200b \n- ID: B09Q2RFL96, rating: 4.3, description: Custom Airpods Case with Keychain, Custom Airpods Pro Case Personalized Airpods Pro Protective Cover with Your Name & Photo for Men Women. ❤️High-quality material: High-quality PC material, bright colors, clearly visible customized patterns; no hindrance to charging; no yellowing, dust-proof, scratch-resistant, and drop-resistant.❤️Compatible with: AirPods Pro suitable for women and men. It is recommended to check your AirPods model before ordering. It fits perfectly with your AirPods charging base and protects your AirPods from damage.❤️Customized earphone sleeve: You can click the "Customize Now" button, upload your favorite picture or add text to design your Airpod earphone sleeve.❤️Package includes: Customized Airpod Pro earphone sleeve + top cover + keychain, which is convenient to carry, and it is recommended to wipe it clean with clean water regularly.❤️Ideal gift: Customized Airpods earphone sleeves are ideal for gift giving, with your photo printed or photos of friends, love, family, ideal gifts for friends, family on birthdays, Christmas, Valentine\'s Day. \n- ID: B09PG1T4L8, rating: 3.3, description: Wireless Earbuds. Wireless Earbuds.Wireless Earbuds.Wireless Earbuds.Wireless Earbuds.Wireless Earbuds. \n- ID: B0CG9ZWRMC, rating: 4.9, description: 2 Pack Earbuds Wired in Ear Wired Headphones,Earphones with Microphone for 3.5mm Jack Ear Buds Noise Isolation & Volume Control Compatible with iPhone/iPad/Computer/MP3/4 and Other 3.5mm Jack Devices. 【Excellent Sound Quality】Our wired ear buds are equipped with a premium shockproof membrane and advanced sound devices, surpassing conventional headphones wired in sensitivity and noise reduction. Experience an exceptional combination of powerful bass and crystal-clear stereo, allowing you to enjoy music like never before.【Unparalleled Comfort】The wired headphones 3.5mm jack feature a ...
# ('debug', {'step': 3, 'timestamp': '2026-02-17T20:58:38.899639+00:00', 'type': 'task_result', 'payload': {'id': '967f3ed7-fb66-8635-19d4-b8ac3f306042', 'name': 'tool_node', 'error': None, 'result': {'messages': [ToolMessage(content='- ID: B0B978S5FH, rating: 3.3, description: Earbuds for Wired Headphones Wired Earphones with Microphone Noise Isolating Headsets for Cell Phone White.  \n- ID: B0C3GVF5H9, rating: 4.1, description: MuveAcoustics Link Earbud Headphones True Wireless Bluetooth, in-Ear, Earphones ENC Noise Canceling Microphone, 24H Playtime, IPX5, for Small Ears, Travel, Commute, Home Office, Black. Weatherproof in most scenarios: The Bluetooth earphones may be protected from liquids, including accidental splashes and excessive sweating, thanks to the IPX5-rated LINK wireless earphones. The Link earphones are typically suitable for any activity or setting. Just take them before going to the gym, working out outside, riding a bike, doing Pilates, or travelling!Sound That Inspires : The MuveAcoustics LINK Wireless bluetooth earbuds have a powerful and deep bass that helps you feel every note, immersing you in a world of sound that is both rich and high-fidelity.Instant\xa0Wireless Experience : MvueAcoustics LINK earbuds wireless bluetooth earphones push the boundaries of true wireless earphone technology. It pairs swiftly with your device after the first pairing and has a Bluetooth range of up to 33 feet.All Day Quality Sound\xa0 : The LINK earphones bluetooth wireless can be used for 8 hours when fully charged. The convenient, all-day compact wireless charging case for your earbuds can recharge them twice for 16 additional listening hours!Easy Hands-Free Talking : With the LINK true wireless earbuds\' hands-free calling feature and environmental noise cancelling, talking without using your hands is now simple and effortless. It\'s offered by the LINK true wireless earbuds.Wireless Charging: It is recommended that you use a Qi-standard wireless charging pad to charge the case for your earbuds. Close the charging case\'s lid and place the back of the case in the middle of the charging pad\'s surface. For the best charging results, line up the middle of the charging case with the middle of the charging pad.\u200b \n- ID: B09Q2RFL96, rating: 4.3, description: Custom Airpods Case with Keychain, Custom Airpods Pro Case Personalized Airpods Pro Protective Cover with Your Name & Photo for Men Women. ❤️High-quality material: High-quality PC material, bright colors, clearly visible customized patterns; no hindrance to charging; no yellowing, dust-proof, scratch-resistant, and drop-resistant.❤️Compatible with: AirPods Pro suitable for women and men. It is recommended to check your AirPods model before ordering. It fits perfectly with your AirPods charging base and protects your AirPods from damage.❤️Customized earphone sleeve: You can click the "Customize Now" button, upload your favorite picture or add text to design your Airpod earphone sleeve.❤️Package includes: Customized Airpod Pro earphone sleeve + top cover + keychain, which is convenient to carry, and it is recommended to wipe it clean with clean water regularly.❤️Ideal gift: Customized Airpods earphone sleeves are ideal for gift giving, with your photo printed or photos of friends, love, family, ideal gifts for friends, family on birthdays, Christmas, Valentine\'s Day. \n- ID: B09PG1T4L8, rating: 3.3, description: Wireless Earbuds. Wireless Earbuds.Wireless Earbuds.Wireless Earbuds.Wireless Earbuds.Wireless Earbuds. \n- ID: B0CG9ZWRMC, rating: 4.9, description: 2 Pack Earbuds Wired in Ear Wired Headphones,Earphones with Microphone for 3.5mm Jack Ear Buds Noise Isolation & Volume Control Compatible with iPhone/iPad/Computer/MP3/4 and Other 3.5mm Jack Devices. 【Excellent Sound Quality】Our wired ear buds are equipped with a premium shockproof membrane and advanced sound devices, surpassing conventional headphones wired in sensitivity and noise reduction. Experience an exce ...
# ('values', {'messages': [{'role': 'user', 'content': 'Can I get earphones for myself, a laptop bag for my wife and something cool for my kids?'}, AIMessage(content='I will find earphones, a laptop bag, and something cool for kids from the available products for you.', additional_kwargs={}, response_metadata={}, tool_calls=[{'name': 'get_formatted_context', 'args': {'query': 'earphones', 'top_k': 5}, 'id': 'call_0', 'type': 'tool_call'}, {'name': 'get_formatted_context', 'args': {'query': 'laptop bag', 'top_k': 5}, 'id': 'call_1', 'type': 'tool_call'}, {'name': 'get_formatted_context', 'args': {'query': 'cool kids items', 'top_k': 5}, 'id': 'call_2', 'type': 'tool_call'}], invalid_tool_calls=[]), ToolMessage(content='- ID: B0B978S5FH, rating: 3.3, description: Earbuds for Wired Headphones Wired Earphones with Microphone Noise Isolating Headsets for Cell Phone White.  \n- ID: B0C3GVF5H9, rating: 4.1, description: MuveAcoustics Link Earbud Headphones True Wireless Bluetooth, in-Ear, Earphones ENC Noise Canceling Microphone, 24H Playtime, IPX5, for Small Ears, Travel, Commute, Home Office, Black. Weatherproof in most scenarios: The Bluetooth earphones may be protected from liquids, including accidental splashes and excessive sweating, thanks to the IPX5-rated LINK wireless earphones. The Link earphones are typically suitable for any activity or setting. Just take them before going to the gym, working out outside, riding a bike, doing Pilates, or travelling!Sound That Inspires : The MuveAcoustics LINK Wireless bluetooth earbuds have a powerful and deep bass that helps you feel every note, immersing you in a world of sound that is both rich and high-fidelity.Instant\xa0Wireless Experience : MvueAcoustics LINK earbuds wireless bluetooth earphones push the boundaries of true wireless earphone technology. It pairs swiftly with your device after the first pairing and has a Bluetooth range of up to 33 feet.All Day Quality Sound\xa0 : The LINK earphones bluetooth wireless can be used for 8 hours when fully charged. The convenient, all-day compact wireless charging case for your earbuds can recharge them twice for 16 additional listening hours!Easy Hands-Free Talking : With the LINK true wireless earbuds\' hands-free calling feature and environmental noise cancelling, talking without using your hands is now simple and effortless. It\'s offered by the LINK true wireless earbuds.Wireless Charging: It is recommended that you use a Qi-standard wireless charging pad to charge the case for your earbuds. Close the charging case\'s lid and place the back of the case in the middle of the charging pad\'s surface. For the best charging results, line up the middle of the charging case with the middle of the charging pad.\u200b \n- ID: B09Q2RFL96, rating: 4.3, description: Custom Airpods Case with Keychain, Custom Airpods Pro Case Personalized Airpods Pro Protective Cover with Your Name & Photo for Men Women. ❤️High-quality material: High-quality PC material, bright colors, clearly visible customized patterns; no hindrance to charging; no yellowing, dust-proof, scratch-resistant, and drop-resistant.❤️Compatible with: AirPods Pro suitable for women and men. It is recommended to check your AirPods model before ordering. It fits perfectly with your AirPods charging base and protects your AirPods from damage.❤️Customized earphone sleeve: You can click the "Customize Now" button, upload your favorite picture or add text to design your Airpod earphone sleeve.❤️Package includes: Customized Airpod Pro earphone sleeve + top cover + keychain, which is convenient to carry, and it is recommended to wipe it clean with clean water regularly.❤️Ideal gift: Customized Airpods earphone sleeves are ideal for gift giving, with your photo printed or photos of friends, love, family, ideal gifts for friends, family on birthdays, Christmas, Valentine\'s Day. \n- ID: B09PG1T4L8, rating: 3.3, description: Wireless Earbuds. Wireless Earbuds.Wireless Earbuds.Wireless Earbuds.Wire ...
# ('debug', {'step': 3, 'timestamp': '2026-02-17T20:58:38.899783+00:00', 'type': 'checkpoint', 'payload': {'config': {'configurable': {'checkpoint_ns': '', 'thread_id': 'test0000000011', 'checkpoint_id': '1f10c436-ef39-6aca-8003-cfb8dc790203'}}, 'parent_config': {'configurable': {'checkpoint_ns': '', 'thread_id': 'test0000000011', 'checkpoint_id': '1f10c436-e8c0-6dc4-8002-3edd5cbb87ce'}}, 'values': {'messages': [{'role': 'user', 'content': 'Can I get earphones for myself, a laptop bag for my wife and something cool for my kids?'}, AIMessage(content='I will find earphones, a laptop bag, and something cool for kids from the available products for you.', additional_kwargs={}, response_metadata={}, tool_calls=[{'name': 'get_formatted_context', 'args': {'query': 'earphones', 'top_k': 5}, 'id': 'call_0', 'type': 'tool_call'}, {'name': 'get_formatted_context', 'args': {'query': 'laptop bag', 'top_k': 5}, 'id': 'call_1', 'type': 'tool_call'}, {'name': 'get_formatted_context', 'args': {'query': 'cool kids items', 'top_k': 5}, 'id': 'call_2', 'type': 'tool_call'}], invalid_tool_calls=[]), ToolMessage(content='- ID: B0B978S5FH, rating: 3.3, description: Earbuds for Wired Headphones Wired Earphones with Microphone Noise Isolating Headsets for Cell Phone White.  \n- ID: B0C3GVF5H9, rating: 4.1, description: MuveAcoustics Link Earbud Headphones True Wireless Bluetooth, in-Ear, Earphones ENC Noise Canceling Microphone, 24H Playtime, IPX5, for Small Ears, Travel, Commute, Home Office, Black. Weatherproof in most scenarios: The Bluetooth earphones may be protected from liquids, including accidental splashes and excessive sweating, thanks to the IPX5-rated LINK wireless earphones. The Link earphones are typically suitable for any activity or setting. Just take them before going to the gym, working out outside, riding a bike, doing Pilates, or travelling!Sound That Inspires : The MuveAcoustics LINK Wireless bluetooth earbuds have a powerful and deep bass that helps you feel every note, immersing you in a world of sound that is both rich and high-fidelity.Instant\xa0Wireless Experience : MvueAcoustics LINK earbuds wireless bluetooth earphones push the boundaries of true wireless earphone technology. It pairs swiftly with your device after the first pairing and has a Bluetooth range of up to 33 feet.All Day Quality Sound\xa0 : The LINK earphones bluetooth wireless can be used for 8 hours when fully charged. The convenient, all-day compact wireless charging case for your earbuds can recharge them twice for 16 additional listening hours!Easy Hands-Free Talking : With the LINK true wireless earbuds\' hands-free calling feature and environmental noise cancelling, talking without using your hands is now simple and effortless. It\'s offered by the LINK true wireless earbuds.Wireless Charging: It is recommended that you use a Qi-standard wireless charging pad to charge the case for your earbuds. Close the charging case\'s lid and place the back of the case in the middle of the charging pad\'s surface. For the best charging results, line up the middle of the charging case with the middle of the charging pad.\u200b \n- ID: B09Q2RFL96, rating: 4.3, description: Custom Airpods Case with Keychain, Custom Airpods Pro Case Personalized Airpods Pro Protective Cover with Your Name & Photo for Men Women. ❤️High-quality material: High-quality PC material, bright colors, clearly visible customized patterns; no hindrance to charging; no yellowing, dust-proof, scratch-resistant, and drop-resistant.❤️Compatible with: AirPods Pro suitable for women and men. It is recommended to check your AirPods model before ordering. It fits perfectly with your AirPods charging base and protects your AirPods from damage.❤️Customized earphone sleeve: You can click the "Customize Now" button, upload your favorite picture or add text to design your Airpod earphone sleeve.❤️Package includes: Customized Airpod Pro earphone sleeve + top cover + keychain, which is convenient to carry, and it i ...
# ('debug', {'step': 4, 'timestamp': '2026-02-17T20:58:38.899788+00:00', 'type': 'task', 'payload': {'id': '8e20c76d-e7ba-6faf-2a68-c8e805137c44', 'name': 'agent_node', 'input': State(messages=[{'role': 'user', 'content': 'Can I get earphones for myself, a laptop bag for my wife and something cool for my kids?'}, AIMessage(content='I will find earphones, a laptop bag, and something cool for kids from the available products for you.', additional_kwargs={}, response_metadata={}, tool_calls=[{'name': 'get_formatted_context', 'args': {'query': 'earphones', 'top_k': 5}, 'id': 'call_0', 'type': 'tool_call'}, {'name': 'get_formatted_context', 'args': {'query': 'laptop bag', 'top_k': 5}, 'id': 'call_1', 'type': 'tool_call'}, {'name': 'get_formatted_context', 'args': {'query': 'cool kids items', 'top_k': 5}, 'id': 'call_2', 'type': 'tool_call'}], invalid_tool_calls=[]), ToolMessage(content='- ID: B0B978S5FH, rating: 3.3, description: Earbuds for Wired Headphones Wired Earphones with Microphone Noise Isolating Headsets for Cell Phone White.  \n- ID: B0C3GVF5H9, rating: 4.1, description: MuveAcoustics Link Earbud Headphones True Wireless Bluetooth, in-Ear, Earphones ENC Noise Canceling Microphone, 24H Playtime, IPX5, for Small Ears, Travel, Commute, Home Office, Black. Weatherproof in most scenarios: The Bluetooth earphones may be protected from liquids, including accidental splashes and excessive sweating, thanks to the IPX5-rated LINK wireless earphones. The Link earphones are typically suitable for any activity or setting. Just take them before going to the gym, working out outside, riding a bike, doing Pilates, or travelling!Sound That Inspires : The MuveAcoustics LINK Wireless bluetooth earbuds have a powerful and deep bass that helps you feel every note, immersing you in a world of sound that is both rich and high-fidelity.Instant\xa0Wireless Experience : MvueAcoustics LINK earbuds wireless bluetooth earphones push the boundaries of true wireless earphone technology. It pairs swiftly with your device after the first pairing and has a Bluetooth range of up to 33 feet.All Day Quality Sound\xa0 : The LINK earphones bluetooth wireless can be used for 8 hours when fully charged. The convenient, all-day compact wireless charging case for your earbuds can recharge them twice for 16 additional listening hours!Easy Hands-Free Talking : With the LINK true wireless earbuds\' hands-free calling feature and environmental noise cancelling, talking without using your hands is now simple and effortless. It\'s offered by the LINK true wireless earbuds.Wireless Charging: It is recommended that you use a Qi-standard wireless charging pad to charge the case for your earbuds. Close the charging case\'s lid and place the back of the case in the middle of the charging pad\'s surface. For the best charging results, line up the middle of the charging case with the middle of the charging pad.\u200b \n- ID: B09Q2RFL96, rating: 4.3, description: Custom Airpods Case with Keychain, Custom Airpods Pro Case Personalized Airpods Pro Protective Cover with Your Name & Photo for Men Women. ❤️High-quality material: High-quality PC material, bright colors, clearly visible customized patterns; no hindrance to charging; no yellowing, dust-proof, scratch-resistant, and drop-resistant.❤️Compatible with: AirPods Pro suitable for women and men. It is recommended to check your AirPods model before ordering. It fits perfectly with your AirPods charging base and protects your AirPods from damage.❤️Customized earphone sleeve: You can click the "Customize Now" button, upload your favorite picture or add text to design your Airpod earphone sleeve.❤️Package includes: Customized Airpod Pro earphone sleeve + top cover + keychain, which is convenient to carry, and it is recommended to wipe it clean with clean water regularly.❤️Ideal gift: Customized Airpods earphone sleeves are ideal for gift giving, with your photo printed or photos of friends, love, family, ideal gifts for friends, fa ...
# ('updates', {'agent_node': {'messages': [AIMessage(content="Here are some options for you:\n\nEarphones:\n- MuveAcoustics Link Earbud Headphones: True Wireless Bluetooth, ENC Noise Canceling Microphone, 24H Playtime, IPX5, suitable for small ears, travel, commute, home office. Black color.\n- Wired Earbuds Wired Headphones: Wired earphones with microphone, noise isolation, volume control, compatible with 3.5mm jack devices like iPhone, iPad, computers.\n- Custom Airpods Case with Keychain: Personalized protective cover for Airpods Pro with your name and photo, high-quality PC material.\n\nLaptop Bags for your wife:\n- Keyli Laptop Bag for Women: Large PU leather laptop briefcase with USB charging port, multiple compartments, waterproof, stylish and versatile.\n- ESTARER Men's Laptop Messenger Bag: Water-resistant canvas computer bag, 3-in-1 convertible briefcase, padded laptop sleeve, multiple pockets.\n- ETRONIK Lunch Backpack for Women: 15.6 inch laptop backpack with USB port, insulated lunch bag, multiple compartments, suitable for work and travel.\n\nCool items for kids:\n- iClever Kids Headphones Cat Ear: LED light-up headphones with 85dBA safe volume, foldable, comfortable, compatible with tablets and laptops.\n- Kids Headphones with Mic: Volume limited foldable on-ear headphones with mic, suitable for kids aged 3-16, comfortable and lightweight.\n- 200PCS Trippy Mixed Stickers: Vinyl waterproof skateboard stickers for decorating laptops, water bottles, and more, cool and creative.\n\nIf you want detailed specifications or more options on any category, please let me know!", additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[])], 'tool_calls': [], 'iteration': 2, 'answer': "Here are some options for you:\n\nEarphones:\n- MuveAcoustics Link Earbud Headphones: True Wireless Bluetooth, ENC Noise Canceling Microphone, 24H Playtime, IPX5, suitable for small ears, travel, commute, home office. Black color.\n- Wired Earbuds Wired Headphones: Wired earphones with microphone, noise isolation, volume control, compatible with 3.5mm jack devices like iPhone, iPad, computers.\n- Custom Airpods Case with Keychain: Personalized protective cover for Airpods Pro with your name and photo, high-quality PC material.\n\nLaptop Bags for your wife:\n- Keyli Laptop Bag for Women: Large PU leather laptop briefcase with USB charging port, multiple compartments, waterproof, stylish and versatile.\n- ESTARER Men's Laptop Messenger Bag: Water-resistant canvas computer bag, 3-in-1 convertible briefcase, padded laptop sleeve, multiple pockets.\n- ETRONIK Lunch Backpack for Women: 15.6 inch laptop backpack with USB port, insulated lunch bag, multiple compartments, suitable for work and travel.\n\nCool items for kids:\n- iClever Kids Headphones Cat Ear: LED light-up headphones with 85dBA safe volume, foldable, comfortable, compatible with tablets and laptops.\n- Kids Headphones with Mic: Volume limited foldable on-ear headphones with mic, suitable for kids aged 3-16, comfortable and lightweight.\n- 200PCS Trippy Mixed Stickers: Vinyl waterproof skateboard stickers for decorating laptops, water bottles, and more, cool and creative.\n\nIf you want detailed specifications or more options on any category, please let me know!", 'final_answer': True, 'references': [RAGUsedContext(id='B0C3GVF5H9', description='MuveAcoustics Link Earbud Headphones True Wireless Bluetooth Earphones'), RAGUsedContext(id='B0CG9ZWRMC', description='2 Pack Earbuds Wired in Ear Wired Headphones with Microphone'), RAGUsedContext(id='B09Q2RFL96', description='Custom Airpods Case with Keychain Personalized Airpods Pro Case'), RAGUsedContext(id='B0BFDRRB65', description='Keyli Laptop Bag for Women Large PU Leather Laptop Briefcase with USB Charging Port'), RAGUsedContext(id='B0B2PLM3T5', description="ESTARER Men's Laptop Messenger Bag Water Resistant Canvas Computer Bag"), RAGUsedContext(id='B0BKZRQS92', description='ETRONIK Lunch Backpack for Women 15.6 inch L ...
# ('debug', {'step': 4, 'timestamp': '2026-02-17T20:58:49.428158+00:00', 'type': 'task_result', 'payload': {'id': '8e20c76d-e7ba-6faf-2a68-c8e805137c44', 'name': 'agent_node', 'error': None, 'result': {'messages': [AIMessage(content="Here are some options for you:\n\nEarphones:\n- MuveAcoustics Link Earbud Headphones: True Wireless Bluetooth, ENC Noise Canceling Microphone, 24H Playtime, IPX5, suitable for small ears, travel, commute, home office. Black color.\n- Wired Earbuds Wired Headphones: Wired earphones with microphone, noise isolation, volume control, compatible with 3.5mm jack devices like iPhone, iPad, computers.\n- Custom Airpods Case with Keychain: Personalized protective cover for Airpods Pro with your name and photo, high-quality PC material.\n\nLaptop Bags for your wife:\n- Keyli Laptop Bag for Women: Large PU leather laptop briefcase with USB charging port, multiple compartments, waterproof, stylish and versatile.\n- ESTARER Men's Laptop Messenger Bag: Water-resistant canvas computer bag, 3-in-1 convertible briefcase, padded laptop sleeve, multiple pockets.\n- ETRONIK Lunch Backpack for Women: 15.6 inch laptop backpack with USB port, insulated lunch bag, multiple compartments, suitable for work and travel.\n\nCool items for kids:\n- iClever Kids Headphones Cat Ear: LED light-up headphones with 85dBA safe volume, foldable, comfortable, compatible with tablets and laptops.\n- Kids Headphones with Mic: Volume limited foldable on-ear headphones with mic, suitable for kids aged 3-16, comfortable and lightweight.\n- 200PCS Trippy Mixed Stickers: Vinyl waterproof skateboard stickers for decorating laptops, water bottles, and more, cool and creative.\n\nIf you want detailed specifications or more options on any category, please let me know!", additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[])], 'tool_calls': [], 'iteration': 2, 'answer': "Here are some options for you:\n\nEarphones:\n- MuveAcoustics Link Earbud Headphones: True Wireless Bluetooth, ENC Noise Canceling Microphone, 24H Playtime, IPX5, suitable for small ears, travel, commute, home office. Black color.\n- Wired Earbuds Wired Headphones: Wired earphones with microphone, noise isolation, volume control, compatible with 3.5mm jack devices like iPhone, iPad, computers.\n- Custom Airpods Case with Keychain: Personalized protective cover for Airpods Pro with your name and photo, high-quality PC material.\n\nLaptop Bags for your wife:\n- Keyli Laptop Bag for Women: Large PU leather laptop briefcase with USB charging port, multiple compartments, waterproof, stylish and versatile.\n- ESTARER Men's Laptop Messenger Bag: Water-resistant canvas computer bag, 3-in-1 convertible briefcase, padded laptop sleeve, multiple pockets.\n- ETRONIK Lunch Backpack for Women: 15.6 inch laptop backpack with USB port, insulated lunch bag, multiple compartments, suitable for work and travel.\n\nCool items for kids:\n- iClever Kids Headphones Cat Ear: LED light-up headphones with 85dBA safe volume, foldable, comfortable, compatible with tablets and laptops.\n- Kids Headphones with Mic: Volume limited foldable on-ear headphones with mic, suitable for kids aged 3-16, comfortable and lightweight.\n- 200PCS Trippy Mixed Stickers: Vinyl waterproof skateboard stickers for decorating laptops, water bottles, and more, cool and creative.\n\nIf you want detailed specifications or more options on any category, please let me know!", 'final_answer': True, 'references': [RAGUsedContext(id='B0C3GVF5H9', description='MuveAcoustics Link Earbud Headphones True Wireless Bluetooth Earphones'), RAGUsedContext(id='B0CG9ZWRMC', description='2 Pack Earbuds Wired in Ear Wired Headphones with Microphone'), RAGUsedContext(id='B09Q2RFL96', description='Custom Airpods Case with Keychain Personalized Airpods Pro Case'), RAGUsedContext(id='B0BFDRRB65', description='Keyli Laptop Bag for Women Large PU Leather Laptop Briefcase with USB Charging Port'), RAGUsedContext(id='B0B2PLM3T5', desc ...
# ('values', {'messages': [{'role': 'user', 'content': 'Can I get earphones for myself, a laptop bag for my wife and something cool for my kids?'}, AIMessage(content='I will find earphones, a laptop bag, and something cool for kids from the available products for you.', additional_kwargs={}, response_metadata={}, tool_calls=[{'name': 'get_formatted_context', 'args': {'query': 'earphones', 'top_k': 5}, 'id': 'call_0', 'type': 'tool_call'}, {'name': 'get_formatted_context', 'args': {'query': 'laptop bag', 'top_k': 5}, 'id': 'call_1', 'type': 'tool_call'}, {'name': 'get_formatted_context', 'args': {'query': 'cool kids items', 'top_k': 5}, 'id': 'call_2', 'type': 'tool_call'}], invalid_tool_calls=[]), ToolMessage(content='- ID: B0B978S5FH, rating: 3.3, description: Earbuds for Wired Headphones Wired Earphones with Microphone Noise Isolating Headsets for Cell Phone White.  \n- ID: B0C3GVF5H9, rating: 4.1, description: MuveAcoustics Link Earbud Headphones True Wireless Bluetooth, in-Ear, Earphones ENC Noise Canceling Microphone, 24H Playtime, IPX5, for Small Ears, Travel, Commute, Home Office, Black. Weatherproof in most scenarios: The Bluetooth earphones may be protected from liquids, including accidental splashes and excessive sweating, thanks to the IPX5-rated LINK wireless earphones. The Link earphones are typically suitable for any activity or setting. Just take them before going to the gym, working out outside, riding a bike, doing Pilates, or travelling!Sound That Inspires : The MuveAcoustics LINK Wireless bluetooth earbuds have a powerful and deep bass that helps you feel every note, immersing you in a world of sound that is both rich and high-fidelity.Instant\xa0Wireless Experience : MvueAcoustics LINK earbuds wireless bluetooth earphones push the boundaries of true wireless earphone technology. It pairs swiftly with your device after the first pairing and has a Bluetooth range of up to 33 feet.All Day Quality Sound\xa0 : The LINK earphones bluetooth wireless can be used for 8 hours when fully charged. The convenient, all-day compact wireless charging case for your earbuds can recharge them twice for 16 additional listening hours!Easy Hands-Free Talking : With the LINK true wireless earbuds\' hands-free calling feature and environmental noise cancelling, talking without using your hands is now simple and effortless. It\'s offered by the LINK true wireless earbuds.Wireless Charging: It is recommended that you use a Qi-standard wireless charging pad to charge the case for your earbuds. Close the charging case\'s lid and place the back of the case in the middle of the charging pad\'s surface. For the best charging results, line up the middle of the charging case with the middle of the charging pad.\u200b \n- ID: B09Q2RFL96, rating: 4.3, description: Custom Airpods Case with Keychain, Custom Airpods Pro Case Personalized Airpods Pro Protective Cover with Your Name & Photo for Men Women. ❤️High-quality material: High-quality PC material, bright colors, clearly visible customized patterns; no hindrance to charging; no yellowing, dust-proof, scratch-resistant, and drop-resistant.❤️Compatible with: AirPods Pro suitable for women and men. It is recommended to check your AirPods model before ordering. It fits perfectly with your AirPods charging base and protects your AirPods from damage.❤️Customized earphone sleeve: You can click the "Customize Now" button, upload your favorite picture or add text to design your Airpod earphone sleeve.❤️Package includes: Customized Airpod Pro earphone sleeve + top cover + keychain, which is convenient to carry, and